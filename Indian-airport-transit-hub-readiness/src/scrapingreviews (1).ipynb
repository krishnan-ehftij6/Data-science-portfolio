# %% [markdown]
# Collecting Data for Airport Review Analysis

# %%
# !pip install requests beautifulsoup4 selenium pandas nltk textblob wordcloud matplotlib seaborn
# Out:
# Requirement already satisfied: requests in c:\users\krishnan srinivas\anaconda3\lib\site-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\krishnan srinivas\anaconda3\lib\site-packages (4.12.3)
# Requirement already satisfied: selenium in c:\users\krishnan srinivas\anaconda3\lib\site-packages (4.29.0)
# Requirement already satisfied: pandas in c:\users\krishnan srinivas\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: nltk in c:\users\krishnan srinivas\anaconda3\lib\site-packages (3.9.1)
# Requirement already satisfied: textblob in c:\users\krishnan srinivas\anaconda3\lib\site-packages (0.19.0)
# Requirement already satisfied: wordcloud in c:\users\krishnan srinivas\anaconda3\lib\site-packages (1.9.4)
# Requirement already satisfied: matplotlib in c:\users\krishnan srinivas\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: seaborn in c:\users\krishnan srinivas\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\krishnan srinivas\anaconda3\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\krishnan srinivas\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\krishnan srinivas\anaconda3\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\krishnan srinivas\anaconda3\lib\site-packages (from requests) (2024.8.30)
# Requirement already satisfied: soupsieve>1.2 in c:\users\krishnan srinivas\anaconda3\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: trio~=0.17 in c:\users\krishnan srinivas\anaconda3\lib\site-packages (from selenium) (0.29.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\krishnan srinivas\anaconda3\lib\site-packages (from selenium) (0.12.2)
# Requirement already satisfied: typing_extensions~=4.9 in c:\users\krishnan srinivas\anaconda3\lib\site-packages (from selenium) (4.11.0)
# Requirement already satisfied: websocket-client~=1.8 in c:\users\krishnan srinivas\anaconda3\lib\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\krishnan srinivas\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\krishnan srinivas\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\krishnan srinivas\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\krishnan srinivas\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: click in c:\users\krishnan srinivas\anaconda3\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\krishnan srinivas\anaconda3\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\krishnan srinivas\anaconda3\lib\site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\krishnan srinivas\anaconda3\lib\site-packages (from nltk) (4.66.5)
# Requirement already satisfied: pillow in c:\users\krishnan srinivas\anaconda3\lib\site-packages (from wordcloud) (10.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\krishnan srinivas\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\krishnan srinivas\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\krishnan srinivas\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\krishnan srinivas\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\krishnan srinivas\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\krishnan srinivas\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\krishnan srinivas\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\krishnan srinivas\anaconda3\lib\site-packages (from trio~=0.17->selenium) (25.1.0)
# Requirement already satisfied: sortedcontainers in c:\users\krishnan srinivas\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: outcome in c:\users\krishnan srinivas\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\krishnan srinivas\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\krishnan srinivas\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.17.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\krishnan srinivas\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\krishnan srinivas\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: colorama in c:\users\krishnan srinivas\anaconda3\lib\site-packages (from click->nltk) (0.4.6)
# Requirement already satisfied: pycparser in c:\users\krishnan srinivas\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\krishnan srinivas\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %% [markdown]
# **Scraping Reviews on Skytrax**

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
#Listing all airport URLS
airports = {
    "Abu Dhabi": "https://www.airlinequality.com/airport-reviews/abu-dhabi-airport/",
    "Dubai":"https://www.airlinequality.com/airport-reviews/dubai-airport/",
    "Doha":"https://www.airlinequality.com/airport-reviews/doha-airport/",
    "Istanbul":"https://www.airlinequality.com/airport-reviews/istanbul-airport/",
    "Singapore":"https://www.airlinequality.com/airport-reviews/singapore-changi-airport/",
    "Hong Kong": "https://www.airlinequality.com/airport-reviews/hong-kong-airport/",
    "Addis Ababa": "https://www.airlinequality.com/airport-reviews/addis-ababa-airport/",
    "Bangkok-Suvarnabhumi":"https://www.airlinequality.com/airport-reviews/bangkok-suvarnabhumi-airport/",
    "Kuala Lumpur KLIA":"https://www.airlinequality.com/airport-reviews/klia-kuala-lumpur-airport/",
    "Delhi":"https://www.airlinequality.com/airport-reviews/delhi-airport/",
    "Mumbai":"https://www.airlinequality.com/airport-reviews/mumbai-airport/",
    "Bengaluru":"https://www.airlinequality.com/airport-reviews/bangalore-airport/",
    "Hyderabad":"https://www.airlinequality.com/airport-reviews/hyderabad-airport/"
}

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def scrape_skytrax_reviews(airport_name, base_url, pages=30):
    headers = { 
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/133.0.0.0 Safari/537.36 Edg/133.0.0.0"
    }
    
    all_reviews = []

    for i in range(1, pages + 1): 
        print(f"Scraping {airport_name} - Page {i}...")

        # Construct URL for pagination
        url = f"{base_url}/page/{i}/" if i > 1 else base_url
        
        # Send request
        response = requests.get(url, headers=headers)
        if response.status_code != 200:
            print(f"Failed to fetch data for {airport_name} - Page {i}")
            continue

        soup = BeautifulSoup(response.content, "html.parser")

        # Finding all reviews
        reviews = soup.find_all("article", class_="comp comp_reviews-review")
        if not reviews:
            print(f"No reviews found on {airport_name} - Page {i}")
            continue  # Skip if no reviews found

        # Extracting details from each review
        for review in reviews:
            try:
                title = review.find("h2", class_="text_header").get_text(strip=True) if review.find("h2", class_="text_header") else "N/A"
                author = review.find("span", itemprop="name").get_text(strip=True) if review.find("span", itemprop="name") else "N/A"
                date_published = review.find("time", itemprop="datePublished")["datetime"] if review.find("time", itemprop="datePublished") else "N/A"
                review_text = review.find("div", class_="text_content").get_text(strip=True) if review.find("div", class_="text_content") else "N/A"
                
                # Extract overall rating
                overall_rating = review.find("span", itemprop="ratingValue")
                overall_rating = overall_rating.get_text(strip=True) if overall_rating else "N/A"

                # Extract traveler type, experience (arrival/departure/transit)
                traveller_type = review.find("td", class_="review-rating-header type_of_traveller")
                traveller_type = traveller_type.find_next_sibling("td").get_text(strip=True) if traveller_type else "N/A"

                experience = review.find("td", class_="review-rating-header experience_at_airport")
                experience = experience.find_next_sibling("td").get_text(strip=True) if experience else "N/A"

                # Extract recommended (Yes/No)
                recommended = review.find("td", class_="review-rating-header recommended")
                recommended = recommended.find_next_sibling("td").get_text(strip=True) if recommended else "N/A"

                # Extract category ratings (Terminal Cleanliness, Seating, Signs, Food, Shopping, WiFi, Staff)
                category_ratings = {}
                rating_labels = ["Terminal Cleanliness", "Terminal Seating", "Terminal Signs", 
                                 "Food & Beverages", "Airport Shopping", "Wifi Connectivity", "Airport Staff"]
                
                rating_cells = review.find_all("td", class_="review-rating-stars")

                for label, cell in zip(rating_labels, rating_cells):
                    category_ratings[label] = len(cell.find_all("span", class_="star fill"))  # Count filled stars
                
                # Append data to list
                all_reviews.append({
                    "Airport": airport_name,
                    "Title": title,
                    "Author": author,
                    "Date Published": date_published,
                    "Review Text": review_text,
                    "Overall Rating": overall_rating,
                    "Type of Traveller": traveller_type, 
                    "Experience": experience,
                    "Recommended": recommended,
                    **category_ratings  # Unpack category ratings into dictionary
                })

            except Exception as e:
                print(f"Error extracting review for {airport_name}: {e}")

        print(f" ---> {len(all_reviews)} total reviews collected so far")

        # Add delay to avoid getting blocked
        time.sleep(3)  

    return all_reviews

# List of airports to scrape
airports = {
    "Istanbul": "https://www.airlinequality.com/airport-reviews/istanbul-airport",
    "Addis Ababa": "https://www.airlinequality.com/airport-reviews/addis-ababa-airport",
    "Dubai": "https://www.airlinequality.com/airport-reviews/dubai-airport",
    "Doha": "https://www.airlinequality.com/airport-reviews/doha-hamad-airport",
    "Abu Dhabi": "https://www.airlinequality.com/airport-reviews/abu-dhabi-airport",
    "Bangkok": "https://www.airlinequality.com/airport-reviews/bangkok-airport",
    "Singapore": "https://www.airlinequality.com/airport-reviews/singapore-changi-airport",
    "Hong Kong": "https://www.airlinequality.com/airport-reviews/hong-kong-airport",
    "Delhi": "https://www.airlinequality.com/airport-reviews/delhi-indira-gandhi-airport",
    "Mumbai": "https://www.airlinequality.com/airport-reviews/mumbai-chhatrapati-shivaji-airport",
    "Bangalore": "https://www.airlinequality.com/airport-reviews/bangalore-kempegowda-airport",
    "Hyderabad": "https://www.airlinequality.com/airport-reviews/hyderabad-rajiv-gandhi-airport"
}

# Scrape all airports
all_reviews = []
for airport, url in airports.items():
    print(f"\nStarting scraping for {airport}...")
    airport_reviews = scrape_skytrax_reviews(airport, url, pages=30)
    all_reviews.extend(airport_reviews)

# Convert to DataFrame and save to CSV
df = pd.DataFrame(all_reviews)
df.head()
# Out:
# Starting scraping for Istanbul...
# Scraping Istanbul - Page 1...
# No reviews found on Istanbul - Page 1
# Scraping Istanbul - Page 2...
# No reviews found on Istanbul - Page 2
# Scraping Istanbul - Page 3...
# No reviews found on Istanbul - Page 3
# Scraping Istanbul - Page 4...
# No reviews found on Istanbul - Page 4
# Scraping Istanbul - Page 5...
# No reviews found on Istanbul - Page 5
# Scraping Istanbul - Page 6...
# No reviews found on Istanbul - Page 6
# Scraping Istanbul - Page 7...
# No reviews found on Istanbul - Page 7
# Scraping Istanbul - Page 8...
# No reviews found on Istanbul - Page 8
# Scraping Istanbul - Page 9...
# No reviews found on Istanbul - Page 9
# Scraping Istanbul - Page 10...
# No reviews found on Istanbul - Page 10
# Scraping Istanbul - Page 11...
# No reviews found on Istanbul - Page 11
# Scraping Istanbul - Page 12...
# No reviews found on Istanbul - Page 12
# Scraping Istanbul - Page 13...
# No reviews found on Istanbul - Page 13
# Scraping Istanbul - Page 14...
# No reviews found on Istanbul - Page 14
# Scraping Istanbul - Page 15...
# No reviews found on Istanbul - Page 15
# Scraping Istanbul - Page 16...
# No reviews found on Istanbul - Page 16
# Scraping Istanbul - Page 17...
# No reviews found on Istanbul - Page 17
# Scraping Istanbul - Page 18...
# No reviews found on Istanbul - Page 18
# Scraping Istanbul - Page 19...
# No reviews found on Istanbul - Page 19
# Scraping Istanbul - Page 20...
# No reviews found on Istanbul - Page 20
# Scraping Istanbul - Page 21...
# No reviews found on Istanbul - Page 21
# Scraping Istanbul - Page 22...
# No reviews found on Istanbul - Page 22
# Scraping Istanbul - Page 23...
# No reviews found on Istanbul - Page 23
# Scraping Istanbul - Page 24...
# No reviews found on Istanbul - Page 24
# Scraping Istanbul - Page 25...
# No reviews found on Istanbul - Page 25
# Scraping Istanbul - Page 26...
# No reviews found on Istanbul - Page 26
# Scraping Istanbul - Page 27...
# No reviews found on Istanbul - Page 27
# Scraping Istanbul - Page 28...
# No reviews found on Istanbul - Page 28
# Scraping Istanbul - Page 29...
# No reviews found on Istanbul - Page 29
# Scraping Istanbul - Page 30...
# No reviews found on Istanbul - Page 30
#
# Starting scraping for Addis Ababa...
# Scraping Addis Ababa - Page 1...
# No reviews found on Addis Ababa - Page 1
# Scraping Addis Ababa - Page 2...
# No reviews found on Addis Ababa - Page 2
# Scraping Addis Ababa - Page 3...
# No reviews found on Addis Ababa - Page 3
# Scraping Addis Ababa - Page 4...
# No reviews found on Addis Ababa - Page 4
# Scraping Addis Ababa - Page 5...
# No reviews found on Addis Ababa - Page 5
# Scraping Addis Ababa - Page 6...
# No reviews found on Addis Ababa - Page 6
# Scraping Addis Ababa - Page 7...
# No reviews found on Addis Ababa - Page 7
# Scraping Addis Ababa - Page 8...
# No reviews found on Addis Ababa - Page 8
# Scraping Addis Ababa - Page 9...
# No reviews found on Addis Ababa - Page 9
# Scraping Addis Ababa - Page 10...
# No reviews found on Addis Ababa - Page 10
# Scraping Addis Ababa - Page 11...
# No reviews found on Addis Ababa - Page 11
# Scraping Addis Ababa - Page 12...
# No reviews found on Addis Ababa - Page 12
# Scraping Addis Ababa - Page 13...
# No reviews found on Addis Ababa - Page 13
# Scraping Addis Ababa - Page 14...
# No reviews found on Addis Ababa - Page 14
# Scraping Addis Ababa - Page 15...
# No reviews found on Addis Ababa - Page 15
# Scraping Addis Ababa - Page 16...
# No reviews found on Addis Ababa - Page 16
# Scraping Addis Ababa - Page 17...
# No reviews found on Addis Ababa - Page 17
# Scraping Addis Ababa - Page 18...
# No reviews found on Addis Ababa - Page 18
# Scraping Addis Ababa - Page 19...
# No reviews found on Addis Ababa - Page 19
# Scraping Addis Ababa - Page 20...
# No reviews found on Addis Ababa - Page 20
# Scraping Addis Ababa - Page 21...
# No reviews found on Addis Ababa - Page 21
# Scraping Addis Ababa - Page 22...
# No reviews found on Addis Ababa - Page 22
# Scraping Addis Ababa - Page 23...
# No reviews found on Addis Ababa - Page 23
# Scraping Addis Ababa - Page 24...
# No reviews found on Addis Ababa - Page 24
# Scraping Addis Ababa - Page 25...
# No reviews found on Addis Ababa - Page 25
# Scraping Addis Ababa - Page 26...
# No reviews found on Addis Ababa - Page 26
# Scraping Addis Ababa - Page 27...
# No reviews found on Addis Ababa - Page 27
# Scraping Addis Ababa - Page 28...
# No reviews found on Addis Ababa - Page 28
# Scraping Addis Ababa - Page 29...
# No reviews found on Addis Ababa - Page 29
# Scraping Addis Ababa - Page 30...
# No reviews found on Addis Ababa - Page 30
#
# Starting scraping for Dubai...
# Scraping Dubai - Page 1...
# No reviews found on Dubai - Page 1
# Scraping Dubai - Page 2...
# No reviews found on Dubai - Page 2
# Scraping Dubai - Page 3...
# No reviews found on Dubai - Page 3
# Scraping Dubai - Page 4...
# No reviews found on Dubai - Page 4
# Scraping Dubai - Page 5...
# No reviews found on Dubai - Page 5
# Scraping Dubai - Page 6...
# No reviews found on Dubai - Page 6
# Scraping Dubai - Page 7...
# No reviews found on Dubai - Page 7
# Scraping Dubai - Page 8...
# No reviews found on Dubai - Page 8
# Scraping Dubai - Page 9...
# No reviews found on Dubai - Page 9
# Scraping Dubai - Page 10...
# No reviews found on Dubai - Page 10
# Scraping Dubai - Page 11...
# No reviews found on Dubai - Page 11
# Scraping Dubai - Page 12...
# No reviews found on Dubai - Page 12
# Scraping Dubai - Page 13...
# No reviews found on Dubai - Page 13
# Scraping Dubai - Page 14...
# No reviews found on Dubai - Page 14
# Scraping Dubai - Page 15...
# No reviews found on Dubai - Page 15
# Scraping Dubai - Page 16...
# No reviews found on Dubai - Page 16
# Scraping Dubai - Page 17...
# No reviews found on Dubai - Page 17
# Scraping Dubai - Page 18...
# No reviews found on Dubai - Page 18
# Scraping Dubai - Page 19...
# No reviews found on Dubai - Page 19
# Scraping Dubai - Page 20...
# No reviews found on Dubai - Page 20
# Scraping Dubai - Page 21...
# No reviews found on Dubai - Page 21
# Scraping Dubai - Page 22...
# No reviews found on Dubai - Page 22
# Scraping Dubai - Page 23...
# No reviews found on Dubai - Page 23
# Scraping Dubai - Page 24...
# No reviews found on Dubai - Page 24
# Scraping Dubai - Page 25...
# No reviews found on Dubai - Page 25
# Scraping Dubai - Page 26...
# No reviews found on Dubai - Page 26
# Scraping Dubai - Page 27...
# No reviews found on Dubai - Page 27
# Scraping Dubai - Page 28...
# No reviews found on Dubai - Page 28
# Scraping Dubai - Page 29...
# No reviews found on Dubai - Page 29
# Scraping Dubai - Page 30...
# No reviews found on Dubai - Page 30
#
# Starting scraping for Doha...
# Scraping Doha - Page 1...
# Failed to fetch data for Doha - Page 1
# Scraping Doha - Page 2...
# No reviews found on Doha - Page 2
# Scraping Doha - Page 3...
# No reviews found on Doha - Page 3
# Scraping Doha - Page 4...
# No reviews found on Doha - Page 4
# Scraping Doha - Page 5...
# No reviews found on Doha - Page 5
# Scraping Doha - Page 6...
# No reviews found on Doha - Page 6
# Scraping Doha - Page 7...
# No reviews found on Doha - Page 7
# Scraping Doha - Page 8...
# No reviews found on Doha - Page 8
# Scraping Doha - Page 9...
# No reviews found on Doha - Page 9
# Scraping Doha - Page 10...
# No reviews found on Doha - Page 10
# Scraping Doha - Page 11...
# No reviews found on Doha - Page 11
# Scraping Doha - Page 12...
# No reviews found on Doha - Page 12
# Scraping Doha - Page 13...
# No reviews found on Doha - Page 13
# Scraping Doha - Page 14...
# No reviews found on Doha - Page 14
# Scraping Doha - Page 15...
# No reviews found on Doha - Page 15
# Scraping Doha - Page 16...
# No reviews found on Doha - Page 16
# Scraping Doha - Page 17...
# No reviews found on Doha - Page 17
# Scraping Doha - Page 18...
# No reviews found on Doha - Page 18
# Scraping Doha - Page 19...
# No reviews found on Doha - Page 19
# Scraping Doha - Page 20...
# No reviews found on Doha - Page 20
# Scraping Doha - Page 21...
# No reviews found on Doha - Page 21
# Scraping Doha - Page 22...
# No reviews found on Doha - Page 22
# Scraping Doha - Page 23...
# No reviews found on Doha - Page 23
# Scraping Doha - Page 24...
# No reviews found on Doha - Page 24
# Scraping Doha - Page 25...
# No reviews found on Doha - Page 25
# Scraping Doha - Page 26...
# No reviews found on Doha - Page 26
# Scraping Doha - Page 27...
# No reviews found on Doha - Page 27
# Scraping Doha - Page 28...
# No reviews found on Doha - Page 28
# Scraping Doha - Page 29...
# No reviews found on Doha - Page 29
# Scraping Doha - Page 30...
# No reviews found on Doha - Page 30
#
# Starting scraping for Abu Dhabi...
# Scraping Abu Dhabi - Page 1...
# No reviews found on Abu Dhabi - Page 1
# Scraping Abu Dhabi - Page 2...
# No reviews found on Abu Dhabi - Page 2
# Scraping Abu Dhabi - Page 3...
# No reviews found on Abu Dhabi - Page 3
# Scraping Abu Dhabi - Page 4...
# No reviews found on Abu Dhabi - Page 4
# Scraping Abu Dhabi - Page 5...
# No reviews found on Abu Dhabi - Page 5
# Scraping Abu Dhabi - Page 6...
# No reviews found on Abu Dhabi - Page 6
# Scraping Abu Dhabi - Page 7...
# No reviews found on Abu Dhabi - Page 7
# Scraping Abu Dhabi - Page 8...
# No reviews found on Abu Dhabi - Page 8
# Scraping Abu Dhabi - Page 9...
# No reviews found on Abu Dhabi - Page 9
# Scraping Abu Dhabi - Page 10...
# No reviews found on Abu Dhabi - Page 10
# Scraping Abu Dhabi - Page 11...
# No reviews found on Abu Dhabi - Page 11
# Scraping Abu Dhabi - Page 12...
# No reviews found on Abu Dhabi - Page 12
# Scraping Abu Dhabi - Page 13...
# No reviews found on Abu Dhabi - Page 13
# Scraping Abu Dhabi - Page 14...
# No reviews found on Abu Dhabi - Page 14
# Scraping Abu Dhabi - Page 15...
# No reviews found on Abu Dhabi - Page 15
# Scraping Abu Dhabi - Page 16...
# No reviews found on Abu Dhabi - Page 16
# Scraping Abu Dhabi - Page 17...
# No reviews found on Abu Dhabi - Page 17
# Scraping Abu Dhabi - Page 18...
# No reviews found on Abu Dhabi - Page 18
# Scraping Abu Dhabi - Page 19...
# No reviews found on Abu Dhabi - Page 19
# Scraping Abu Dhabi - Page 20...
# No reviews found on Abu Dhabi - Page 20
# Scraping Abu Dhabi - Page 21...
# No reviews found on Abu Dhabi - Page 21
# Scraping Abu Dhabi - Page 22...
# No reviews found on Abu Dhabi - Page 22
# Scraping Abu Dhabi - Page 23...
# No reviews found on Abu Dhabi - Page 23
# Scraping Abu Dhabi - Page 24...
# No reviews found on Abu Dhabi - Page 24
# Scraping Abu Dhabi - Page 25...
# No reviews found on Abu Dhabi - Page 25
# Scraping Abu Dhabi - Page 26...
# No reviews found on Abu Dhabi - Page 26
# Scraping Abu Dhabi - Page 27...
# No reviews found on Abu Dhabi - Page 27
# Scraping Abu Dhabi - Page 28...
# No reviews found on Abu Dhabi - Page 28
# Scraping Abu Dhabi - Page 29...
# No reviews found on Abu Dhabi - Page 29
# Scraping Abu Dhabi - Page 30...
# No reviews found on Abu Dhabi - Page 30
#
# Starting scraping for Bangkok...
# Scraping Bangkok - Page 1...
# Failed to fetch data for Bangkok - Page 1
# Scraping Bangkok - Page 2...
# No reviews found on Bangkok - Page 2
# Scraping Bangkok - Page 3...
# No reviews found on Bangkok - Page 3
# Scraping Bangkok - Page 4...
# No reviews found on Bangkok - Page 4
# Scraping Bangkok - Page 5...
# No reviews found on Bangkok - Page 5
# Scraping Bangkok - Page 6...
# No reviews found on Bangkok - Page 6
# Scraping Bangkok - Page 7...
# No reviews found on Bangkok - Page 7
# Scraping Bangkok - Page 8...
# No reviews found on Bangkok - Page 8
# Scraping Bangkok - Page 9...
# No reviews found on Bangkok - Page 9
# Scraping Bangkok - Page 10...
# No reviews found on Bangkok - Page 10
# Scraping Bangkok - Page 11...
# No reviews found on Bangkok - Page 11
# Scraping Bangkok - Page 12...
# No reviews found on Bangkok - Page 12
# Scraping Bangkok - Page 13...
# No reviews found on Bangkok - Page 13
# Scraping Bangkok - Page 14...
# No reviews found on Bangkok - Page 14
# Scraping Bangkok - Page 15...
# No reviews found on Bangkok - Page 15
# Scraping Bangkok - Page 16...
# No reviews found on Bangkok - Page 16
# Scraping Bangkok - Page 17...
# No reviews found on Bangkok - Page 17
# Scraping Bangkok - Page 18...
# No reviews found on Bangkok - Page 18
# Scraping Bangkok - Page 19...
# No reviews found on Bangkok - Page 19
# Scraping Bangkok - Page 20...
# No reviews found on Bangkok - Page 20
# Scraping Bangkok - Page 21...
# No reviews found on Bangkok - Page 21
# Scraping Bangkok - Page 22...
# No reviews found on Bangkok - Page 22
# Scraping Bangkok - Page 23...
# No reviews found on Bangkok - Page 23
# Scraping Bangkok - Page 24...
# No reviews found on Bangkok - Page 24
# Scraping Bangkok - Page 25...
# No reviews found on Bangkok - Page 25
# Scraping Bangkok - Page 26...
# No reviews found on Bangkok - Page 26
# Scraping Bangkok - Page 27...
# No reviews found on Bangkok - Page 27
# Scraping Bangkok - Page 28...
# No reviews found on Bangkok - Page 28
# Scraping Bangkok - Page 29...
# No reviews found on Bangkok - Page 29
# Scraping Bangkok - Page 30...
# No reviews found on Bangkok - Page 30
#
# Starting scraping for Singapore...
# Scraping Singapore - Page 1...
# No reviews found on Singapore - Page 1
# Scraping Singapore - Page 2...
# No reviews found on Singapore - Page 2
# Scraping Singapore - Page 3...
# No reviews found on Singapore - Page 3
# Scraping Singapore - Page 4...
# No reviews found on Singapore - Page 4
# Scraping Singapore - Page 5...
# No reviews found on Singapore - Page 5
# Scraping Singapore - Page 6...
# No reviews found on Singapore - Page 6
# Scraping Singapore - Page 7...
# No reviews found on Singapore - Page 7
# Scraping Singapore - Page 8...
# No reviews found on Singapore - Page 8
# Scraping Singapore - Page 9...
# No reviews found on Singapore - Page 9
# Scraping Singapore - Page 10...
# No reviews found on Singapore - Page 10
# Scraping Singapore - Page 11...
# No reviews found on Singapore - Page 11
# Scraping Singapore - Page 12...
# No reviews found on Singapore - Page 12
# Scraping Singapore - Page 13...
# No reviews found on Singapore - Page 13
# Scraping Singapore - Page 14...
# No reviews found on Singapore - Page 14
# Scraping Singapore - Page 15...
# No reviews found on Singapore - Page 15
# Scraping Singapore - Page 16...
# No reviews found on Singapore - Page 16
# Scraping Singapore - Page 17...
# No reviews found on Singapore - Page 17
# Scraping Singapore - Page 18...
# No reviews found on Singapore - Page 18
# Scraping Singapore - Page 19...
# No reviews found on Singapore - Page 19
# Scraping Singapore - Page 20...
# No reviews found on Singapore - Page 20
# Scraping Singapore - Page 21...
# No reviews found on Singapore - Page 21
# Scraping Singapore - Page 22...
# No reviews found on Singapore - Page 22
# Scraping Singapore - Page 23...
# No reviews found on Singapore - Page 23
# Scraping Singapore - Page 24...
# No reviews found on Singapore - Page 24
# Scraping Singapore - Page 25...
# No reviews found on Singapore - Page 25
# Scraping Singapore - Page 26...
# No reviews found on Singapore - Page 26
# Scraping Singapore - Page 27...
# No reviews found on Singapore - Page 27
# Scraping Singapore - Page 28...
# No reviews found on Singapore - Page 28
# Scraping Singapore - Page 29...
# No reviews found on Singapore - Page 29
# Scraping Singapore - Page 30...
# No reviews found on Singapore - Page 30
#
# Starting scraping for Hong Kong...
# Scraping Hong Kong - Page 1...
# No reviews found on Hong Kong - Page 1
# Scraping Hong Kong - Page 2...
# No reviews found on Hong Kong - Page 2
# Scraping Hong Kong - Page 3...
# No reviews found on Hong Kong - Page 3
# Scraping Hong Kong - Page 4...
# No reviews found on Hong Kong - Page 4
# Scraping Hong Kong - Page 5...
# No reviews found on Hong Kong - Page 5
# Scraping Hong Kong - Page 6...
# No reviews found on Hong Kong - Page 6
# Scraping Hong Kong - Page 7...
# No reviews found on Hong Kong - Page 7
# Scraping Hong Kong - Page 8...
# No reviews found on Hong Kong - Page 8
# Scraping Hong Kong - Page 9...
# No reviews found on Hong Kong - Page 9
# Scraping Hong Kong - Page 10...
# No reviews found on Hong Kong - Page 10
# Scraping Hong Kong - Page 11...
# No reviews found on Hong Kong - Page 11
# Scraping Hong Kong - Page 12...
# No reviews found on Hong Kong - Page 12
# Scraping Hong Kong - Page 13...
# No reviews found on Hong Kong - Page 13
# Scraping Hong Kong - Page 14...
# No reviews found on Hong Kong - Page 14
# Scraping Hong Kong - Page 15...
# No reviews found on Hong Kong - Page 15
# Scraping Hong Kong - Page 16...
# No reviews found on Hong Kong - Page 16
# Scraping Hong Kong - Page 17...
# No reviews found on Hong Kong - Page 17
# Scraping Hong Kong - Page 18...
# No reviews found on Hong Kong - Page 18
# Scraping Hong Kong - Page 19...
# No reviews found on Hong Kong - Page 19
# Scraping Hong Kong - Page 20...
# No reviews found on Hong Kong - Page 20
# Scraping Hong Kong - Page 21...
# No reviews found on Hong Kong - Page 21
# Scraping Hong Kong - Page 22...
# No reviews found on Hong Kong - Page 22
# Scraping Hong Kong - Page 23...
# No reviews found on Hong Kong - Page 23
# Scraping Hong Kong - Page 24...
# No reviews found on Hong Kong - Page 24
# Scraping Hong Kong - Page 25...
# No reviews found on Hong Kong - Page 25
# Scraping Hong Kong - Page 26...
# No reviews found on Hong Kong - Page 26
# Scraping Hong Kong - Page 27...
# No reviews found on Hong Kong - Page 27
# Scraping Hong Kong - Page 28...
# No reviews found on Hong Kong - Page 28
# Scraping Hong Kong - Page 29...
# No reviews found on Hong Kong - Page 29
# Scraping Hong Kong - Page 30...
# No reviews found on Hong Kong - Page 30
#
# Starting scraping for Delhi...
# Scraping Delhi - Page 1...
# Failed to fetch data for Delhi - Page 1
# Scraping Delhi - Page 2...
# No reviews found on Delhi - Page 2
# Scraping Delhi - Page 3...
# No reviews found on Delhi - Page 3
# Scraping Delhi - Page 4...
# No reviews found on Delhi - Page 4
# Scraping Delhi - Page 5...
# No reviews found on Delhi - Page 5
# Scraping Delhi - Page 6...
# No reviews found on Delhi - Page 6
# Scraping Delhi - Page 7...
# No reviews found on Delhi - Page 7
# Scraping Delhi - Page 8...
# No reviews found on Delhi - Page 8
# Scraping Delhi - Page 9...
# No reviews found on Delhi - Page 9
# Scraping Delhi - Page 10...
# No reviews found on Delhi - Page 10
# Scraping Delhi - Page 11...
# No reviews found on Delhi - Page 11
# Scraping Delhi - Page 12...
# No reviews found on Delhi - Page 12
# Scraping Delhi - Page 13...
# No reviews found on Delhi - Page 13
# Scraping Delhi - Page 14...
# No reviews found on Delhi - Page 14
# Scraping Delhi - Page 15...
# No reviews found on Delhi - Page 15
# Scraping Delhi - Page 16...
# No reviews found on Delhi - Page 16
# Scraping Delhi - Page 17...
# No reviews found on Delhi - Page 17
# Scraping Delhi - Page 18...
# No reviews found on Delhi - Page 18
# Scraping Delhi - Page 19...
# No reviews found on Delhi - Page 19
# Scraping Delhi - Page 20...
# No reviews found on Delhi - Page 20
# Scraping Delhi - Page 21...
# No reviews found on Delhi - Page 21
# Scraping Delhi - Page 22...
# No reviews found on Delhi - Page 22
# Scraping Delhi - Page 23...
# No reviews found on Delhi - Page 23
# Scraping Delhi - Page 24...
# No reviews found on Delhi - Page 24
# Scraping Delhi - Page 25...
# No reviews found on Delhi - Page 25
# Scraping Delhi - Page 26...
# No reviews found on Delhi - Page 26
# Scraping Delhi - Page 27...
# No reviews found on Delhi - Page 27
# Scraping Delhi - Page 28...
# No reviews found on Delhi - Page 28
# Scraping Delhi - Page 29...
# No reviews found on Delhi - Page 29
# Scraping Delhi - Page 30...
# No reviews found on Delhi - Page 30
#
# Starting scraping for Mumbai...
# Scraping Mumbai - Page 1...
# Failed to fetch data for Mumbai - Page 1
# Scraping Mumbai - Page 2...
# No reviews found on Mumbai - Page 2
# Scraping Mumbai - Page 3...
# No reviews found on Mumbai - Page 3
# Scraping Mumbai - Page 4...
# No reviews found on Mumbai - Page 4
# Scraping Mumbai - Page 5...
# No reviews found on Mumbai - Page 5
# Scraping Mumbai - Page 6...
# No reviews found on Mumbai - Page 6
# Scraping Mumbai - Page 7...
# No reviews found on Mumbai - Page 7
# Scraping Mumbai - Page 8...
# No reviews found on Mumbai - Page 8
# Scraping Mumbai - Page 9...
# No reviews found on Mumbai - Page 9
# Scraping Mumbai - Page 10...
# No reviews found on Mumbai - Page 10
# Scraping Mumbai - Page 11...
# No reviews found on Mumbai - Page 11
# Scraping Mumbai - Page 12...
# No reviews found on Mumbai - Page 12
# Scraping Mumbai - Page 13...
# No reviews found on Mumbai - Page 13
# Scraping Mumbai - Page 14...
# No reviews found on Mumbai - Page 14
# Scraping Mumbai - Page 15...
# No reviews found on Mumbai - Page 15
# Scraping Mumbai - Page 16...
# No reviews found on Mumbai - Page 16
# Scraping Mumbai - Page 17...
# No reviews found on Mumbai - Page 17
# Scraping Mumbai - Page 18...
# No reviews found on Mumbai - Page 18
# Scraping Mumbai - Page 19...
# No reviews found on Mumbai - Page 19
# Scraping Mumbai - Page 20...
# No reviews found on Mumbai - Page 20
# Scraping Mumbai - Page 21...
# No reviews found on Mumbai - Page 21
# Scraping Mumbai - Page 22...
# No reviews found on Mumbai - Page 22
# Scraping Mumbai - Page 23...
# No reviews found on Mumbai - Page 23
# Scraping Mumbai - Page 24...
# No reviews found on Mumbai - Page 24
# Scraping Mumbai - Page 25...
# No reviews found on Mumbai - Page 25
# Scraping Mumbai - Page 26...
# No reviews found on Mumbai - Page 26
# Scraping Mumbai - Page 27...
# No reviews found on Mumbai - Page 27
# Scraping Mumbai - Page 28...
# No reviews found on Mumbai - Page 28
# Scraping Mumbai - Page 29...
# No reviews found on Mumbai - Page 29
# Scraping Mumbai - Page 30...
# No reviews found on Mumbai - Page 30
#
# Starting scraping for Bangalore...
# Scraping Bangalore - Page 1...
# Failed to fetch data for Bangalore - Page 1
# Scraping Bangalore - Page 2...
# No reviews found on Bangalore - Page 2
# Scraping Bangalore - Page 3...
# No reviews found on Bangalore - Page 3
# Scraping Bangalore - Page 4...
# No reviews found on Bangalore - Page 4
# Scraping Bangalore - Page 5...
# No reviews found on Bangalore - Page 5
# Scraping Bangalore - Page 6...
# No reviews found on Bangalore - Page 6
# Scraping Bangalore - Page 7...
# No reviews found on Bangalore - Page 7
# Scraping Bangalore - Page 8...
# No reviews found on Bangalore - Page 8
# Scraping Bangalore - Page 9...
# No reviews found on Bangalore - Page 9
# Scraping Bangalore - Page 10...
# No reviews found on Bangalore - Page 10
# Scraping Bangalore - Page 11...
# No reviews found on Bangalore - Page 11
# Scraping Bangalore - Page 12...
# No reviews found on Bangalore - Page 12
# Scraping Bangalore - Page 13...
# No reviews found on Bangalore - Page 13
# Scraping Bangalore - Page 14...
# No reviews found on Bangalore - Page 14
# Scraping Bangalore - Page 15...
# No reviews found on Bangalore - Page 15
# Scraping Bangalore - Page 16...
# No reviews found on Bangalore - Page 16
# Scraping Bangalore - Page 17...
# No reviews found on Bangalore - Page 17
# Scraping Bangalore - Page 18...
# No reviews found on Bangalore - Page 18
# Scraping Bangalore - Page 19...
# No reviews found on Bangalore - Page 19
# Scraping Bangalore - Page 20...
# No reviews found on Bangalore - Page 20
# Scraping Bangalore - Page 21...
# No reviews found on Bangalore - Page 21
# Scraping Bangalore - Page 22...
# No reviews found on Bangalore - Page 22
# Scraping Bangalore - Page 23...
# No reviews found on Bangalore - Page 23
# Scraping Bangalore - Page 24...
# No reviews found on Bangalore - Page 24
# Scraping Bangalore - Page 25...
# No reviews found on Bangalore - Page 25
# Scraping Bangalore - Page 26...
# No reviews found on Bangalore - Page 26
# Scraping Bangalore - Page 27...
# No reviews found on Bangalore - Page 27
# Scraping Bangalore - Page 28...
# No reviews found on Bangalore - Page 28
# Scraping Bangalore - Page 29...
# No reviews found on Bangalore - Page 29
# Scraping Bangalore - Page 30...
# No reviews found on Bangalore - Page 30
#
# Starting scraping for Hyderabad...
# Scraping Hyderabad - Page 1...
# Failed to fetch data for Hyderabad - Page 1
# Scraping Hyderabad - Page 2...
# No reviews found on Hyderabad - Page 2
# Scraping Hyderabad - Page 3...
# No reviews found on Hyderabad - Page 3
# Scraping Hyderabad - Page 4...
# No reviews found on Hyderabad - Page 4
# Scraping Hyderabad - Page 5...
# No reviews found on Hyderabad - Page 5
# Scraping Hyderabad - Page 6...
# No reviews found on Hyderabad - Page 6
# Scraping Hyderabad - Page 7...
# No reviews found on Hyderabad - Page 7
# Scraping Hyderabad - Page 8...
# No reviews found on Hyderabad - Page 8
# Scraping Hyderabad - Page 9...
# No reviews found on Hyderabad - Page 9
# Scraping Hyderabad - Page 10...
# No reviews found on Hyderabad - Page 10
# Scraping Hyderabad - Page 11...
# No reviews found on Hyderabad - Page 11
# Scraping Hyderabad - Page 12...
# No reviews found on Hyderabad - Page 12
# Scraping Hyderabad - Page 13...
# No reviews found on Hyderabad - Page 13
# Scraping Hyderabad - Page 14...
# No reviews found on Hyderabad - Page 14
# Scraping Hyderabad - Page 15...
# No reviews found on Hyderabad - Page 15
# Scraping Hyderabad - Page 16...
# No reviews found on Hyderabad - Page 16
# Scraping Hyderabad - Page 17...
# No reviews found on Hyderabad - Page 17
# Scraping Hyderabad - Page 18...
# No reviews found on Hyderabad - Page 18
# Scraping Hyderabad - Page 19...
# No reviews found on Hyderabad - Page 19
# Scraping Hyderabad - Page 20...
# No reviews found on Hyderabad - Page 20
# Scraping Hyderabad - Page 21...
# No reviews found on Hyderabad - Page 21
# Scraping Hyderabad - Page 22...
# No reviews found on Hyderabad - Page 22
# Scraping Hyderabad - Page 23...
# No reviews found on Hyderabad - Page 23
# Scraping Hyderabad - Page 24...
# No reviews found on Hyderabad - Page 24
# Scraping Hyderabad - Page 25...
# No reviews found on Hyderabad - Page 25
# Scraping Hyderabad - Page 26...
# No reviews found on Hyderabad - Page 26
# Scraping Hyderabad - Page 27...
# No reviews found on Hyderabad - Page 27
# Scraping Hyderabad - Page 28...
# No reviews found on Hyderabad - Page 28
# Scraping Hyderabad - Page 29...
# No reviews found on Hyderabad - Page 29
# Scraping Hyderabad - Page 30...
# No reviews found on Hyderabad - Page 30
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.to_csv("airport_reviews.csv", index=False)
print("\nScraping complete! Data saved to airport_reviews.csv")
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import requests
from bs4 import BeautifulSoup
import time

# Define base URL (Example for one airport)
airport_url = "https://www.airlinequality.com/airport-reviews/istanbul-airport/page/2/"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/133.0.0.0 Safari/537.36 Edg/133.0.0.0"
}

# Send request
response = requests.get(airport_url, headers=headers)

# Check response status
if response.status_code == 200:
    print("\n✅ Successfully fetched the page!")
else:
    print(f"\n❌ Failed to fetch the page. Status Code: {response.status_code}")
    exit()

# Parse HTML
soup = BeautifulSoup(response.text, "html.parser")

# Print full HTML to check structure (Use only for debugging)
print("\n🔍 Full Page HTML:\n")
print(soup.prettify())  # Prints the entire page content

# Find all reviews
review_containers = soup.find_all("article", class_="comp compo_reviews_review")

# Check if reviews were found
if not review_containers:
    print("\n❌ No reviews found on the page. Check class name or site structure!")
    exit()

# Extract first review for testing
first_review = review_containers[0]  # Get the first review

# Extract review text
review_text = first_review.find("div", class_="text_content")
review_text = review_text.text.strip() if review_text else "No review text found"

# Print extracted review content
print("\n✅ First Review Extracted:\n")
print(review_text)
# Out:
# ✅ Successfully fetched the page!
#
# 🔍 Full Page HTML:
#
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js lt-ie9 lt-ie8 lt-ie7 lt-ie10" lang="en-GB"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js lt-ie9 lt-ie8 lt-ie10" lang="en-GB"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js lt-ie9 lt-ie10" lang="en-GB"> <![endif]-->
# <!--[if IE 9]>    <html class="no-js lt-ie10" lang="en-GB"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html lang="en-GB">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Istanbul Airport Customer Reviews - SKYTRAX
#   </title>
#   <link as="image" data-rocket-preload="" fetchpriority="high" href="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/images/nav/grad-header.jpg" rel="preload"/>
#   <!-- Google Chrome Frame for IE -->
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <!-- mobile meta -->
#   <meta content="True" name="HandheldFriendly"/>
#   <meta content="320" name="MobileOptimized"/>
#   <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport">
#    <!-- icons & favicons -->
#    <link href="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/images/apple-icon-touch.png" rel="apple-touch-icon"/>
#    <link href="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/favicon.png" rel="icon"/>
#    <!--[if IE]>
# 			<link rel="shortcut icon" href="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/favicon.ico">
# 		<![endif]-->
#    <meta content="#f01d4f" name="msapplication-TileColor"/>
#    <meta content="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/images/win8-tile-icon.png" name="msapplication-TileImage"/>
#    <link href="https://www.airlinequality.com/xmlrpc.php" rel="pingback"/>
#    <link href="https://fonts.googleapis.com/css?family=Source+Sans+Pro" rel="stylesheet"/>
#    <link href="https://fonts.googleapis.com/css?family=Montserrat:300,300i,500,700|Playfair+Display:400i,900" rel="stylesheet"/>
#    <script data-rocket-defer="" defer="" src="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/static_homepage_assets/js/static/modernizr-2.6.2.min.js">
#    </script>
#    <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots">
#     <style>
#      img:is([sizes="auto" i], [sizes^="auto," i]) { contain-intrinsic-size: 3000px 1500px }
#     </style>
#     <!-- This site is optimized with the Yoast SEO plugin v24.4 - https://yoast.com/wordpress/plugins/seo/ -->
#     <title>
#      Istanbul Airport Customer Reviews - SKYTRAX
#     </title>
#     <meta content="The latest Istanbul Airport customer reviews, Istanbul Airport Quality ratings and Istanbul Airport passenger opinions about Istanbul Airport standards" name="description">
#      <link href="https://www.airlinequality.com/airport-reviews/istanbul-airport/" rel="canonical">
#       <link href="https://www.airlinequality.com/airport-reviews/istanbul-airport/page/2/" rel="next">
#        <meta content="en_GB" property="og:locale">
#         <meta content="website" property="og:type">
#          <meta content="Customer Reviews - SKYTRAX" property="og:title">
#           <meta content="The latest [name] customer reviews, [name] Quality ratings and [name] passenger opinions about [name] standards" property="og:description"/>
#           <meta content="https://www.airlinequality.com/review_airline/" property="og:url"/>
#           <meta content="SKYTRAX" property="og:site_name"/>
#           <script class="yoast-schema-graph" type="application/ld+json">
#            {"@context":"https://schema.org","@graph":[{"@type":"CollectionPage","@id":"https://www.airlinequality.com/review_airline/","url":"https://www.airlinequality.com/review_airline/","name":"Customer Reviews - SKYTRAX","isPartOf":{"@id":"https://www.airlinequality.com/#website"},"description":"The latest [name] customer reviews, [name] Quality ratings and [name] passenger opinions about [name] standards","breadcrumb":{"@id":"https://www.airlinequality.com/review_airline/#breadcrumb"},"inLanguage":"en-GB"},{"@type":"BreadcrumbList","@id":"https://www.airlinequality.com/review_airline/#breadcrumb","itemListElement":[{"@type":"ListItem","position":1,"name":"Home","item":"https://www.airlinequality.com/"},{"@type":"ListItem","position":2,"name":"Airport Reviews"}]},{"@type":"WebSite","@id":"https://www.airlinequality.com/#website","url":"https://www.airlinequality.com/","name":"SKYTRAX","description":"Air Travel Ratings &amp; Reviews | Airline Rating and Reviews | Airport Rating and Reviews | Seat Reviews","potentialAction":[{"@type":"SearchAction","target":{"@type":"EntryPoint","urlTemplate":"https://www.airlinequality.com/?s={search_term_string}"},"query-input":{"@type":"PropertyValueSpecification","valueRequired":true,"valueName":"search_term_string"}}],"inLanguage":"en-GB"}]}
#           </script>
#           <!-- / Yoast SEO plugin. -->
#           <link href="//cdn.jsdelivr.net" rel="dns-prefetch">
#            <link href="https://www.airlinequality.com/wp-content/plugins/wp-google-search/wgs.css" id="wgs-css" media="all" rel="stylesheet" type="text/css">
#             <link href="https://www.airlinequality.com/wp-content/plugins/wp-google-search/wgs2.css" id="wgs2-css" media="all" rel="stylesheet" type="text/css">
#              <style id="wp-emoji-styles-inline-css" type="text/css">
#               img.wp-smiley, img.emoji {
# 		display: inline !important;
# 		border: none !important;
# 		box-shadow: none !important;
# 		height: 1em !important;
# 		width: 1em !important;
# 		margin: 0 0.07em !important;
# 		vertical-align: -0.1em !important;
# 		background: none !important;
# 		padding: 0 !important;
# 	}
#              </style>
#              <link href="https://www.airlinequality.com/wp-includes/css/dist/block-library/style.min.css" id="wp-block-library-css" media="all" rel="stylesheet" type="text/css">
#               <style id="classic-theme-styles-inline-css" type="text/css">
#                /*! This file is auto-generated */
# .wp-block-button__link{color:#fff;background-color:#32373c;border-radius:9999px;box-shadow:none;text-decoration:none;padding:calc(.667em + 2px) calc(1.333em + 2px);font-size:1.125em}.wp-block-file__button{background:#32373c;color:#fff;text-decoration:none}
#               </style>
#               <style id="global-styles-inline-css" type="text/css">
#                :root{--wp--preset--aspect-ratio--square: 1;--wp--preset--aspect-ratio--4-3: 4/3;--wp--preset--aspect-ratio--3-4: 3/4;--wp--preset--aspect-ratio--3-2: 3/2;--wp--preset--aspect-ratio--2-3: 2/3;--wp--preset--aspect-ratio--16-9: 16/9;--wp--preset--aspect-ratio--9-16: 9/16;--wp--preset--color--black: #000000;--wp--preset--color--cyan-bluish-gray: #abb8c3;--wp--preset--color--white: #ffffff;--wp--preset--color--pale-pink: #f78da7;--wp--preset--color--vivid-red: #cf2e2e;--wp--preset--color--luminous-vivid-orange: #ff6900;--wp--preset--color--luminous-vivid-amber: #fcb900;--wp--preset--color--light-green-cyan: #7bdcb5;--wp--preset--color--vivid-green-cyan: #00d084;--wp--preset--color--pale-cyan-blue: #8ed1fc;--wp--preset--color--vivid-cyan-blue: #0693e3;--wp--preset--color--vivid-purple: #9b51e0;--wp--preset--gradient--vivid-cyan-blue-to-vivid-purple: linear-gradient(135deg,rgba(6,147,227,1) 0%,rgb(155,81,224) 100%);--wp--preset--gradient--light-green-cyan-to-vivid-green-cyan: linear-gradient(135deg,rgb(122,220,180) 0%,rgb(0,208,130) 100%);--wp--preset--gradient--luminous-vivid-amber-to-luminous-vivid-orange: linear-gradient(135deg,rgba(252,185,0,1) 0%,rgba(255,105,0,1) 100%);--wp--preset--gradient--luminous-vivid-orange-to-vivid-red: linear-gradient(135deg,rgba(255,105,0,1) 0%,rgb(207,46,46) 100%);--wp--preset--gradient--very-light-gray-to-cyan-bluish-gray: linear-gradient(135deg,rgb(238,238,238) 0%,rgb(169,184,195) 100%);--wp--preset--gradient--cool-to-warm-spectrum: linear-gradient(135deg,rgb(74,234,220) 0%,rgb(151,120,209) 20%,rgb(207,42,186) 40%,rgb(238,44,130) 60%,rgb(251,105,98) 80%,rgb(254,248,76) 100%);--wp--preset--gradient--blush-light-purple: linear-gradient(135deg,rgb(255,206,236) 0%,rgb(152,150,240) 100%);--wp--preset--gradient--blush-bordeaux: linear-gradient(135deg,rgb(254,205,165) 0%,rgb(254,45,45) 50%,rgb(107,0,62) 100%);--wp--preset--gradient--luminous-dusk: linear-gradient(135deg,rgb(255,203,112) 0%,rgb(199,81,192) 50%,rgb(65,88,208) 100%);--wp--preset--gradient--pale-ocean: linear-gradient(135deg,rgb(255,245,203) 0%,rgb(182,227,212) 50%,rgb(51,167,181) 100%);--wp--preset--gradient--electric-grass: linear-gradient(135deg,rgb(202,248,128) 0%,rgb(113,206,126) 100%);--wp--preset--gradient--midnight: linear-gradient(135deg,rgb(2,3,129) 0%,rgb(40,116,252) 100%);--wp--preset--font-size--small: 13px;--wp--preset--font-size--medium: 20px;--wp--preset--font-size--large: 36px;--wp--preset--font-size--x-large: 42px;--wp--preset--spacing--20: 0.44rem;--wp--preset--spacing--30: 0.67rem;--wp--preset--spacing--40: 1rem;--wp--preset--spacing--50: 1.5rem;--wp--preset--spacing--60: 2.25rem;--wp--preset--spacing--70: 3.38rem;--wp--preset--spacing--80: 5.06rem;--wp--preset--shadow--natural: 6px 6px 9px rgba(0, 0, 0, 0.2);--wp--preset--shadow--deep: 12px 12px 50px rgba(0, 0, 0, 0.4);--wp--preset--shadow--sharp: 6px 6px 0px rgba(0, 0, 0, 0.2);--wp--preset--shadow--outlined: 6px 6px 0px -3px rgba(255, 255, 255, 1), 6px 6px rgba(0, 0, 0, 1);--wp--preset--shadow--crisp: 6px 6px 0px rgba(0, 0, 0, 1);}:where(.is-layout-flex){gap: 0.5em;}:where(.is-layout-grid){gap: 0.5em;}body .is-layout-flex{display: flex;}.is-layout-flex{flex-wrap: wrap;align-items: center;}.is-layout-flex > :is(*, div){margin: 0;}body .is-layout-grid{display: grid;}.is-layout-grid > :is(*, div){margin: 0;}:where(.wp-block-columns.is-layout-flex){gap: 2em;}:where(.wp-block-columns.is-layout-grid){gap: 2em;}:where(.wp-block-post-template.is-layout-flex){gap: 1.25em;}:where(.wp-block-post-template.is-layout-grid){gap: 1.25em;}.has-black-color{color: var(--wp--preset--color--black) !important;}.has-cyan-bluish-gray-color{color: var(--wp--preset--color--cyan-bluish-gray) !important;}.has-white-color{color: var(--wp--preset--color--white) !important;}.has-pale-pink-color{color: var(--wp--preset--color--pale-pink) !important;}.has-vivid-red-color{color: var(--wp--preset--color--vivid-red) !important;}.has-luminous-vivid-orange-color{color: var(--wp--preset--color ...
# :where(.wp-block-post-template.is-layout-flex){gap: 1.25em;}:where(.wp-block-post-template.is-layout-grid){gap: 1.25em;}
# :where(.wp-block-columns.is-layout-flex){gap: 2em;}:where(.wp-block-columns.is-layout-grid){gap: 2em;}
# :root :where(.wp-block-pullquote){font-size: 1.5em;line-height: 1.6;}
#               </style>
#               <link href="https://www.airlinequality.com/wp-content/plugins/wp-members/assets/css/forms/generic-no-float.min.css" id="wp-members-css" media="all" rel="stylesheet" type="text/css"/>
#               <link href="https://www.airlinequality.com/wp-content/tablepress-combined.min.css" id="tablepress-default-css" media="all" rel="stylesheet" type="text/css"/>
#               <link href="//cdn.jsdelivr.net/jquery.slick/1.3.11/slick.css" id="slick-css" media="all" rel="stylesheet" type="text/css"/>
#               <link href="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/css/style.css" id="joints-stylesheet-css" media="all" rel="stylesheet" type="text/css"/>
#               <link href="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/css/icons/foundation-icons.css" id="foundation-icons-css" media="all" rel="stylesheet" type="text/css"/>
#               <script id="jquery-js" src="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/js/vendor/jquery.js" type="text/javascript">
#               </script>
#               <script data-rocket-defer="" defer="" id="modernizr-js" src="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/js/vendor/modernizr.js" type="text/javascript">
#               </script>
#               <script data-rocket-defer="" defer="" id="picturefill-js" src="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/js/vendor/picturefill.min.js" type="text/javascript">
#               </script>
#               <link href="https://www.airlinequality.com/wp-json/" rel="https://api.w.org/"/>
#               <link href="https://www.airlinequality.com/wp-content/plugins/gendall-default/img/favicon.png" rel="icon" type="image/png"/>
#               <style id="wp-custom-css" type="text/css">
#                .home #main > section.layout-section.layout-2.border-top > div.col-content > div:nth-child(3), .home #main > section.layout-section.layout-2.border-top > div.col-content > div:nth-child(4) > section {
# 	display:none;
# }
#
# .captcha {
# 	float: none;
# 	text-align: left;
# 	margin-bottom: 20px;
# }
#
# #main > section .accordion-toggle {
# 	color: #f78152;
# 	background: none;
# 	font-size: 16px;
# 	margin: 10px 0 0 21px;
# }
# #main > section .accordion-toggle:hover {
# 	background: transparent;
# }
# #main > section .accordion-toggle .arrow-down {
# 	border-color: #f78152 transparent transparent transparent;
#
# }
#
# .home .button:not(.button-hero):not(.button-inverted), .new-button {
#   font-weight: 700;
#   padding: 0.67143em 0.87566em;
#   transition: background, color;
#   transition-duration: .2s;
#   cursor: pointer;
#   background: #0192d1;
#   display: block;
#   font-size: 1em;
#   text-decoration: none;
#   text-align: center;
#   padding: 12px 45px;
#   border: 2px solid #0192d1;
#   line-height: 1;
#   color: #ffffff; }
#   .home .button:not(.button-hero):not(.button-inverted):focus, .new-button:focus {
#     outline: none;
#     box-shadow: inset #77b255 0 0 0 0.2em; }
#   .home .button:not(.button-hero):not(.button-inverted):hover, .new-button:hover {
# 		text-decoration: none;
#     background: #ff6e3b;
#     border-color: #ff6e3b; }
#   .home .button:not(.button-hero):not(.button-inverted).cta {
#     border-radius: 0.13646em; }
#   .home .button:not(.button-hero):not(.button-inverted).submit-search {
#     padding: 0.87566em 2.89287em; }
#   .home .button:not(.button-hero):not(.button-inverted).centered {
#     width: 14em;
#     padding-right: 1.142em;
#     padding-left: 1.142em;
#     margin: 0 auto; }
#
# @media screen and (min-width: 700px) {
#     .new-button {
#       display: inline-block;
# 			font-size: 14px;
#     }
# }
#
#
# .home .button.button-inverted, .new-button.button-inverted {
#       background: #fff;
#       border: 2px solid #0192d1;
#       padding: 12px 45px;
#       color: #0192d1;
# }
#
# .home .button.button-inverted:hover, .new-button.button-inverted:hover {
#   background: #0192d1;
#   color: #fff;
# }
#
# @media screen and (min-width: 768px) {
# 	.new-buttons {
# 			margin-left: calc(1.1rem + 88px);
# 	}
# }
#
# .termly-styles-consent-banner-d8e726 .termly-styles-main-bdb6e9 p,
# .tcfConsentSettings .tcfCategoriesTabContent .consentSettingsRowContainer div {
# 	color: #fff;
# }
#               </style>
#               <script data-rocket-defer="" defer="" src="https://www.google.com/jsapi" type="text/javascript">
#               </script>
#               <script type="text/javascript">
#                google.load("search", "1");
#
#     // Call this function when the page has been loaded
#     function initialize() {
#         var searchControl = new google.search.SearchControl();
#         searchControl.addSearcher(new google.search.WebSearch());
#         searchControl.addSearcher(new google.search.NewsSearch());
#         searchControl.draw(document.getElementById("searchcontrol"));
#     }
#     google.setOnLoadCallback(initialize);
#               </script>
#               <script src="https://www.google.com/recaptcha/api.js">
#               </script>
#               <script>
#                (adsbygoogle = window.adsbygoogle || []).push({
#
#         google_ad_client: "ca-pub-7401091822721150",
#
#         enable_page_level_ads: true
#
#     });
#               </script>
#               <style id="rocket-lazyrender-inline-css">
#                [data-wpr-lazyrender] {content-visibility: auto;}
#               </style>
#               <meta content="WP Rocket 3.18.1.5" data-wpr-features="wpr_defer_js wpr_automatic_lazy_rendering wpr_oci wpr_desktop wpr_dns_prefetch" name="generator"/>
#              </link>
#             </link>
#            </link>
#           </link>
#          </meta>
#         </meta>
#        </meta>
#       </link>
#      </link>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body class="archive post-type-archive post-type-archive-review_airport paged-2 post-type-paged-2 js-legacy-header" data-rsssl="1">
#   <!--
# <div class="off-canvas-wrap" data-offcanvas>
#     <div class="inner-wrap">
# -->
#   <div id="container">
#    <header class="header header--legacy" role="banner">
#     <div id="inner-header">
#      <div class="top" id="mainMenu">
#       <div class="brand-logo">
#        <a href="https://www.airlinequality.com" rel="nofollow">
#         <img alt="SKYTRAX" onerror="this.src='https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/images/skytrax.png'" src="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/images/skytrax.svg"/>
#        </a>
#        <small>
#         Air Travel Ratings &amp; Reviews | Airline Rating and Reviews | Airport Rating and Reviews | Seat Reviews
#        </small>
#       </div>
#       <div class="menu-container">
#        <div class="gcs-input nav-search">
#         <div class="gcs-input">
#          <form action="/search " class="custom_search_form custom_search_form_header">
#           <input class="custom_search_form_input" dir="ltr" id="" name="search" placeholder="" spellcheck="false" title="search" type="text" value=""/>
#           <input class="custom_search_form_button desktop-search-button" title="search" type="submit" value="Search"/>
#           <button aria-label="Submit Search" class="button button-hero submit-search uppercase display text-heavy mobile-search-button">
#            <svg class="button-icon">
#             <use xlink:href="#search">
#             </use>
#            </svg>
#           </button>
#          </form>
#         </div>
#        </div>
#        <nav class="nav-user">
#         <ul class="sub-nav">
#          <li>
#           <a href="https://www.airlinequality.com/sign-in">
#            Log In
#           </a>
#          </li>
#          <li>
#           <a href="https://www.airlinequality.com/reviewer/reviewer-signup">
#            Join
#           </a>
#          </li>
#         </ul>
#        </nav>
#       </div>
#      </div>
#      <a class="menu-toggle" href="#mainMenu">
#       <span>
#        Menu
#       </span>
#      </a>
#      <div class="bottom">
#       <!-- Darren changed 2016-12-07 -->
#       <div class="nav-main-outer">
#        <div class="nav-main">
#         <nav class="top-bar" data-options="is_hover: true" data-topbar="">
#          <section class="top-bar-section nav__main">
#           <div class="top-bar top-bar-section">
#            <ul class="menu-class" id="menu-primary-site-navigation">
#             <li class="airline-reviews has-dropdown not-click">
#              <a href="#" target="">
#               Airline Reviews
#              </a>
#              <div class="dropdown">
#               <div class="nav-links">
#                <ul class="nav-links__list">
#                 <li class="airline-reviews navSectionTitle not-click">
#                  <a href="#" target="">
#                   Airline Reviews
#                  </a>
#                 </li>
#                 <li class="latest-airline-reviews not-click">
#                  <a href="https://www.airlinequality.com/review-pages/latest-airline-reviews/" target="">
#                   Latest Airline Reviews
#                  </a>
#                 </li>
#                 <li class="a-z-airline-reviews not-click">
#                  <a href="https://www.airlinequality.com/review-pages/a-z-airline-reviews/" target="">
#                   A-Z Airline Reviews
#                  </a>
#                 </li>
#                 <li class="airline-review-scores not-click">
#                  <a href="https://www.airlinequality.com/review-pages/a-z-airline-reviews/airline-review-ratings/" target="">
#                   Airline Review Scores
#                  </a>
#                 </li>
#                 <li class="a-z-airline-photos not-click">
#                  <a href="https://www.airlinequality.com/review-pages/a-z-airline-photos/" target="">
#                   A-Z Airline Photos
#                  </a>
#                 </li>
#                 <li class="airline-lounges navSectionTitle not-click">
#                  <a href="#" target="">
#                   Airline Lounges
#                  </a>
#                 </li>
#                 <li class="latest-lounge-reviews not-click">
#                  <a href="https://www.airlinequality.com/review-pages/latest-lounge-reviews/" target="">
#                   Latest Lounge Reviews
#                  </a>
#                 </li>
#                 <li class="a-z-airline-lounge-reviews not-click">
#                  <a href="https://www.airlinequality.com/review-pages/a-z-lounge-reviews/" target="">
#                   A-Z Airline Lounge Reviews
#                  </a>
#                 </li>
#                 <li class="lounge-photo-galleries not-click">
#                  <a href="https://www.airlinequality.com/info/lounge-photo-galleries/" target="">
#                   Lounge Photo Galleries
#                  </a>
#                 </li>
#                 <li class="airline-lounge-scores not-click">
#                  <a href="https://www.airlinequality.com/review-pages/a-z-lounge-reviews/airline-lounge-review-ratings/" target="">
#                   Airline Lounge Scores
#                  </a>
#                 </li>
#                 <li class="a-z-lounge-photos not-click">
#                  <a href="https://www.airlinequality.com/review-pages/a-z-lounge-photos/" target="">
#                   A-Z Lounge Photos
#                  </a>
#                 </li>
#                </ul>
#                <ul class="nav-links__list">
#                 <li class="seperator">
#                 </li>
#                 <li class="airline-seats navSectionTitle not-click">
#                  <a href="#" target="">
#                   Airline Seats
#                  </a>
#                 </li>
#                 <li class="latest-seat-reviews not-click">
#                  <a href="https://www.airlinequality.com/review-pages/latest-seat-reviews/" target="">
#                   Latest Seat Reviews
#                  </a>
#                 </li>
#                 <li class="a-z-airline-seat-reviews not-click">
#                  <a href="https://www.airlinequality.com/review-pages/a-z-seat-reviews/" target="">
#                   A-Z Airline Seat Reviews
#                  </a>
#                 </li>
#                 <li class="airline-seat-scores not-click">
#                  <a href="https://www.airlinequality.com/review-pages/a-z-seat-reviews/airline-seat-review-ratings/" target="">
#                   Airline Seat Scores
#                  </a>
#                 </li>
#                 <li class="a-z-seat-photos not-click">
#                  <a href="https://www.airlinequality.com/review-pages/a-z-seat-photos/" target="">
#                   A-Z Seat Photos
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </div>
#             </li>
#             <li class="airport-reviews has-dropdown not-click">
#              <a href="#" target="">
#               Airport Reviews
#              </a>
#              <div class="dropdown">
#               <div class="nav-links">
#                <ul class="nav-links__list">
#                 <li class="airport-reviews navSectionTitle not-click">
#                  <a href="#" target="">
#                   Airport Reviews
#                  </a>
#                 </li>
#                 <li class="latest-airport-reviews not-click">
#                  <a href="https://www.airlinequality.com/review-pages/latest-airport-reviews/" target="">
#                   Latest Airport Reviews
#                  </a>
#                 </li>
#                 <li class="a-z-airport-reviews not-click">
#                  <a href="https://www.airlinequality.com/review-pages/a-z-airport-reviews/" target="">
#                   A-Z Airport Reviews
#                  </a>
#                 </li>
#                 <li class="airport-review-scores not-click">
#                  <a href="https://www.airlinequality.com/review-pages/a-z-airport-reviews/airport-review-ratings/" target="">
#                   Airport Review Scores
#                  </a>
#                 </li>
#                 <li class="a-z-airport-photos not-click">
#                  <a href="https://www.airlinequality.com/review-pages/a-z-airport-photos/" target="">
#                   A-Z Airport Photos
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </div>
#             </li>
#             <li class="write-a-review not-click">
#              <a href="https://www.airlinequality.com/write-a-review/" target="">
#               Write A Review
#              </a>
#             </li>
#             <li class="airport-airline-rating has-dropdown not-click">
#              <a href="#" target="">
#               Airport &amp; Airline Rating
#              </a>
#              <div class="dropdown">
#               <div class="nav-links">
#                <ul class="nav-links__list">
#                 <li class="airline-rating navSectionTitle not-click">
#                  <a href="#" target="">
#                   Airline Rating
#                  </a>
#                 </li>
#                 <li class="a-z-airline-ratings not-click">
#                  <a href="https://skytraxratings.com/a-z-of-airline-ratings" target="_blank">
#                   A-Z Airline Ratings
#                  </a>
#                 </li>
#                 <li class="5-star-airlines not-click">
#                  <a href="https://skytraxratings.com/worlds-5-star-airlines" target="_blank">
#                   5-Star Airlines
#                  </a>
#                 </li>
#                </ul>
#                <ul class="nav-links__list">
#                 <li class="seperator">
#                 </li>
#                 <li class="airport-rating navSectionTitle not-click">
#                  <a href="#" target="">
#                   Airport Rating
#                  </a>
#                 </li>
#                 <li class="a-z-airport-ratings not-click">
#                  <a href="https://skytraxratings.com/a-z-of-airport-ratings" target="_blank">
#                   A-Z Airport Ratings
#                  </a>
#                 </li>
#                 <li class="5-star-airports not-click">
#                  <a href="https://skytraxratings.com/airports?stars=5" target="_blank">
#                   5-Star Airports
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </div>
#             </li>
#             <li class="skytrax-awards has-dropdown not-click">
#              <a href="#" target="">
#               Skytrax Awards
#              </a>
#              <div class="dropdown">
#               <div class="nav-links">
#                <ul class="nav-links__list">
#                 <li class="airline-awards navSectionTitle not-click">
#                  <a href="#" target="">
#                   Airline Awards
#                  </a>
#                 </li>
#                 <li class="worlds-best-airline not-click">
#                  <a href="https://www.worldairlineawards.com/worlds-top-10-airlines-2023/" target="_blank">
#                   World's Best Airline
#                  </a>
#                 </li>
#                 <li class="worlds-top-100-airlines not-click">
#                  <a href="https://www.worldairlineawards.com/worlds-top-100-airlines-2023/" target="_blank">
#                   World's Top 100 Airlines
#                  </a>
#                 </li>
#                 <li class="about-the-awards not-click">
#                  <a href="https://www.worldairlineawards.com/about-us/" target="_blank">
#                   About the Awards
#                  </a>
#                 </li>
#                </ul>
#                <ul class="nav-links__list">
#                 <li class="seperator">
#                 </li>
#                 <li class="airport-awards navSectionTitle not-click">
#                  <a href="#" target="">
#                   Airport Awards
#                  </a>
#                 </li>
#                 <li class="worlds-best-airport not-click">
#                  <a href="https://www.worldairportawards.com/the-worlds-top-10-airports-of-2023/" target="_blank">
#                   World's Best Airport
#                  </a>
#                 </li>
#                 <li class="worlds-top-100-airports not-click">
#                  <a href="https://www.worldairportawards.com/worlds-top-100-airports-2023/" target="_blank">
#                   World's Top 100 Airports
#                  </a>
#                 </li>
#                 <li class="about-the-awards not-click">
#                  <a href="https://www.worldairportawards.com/about-us/" target="_blank">
#                   About the Awards
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </div>
#             </li>
#             <li class="information has-dropdown not-click">
#              <a href="#" target="">
#               Information
#              </a>
#              <div class="dropdown">
#               <div class="nav-links">
#                <ul class="nav-links__list">
#                 <li class="information navSectionTitle not-click">
#                  <a href="#" target="">
#                   Information
#                  </a>
#                 </li>
#                 <li class="about-us not-click">
#                  <a href="https://www.airlinequality.com/about-us/" target="">
#                   About Us
#                  </a>
#                 </li>
#                 <li class="site-map not-click">
#                  <a href="https://www.airlinequality.com/site-map/" target="">
#                   Site Map
#                  </a>
#                 </li>
#                </ul>
#                <ul class="nav-links__list">
#                 <li class="seperator">
#                 </li>
#                 <li class="help-support navSectionTitle not-click">
#                  <a href="#" target="">
#                   Help &amp; Support
#                  </a>
#                 </li>
#                 <li class="contact-us not-click">
#                  <a href="https://www.airlinequality.com/contact-us/" target="">
#                   Contact Us
#                  </a>
#                 </li>
#                 <li class="faqs not-click">
#                  <a href="https://www.airlinequality.com/info/support/" target="">
#                   FAQs
#                  </a>
#                 </li>
#                 <li class="register-as-a-member not-click">
#                  <a href="https://www.airlinequality.com/info/reviewer-signup/" target="">
#                   Register as a Member
#                  </a>
#                 </li>
#                 <li class="editorial-policy not-click">
#                  <a href="https://www.airlinequality.com/info/editorial-policy/" target="">
#                   Editorial Policy
#                  </a>
#                 </li>
#                 <li class="respond-to-reviews not-click">
#                  <a href="https://www.airlinequality.com/info/skychat/" target="">
#                   Respond to Reviews
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </div>
#             </li>
#            </ul>
#           </div>
#          </section>
#         </nav>
#        </div>
#       </div>
#       <div class="ds-search-outer">
#        <div class="ds-search">
#         <div class="gcs-input nav-search">
#          <div class="gcs-input">
#           <form action="/search " class="custom_search_form custom_search_form_header">
#            <input class="custom_search_form_input" dir="ltr" id="" name="search" placeholder="" spellcheck="false" title="search" type="text" value=""/>
#            <input class="custom_search_form_button desktop-search-button" title="search" type="submit" value="Search"/>
#            <button aria-label="Submit Search" class="button button-hero submit-search uppercase display text-heavy mobile-search-button">
#             <svg class="button-icon">
#              <use xlink:href="#search">
#              </use>
#             </svg>
#            </button>
#           </form>
#          </div>
#         </div>
#        </div>
#       </div>
#       <!-- Darren changed 2016-12-07 -->
#      </div>
#     </div>
#     <div class="dummyheader">
#      <div class="top">
#       <div class="brand-logo">
#        <a href="https://www.airlinequality.com" rel="nofollow">
#         <img alt="SKYTRAX" onerror="this.src='https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/images/skytrax.png'" src="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/images/skytrax.svg"/>
#        </a>
#       </div>
#      </div>
#      <a class="menu-toggle" href="#mainMenu">
#       <span>
#        Menu
#       </span>
#      </a>
#     </div>
#    </header>
#    <div id="content" itemscope="" itemtype="http://schema.org/Airline">
#     <div class="clearfix" id="inner-content">
#      <div id="main" role="main">
#       <section class="layout-section layout-1">
#        <div class="col-content">
#         <section class="comp_review-header">
#          <div class="review-ad">
#           <div class="aq-ad">
#            <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#            </script>
#            <ins class="adsbygoogle" data-ad-client="ca-pub-7401091822721150" data-ad-format="auto" data-ad-slot="8663246558" style="display:block;">
#            </ins>
#            <script>
#             (adsbygoogle = window.adsbygoogle || []).push({});
#            </script>
#           </div>
#          </div>
#          <div class="review-info">
#           <div class="review-heading">
#            <div class="info">
#             <div class="logo">
#             </div>
#             <h1 itemprop="name">
#              Istanbul Airport
#             </h1>
#             <h2>
#              Customer Reviews
#             </h2>
#            </div>
#            <div class="rating">
#             <img alt="5 star Skytrax Rating" class="skytrax-rating" srcset="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/images/skytrax-rating-airport-5.png 1x, https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/images/skytrax-rating-airport-5x2.png 2x"/>
#            </div>
#           </div>
#           <div class="customer-rating">
#            <div class="ratings">
#             <table class="review-ratings">
#              <tr>
#               <td class="review-rating-header terminal-seating">
#                Terminal Seating
#               </td>
#               <td class="review-rating-stars stars">
#                <span class="star fill">
#                 1
#                </span>
#                <span class="star fill">
#                 2
#                </span>
#                <span class="star">
#                 3
#                </span>
#                <span class="star">
#                 4
#                </span>
#                <span class="star">
#                 5
#                </span>
#               </td>
#              </tr>
#              <tr>
#               <td class="review-rating-header terminal-cleanliness">
#                Terminal Cleanliness
#               </td>
#               <td class="review-rating-stars stars">
#                <span class="star fill">
#                 1
#                </span>
#                <span class="star fill">
#                 2
#                </span>
#                <span class="star fill">
#                 3
#                </span>
#                <span class="star">
#                 4
#                </span>
#                <span class="star">
#                 5
#                </span>
#               </td>
#              </tr>
#              <tr>
#               <td class="review-rating-header terminal-signs">
#                Terminal Signs
#               </td>
#               <td class="review-rating-stars stars">
#                <span class="star fill">
#                 1
#                </span>
#                <span class="star fill">
#                 2
#                </span>
#                <span class="star fill">
#                 3
#                </span>
#                <span class="star">
#                 4
#                </span>
#                <span class="star">
#                 5
#                </span>
#               </td>
#              </tr>
#              <tr>
#               <td class="review-rating-header queuing-times">
#                Queuing Times
#               </td>
#               <td class="review-rating-stars stars">
#                <span class="star fill">
#                 1
#                </span>
#                <span class="star fill">
#                 2
#                </span>
#                <span class="star">
#                 3
#                </span>
#                <span class="star">
#                 4
#                </span>
#                <span class="star">
#                 5
#                </span>
#               </td>
#              </tr>
#              <tr>
#               <td class="review-rating-header food-beverages">
#                Food Beverages
#               </td>
#               <td class="review-rating-stars stars">
#                <span class="star fill">
#                 1
#                </span>
#                <span class="star fill">
#                 2
#                </span>
#                <span class="star">
#                 3
#                </span>
#                <span class="star">
#                 4
#                </span>
#                <span class="star">
#                 5
#                </span>
#               </td>
#              </tr>
#              <tr>
#               <td class="review-rating-header airport-staff">
#                Airport Staff
#               </td>
#               <td class="review-rating-stars stars">
#                <span class="star fill">
#                 1
#                </span>
#                <span class="star fill">
#                 2
#                </span>
#                <span class="star">
#                 3
#                </span>
#                <span class="star">
#                 4
#                </span>
#                <span class="star">
#                 5
#                </span>
#               </td>
#              </tr>
#             </table>
#            </div>
#            <div class="rating-totals" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating">
#             <div class="review-count">
#              Customer rating from
#              <span itemprop="reviewCount">
#               636
#              </span>
#              reviews
#             </div>
#             <div class="customer-rating-total">
#              <div class="rating-10 rating-large">
#               <span itemprop="ratingValue">
#                3
#               </span>
#               /
#               <span itemprop="bestRating">
#                10
#               </span>
#              </div>
#             </div>
#             <div class="skytrax-rating-mob">
#              <img alt="5 star Skytrax Rating" class="skytrax-rating" src="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/images/skytrax-rating-airport-5.png"/>
#             </div>
#            </div>
#           </div>
#          </div>
#         </section>
#         <div class="aq-ad">
#          <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#          </script>
#          <ins class="adsbygoogle" data-ad-client="ca-pub-7401091822721150" data-ad-format="auto" data-ad-slot="9526159642" style="display:block;">
#          </ins>
#          <script>
#           (adsbygoogle = window.adsbygoogle || []).push({});
#          </script>
#         </div>
#        </div>
#       </section>
#       <section class="layout-section layout-1 closer-bottom full-width-bg">
#        <div class="col-content">
#         <section class="comp comp__review-tabs">
#          <nav class="write-a-review">
#           <a href="/write-a-review?type=airport&amp;e=istanbul-airport">
#            Write
#                         a Review
#           </a>
#          </nav>
#          <ul class="tabs">
#           <li class="tab-title airport active">
#            <a href="/airport-reviews/istanbul-airport">
#             Airport
#            </a>
#           </li>
#          </ul>
#         </section>
#        </div>
#       </section>
#       <section class="layout-section layout-2 closer-top">
#        <div class="col-content">
#         <article class="comp comp_reviews-airline querylist position-content">
#          <div class="pagination-controls">
#           <div class="pagination-sort">
#            <form method="get">
#             <span class="pagination-label">
#              Sort Reviews by :
#             </span>
#             <input name="pagesize" type="hidden" value="10">
#              <select class="page-order-selector" data-onchange-submit="" name="sortby">
#               <option value="post_date:DESC">
#                Latest Reviews
#               </option>
#               <option value="overall_rating:DESC">
#                Best Rating
#               </option>
#               <option value="queuing_times:DESC">
#                Queuing Times
#               </option>
#               <option value="terminal_cleanliness:DESC">
#                Cleanliness
#               </option>
#               <option value="terminal_seating:DESC">
#                Facilities
#               </option>
#               <option value="terminal_signs:DESC">
#                Signs
#               </option>
#               <option value="airport_staff:DESC">
#                Staff
#               </option>
#               <option value="recommended:DESC">
#                Recommended
#               </option>
#              </select>
#             </input>
#            </form>
#           </div>
#           <div class="pagination-size">
#            <form method="get">
#             <span class="pagination-label">
#              Show
#             </span>
#             <input name="sortby" type="hidden" value="post_date:Desc">
#              <ul class="page-size-selector">
#               <li>
#                <input checked="" data-onchange-submit="" id="10" name="pagesize" type="radio" value="10">
#                 <label for="10">
#                  10
#                 </label>
#                </input>
#               </li>
#               <li>
#                <input data-onchange-submit="" id="20" name="pagesize" type="radio" value="20">
#                 <label for="20">
#                  20
#                 </label>
#                </input>
#               </li>
#               <li>
#                <input data-onchange-submit="" id="50" name="pagesize" type="radio" value="50"/>
#                <label for="50">
#                 50
#                </label>
#               </li>
#               <li>
#                <input data-onchange-submit="" id="100" name="pagesize" type="radio" value="100"/>
#                <label for="100">
#                 100
#                </label>
#               </li>
#              </ul>
#             </input>
#            </form>
#           </div>
#          </div>
#          <article class="comp comp_media-review-rated list-item media position-content review-912007" itemprop="review" itemscope="" itemtype="http://schema.org/Review">
#           <meta content="2024-11-06" itemprop="datePublished"/>
#           <div class="rating-10" itemprop="reviewRating" itemscope="" itemtype="http://schema.org/Rating">
#            <span itemprop="ratingValue">
#             6
#            </span>
#            /
#            <span itemprop="bestRating">
#             10
#            </span>
#           </div>
#           <div class="body" id="anchor912007">
#            <h2 class="text_header">
#             “it is eye wateringly expensive”
#            </h2>
#            <h3 class="text_sub_header userStatusWrapper">
#             <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
#              <a class="userStatus hiflyer" href="/reviewer/reviewer-signup">
#               <span class="userStatusReviewCount">
#                11 reviews
#               </span>
#               <svg class="userStatusIcon" version="1.1" viewbox="0 0 307.3 193.5" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#                <path d="M157.9,95c-13.1,5.5-26.3,11.1-38.5,16c-21,8.4-42.4,16-65.1,18.7c-16,1.5-26.5-1-31.6-9.7C15.6,104.3,8.2,88.7,1.1,72.9
#                 C-2.5,64.8,3.3,61.5,11,62c3.2,0.2,6.6,2.1,9.5,4c8.3,5.6,16.4,11.4,24.4,17.5c5,3.8,9.8,4.1,15.4,1.6c30.8-13.5,61.6-27,92.4-40.3
#                 c30.4-13.2,60.7-26.4,91.3-39.1c16.9-7,34.3-8.1,51.3-0.1c3.8,1.8,7.2,4.7,10.5,7.4c4.9,4.1-2.8,12.5-21.8,22.7
#                 c-20.9,10.7-46,22.5-67,33c0,0-31.8,67.3-46.9,99.2c-5.4,11.6-12.7,21.1-25.6,25c-4.4,1.3-5.9,0.5-5.1-4.2
#                 c1.3-8.1,2.8-16.1,4.4-24.1C147.8,143.9,157.1,98.5,157.9,95z">
#                </path>
#                <path d="M151.7,31.5c-14.3,6.2-30.4,13.2-43.7,18.8c0,0-29.9-17.6-43.4-25.8c-1.6-0.9-2.5-2.8-3.8-4.3c1.4-1,2.6-2.2,4.1-3.1
#                 c9.9-5.7,20.4-5.7,31-2.8C113.6,19.3,138,27,151.7,31.5z">
#                </path>
#               </svg>
#              </a>
#              <span itemprop="name">
#               T Pearce
#              </span>
#             </span>
#             (United Kingdom)
#             <time datetime="2024-11-06" itemprop="datePublished">
#              6th November 2024
#             </time>
#            </h3>
#            <div class="tc_mobile">
#             <div class="text_content" itemprop="reviewBody">
#              ✅
#              <strong>
#               <a href="https://www.airlinequality.com/verified-reviews/">
#                <em>
#                 Trip Verified
#                </em>
#               </a>
#              </strong>
#              | Two things strike the traveller about the "new" Istanbul Airport, firstly it is huge and secondly it is eye wateringly expensive! Its single terminal building means you can walk everywhere but there are some very long stretches with no travelators. Departure Gates are shown 2 hours before the flight and there are no announcements so you have to watch the screens for information. Some transit passengers have to go through security scanning depending upon the origin of the flight - this is OK but even with brand new scanners that should accept liquids you have to remove them for separate scanning which can slow things down. The overriding feeling is that EVERYTHING is overpriced. Can you justify spending EUR8.00 on a Pan-Au-Chocolat or GBP22.00 on a McDonalds meal? The range of high end goods available in the shops is amazing but again the prices are not "duty free" or "tax free" but - how much can they get away with! The net result is a lot of people wandering around but not a lot of buying taking place. There is very limited seating in the main areas, except if you have bought food. Good seating at the gates and reasonable boarding processes. Only 1 hour of free Wi-Fi after you register your passport details available so use it wisely!
#             </div>
#             <div class="review-stats">
#              <table class="review-ratings">
#               <tr>
#                <td class="review-rating-header experience_at_airport">
#                 Experience At Airport
#                </td>
#                <td class="review-value">
#                 Transit
#                </td>
#               </tr>
#               <tr>
#                <td class="review-rating-header date_visit">
#                 Date Visit
#                </td>
#                <td class="review-value">
#                 November 2024
#                </td>
#               </tr>
#               <tr>
#                <td class="review-rating-header type_of_traveller">
#                 Type Of Traveller
#                </td>
#                <td class="review-value">
#                 Couple Leisure
#                </td>
#               </tr>
#               <tr>
#                <td class="review-rating-header queuing_times">
#                 Queuing Times
#                </td>
#                <td class="review-rating-stars stars">
#                 <span class="star fill">
#                  1
#                 </span>
# ...
#              </a>
#             </li>
#             <li class="">
#              <a href="https://www.airlinequality.com/wp-content/uploads/2024/10/IMG_7878-scaled.jpeg">
#               <img alt="" class="attachment-thumbnail size-thumbnail" decoding="async" height="150" sizes="(max-width: 150px) 100vw, 150px" src="https://www.airlinequality.com/wp-content/uploads/2024/10/IMG_7878-150x150.jpeg" srcset="https://www.airlinequality.com/wp-content/uploads/2024/10/IMG_7878-150x150.jpeg 150w, https://www.airlinequality.com/wp-content/uploads/2024/10/IMG_7878-125x125.jpeg 125w, https://www.airlinequality.com/wp-content/uploads/2024/10/IMG_7878-120x120.jpeg 120w, https://www.airlinequality.com/wp-content/uploads/2024/10/IMG_7878-95x95.jpeg 95w, https://www.airlinequality.com/wp-content/uploads/2024/10/IMG_7878-180x180.jpeg 180w, https://www.airlinequality.com/wp-content/uploads/2024/10/IMG_7878-50x50.jpeg 50w, https://www.airlinequality.com/wp-content/uploads/2024/10/IMG_7878-500x500.jpeg 500w" width="150"/>
#              </a>
#             </li>
#             <li class="">
#              <a href="https://www.airlinequality.com/wp-content/uploads/2024/09/photo_2024-09-15_14-58-10.jpg">
#               <img alt="" class="attachment-thumbnail size-thumbnail" decoding="async" height="150" sizes="(max-width: 150px) 100vw, 150px" src="https://www.airlinequality.com/wp-content/uploads/2024/09/photo_2024-09-15_14-58-10-150x150.jpg" srcset="https://www.airlinequality.com/wp-content/uploads/2024/09/photo_2024-09-15_14-58-10-150x150.jpg 150w, https://www.airlinequality.com/wp-content/uploads/2024/09/photo_2024-09-15_14-58-10-125x125.jpg 125w, https://www.airlinequality.com/wp-content/uploads/2024/09/photo_2024-09-15_14-58-10-120x120.jpg 120w, https://www.airlinequality.com/wp-content/uploads/2024/09/photo_2024-09-15_14-58-10-95x95.jpg 95w, https://www.airlinequality.com/wp-content/uploads/2024/09/photo_2024-09-15_14-58-10-180x180.jpg 180w, https://www.airlinequality.com/wp-content/uploads/2024/09/photo_2024-09-15_14-58-10-50x50.jpg 50w, https://www.airlinequality.com/wp-content/uploads/2024/09/photo_2024-09-15_14-58-10-500x500.jpg 500w" width="150"/>
#              </a>
#             </li>
#             <li class="">
#              <a href="">
#              </a>
#             </li>
#            </ul>
#           </div>
#           <form action="/review-pages/gallery-airport-reviews/" id="gallery-form" method="post">
#            <input name="reviewID" type="hidden" value="201904"/>
#            <button class="button" onclick="document.getElementById('gallery-form').submit();">
#             View the photos
#            </button>
#           </form>
#          </article>
#          <div class="aq-ad">
#           <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#           </script>
#           <ins class="adsbygoogle" data-ad-client="ca-pub-7401091822721150" data-ad-format="auto" data-ad-slot="9386558848" style="display:block;">
#           </ins>
#           <script>
#            (adsbygoogle = window.adsbygoogle || []).push({});
#           </script>
#          </div>
#         </div>
#        </div>
#       </section>
#      </div>
#     </div>
#     <!-- end #main -->
#    </div>
#    <!-- end #inner-content -->
#   </div>
#   <!-- end #content -->
#   <div data-wpr-lazyrender="1" id="content">
#    <div class="clearfix" id="inner-content">
#     <div id="main" role="main">
#      <section class="layout-section layout-1 border-top">
#       <div class="col-content">
#        <div class="aq-ad">
#         <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#         </script>
#         <ins class="adsbygoogle" data-ad-client="ca-pub-7401091822721150" data-ad-format="auto" data-ad-slot="1761601644" style="display:block;">
#         </ins>
#         <script>
#          (adsbygoogle = window.adsbygoogle || []).push({});
#         </script>
#        </div>
#       </div>
#      </section>
#     </div>
#    </div>
#   </div>
#   <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#   </script>
#   <ins class="adsbygoogle" data-ad-channel="8143418842" data-ad-client="ca-pub-7401091822721150" data-reactive-ad-format="1" style="display:none">
#   </ins>
#   <script>
#    (adsbygoogle = window.adsbygoogle || []).push({});
#   </script>
#   <footer class="footer clearfix" data-wpr-lazyrender="1" role="contentinfo">
#    <div id="inner-footer">
#     <div class="footer-nav quick-links">
#      <h2>
#       Quick Links
#      </h2>
#      <ul class="footer-main-nav side-nav" id="menu-quick-links">
#       <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-155421" id="menu-item-155421">
#        <a href="https://www.airlinequality.com/info/cookies/">
#         Cookies Policy
#        </a>
#       </li>
#       <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-884780" id="menu-item-884780">
#        <a href="https://www.airlinequality.com/info/privacy-policy/">
#         Privacy Policy
#        </a>
#       </li>
#       <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-88544" id="menu-item-88544">
#        <a href="https://www.airlinequality.com/info/legal-use/">
#         Terms &amp; Conditions
#        </a>
#       </li>
#       <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-88548" id="menu-item-88548">
#        <a href="https://www.airlinequality.com/info/editorial-policy/">
#         Editorial Policy
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="footer-nav about-links">
#      <h2>
#       About
#      </h2>
#      <ul class="footer-sub-nav side-nav" id="menu-about-links">
#       <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-88793" id="menu-item-88793">
#        <a href="https://www.airlinequality.com/contact-us/">
#         Contact &amp; Feedback
#        </a>
#       </li>
#       <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-154908" id="menu-item-154908">
#        <a href="https://www.airlinequality.com/info/support/">
#         Help &amp; Support
#        </a>
#       </li>
#       <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-88796" id="menu-item-88796">
#        <a href="https://www.airlinequality.com/about-us/">
#         About Us
#        </a>
#       </li>
#       <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-667262" id="menu-item-667262">
#        <a href="https://www.airlinequality.com/site-map/">
#         Site Map
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="description">
#      <p>
#       The comprehensive Airline and Airport customer review site for airlines and airports across the world. Read traveller reviews and opinions for Airlines and Airports worldwide, airline lounges and airline Seats. View airline, airport, seat, and lounge photos.
#      </p>
#      <p>
#       © 1999-2025 Copyright SKYTRAX
#      </p>
#      <ul class="social">
#       <li class="facebook">
#        <a href="https://www.facebook.com/pages/Skytrax/110801075638605" target="_blank">
#         Follow us on facebook
#        </a>
#       </li>
#       <li class="twitter">
#        <a href="https://twitter.com/airlinequality" target="_blank">
#         Follow us on twitter
#        </a>
#       </li>
#       <li class="youtube">
#        <a href="https://www.youtube.com/channel/UCxnW-L6M9GZPeShvIq5x-Ug" target="_blank">
#         Follow us on YouTube
#        </a>
#       </li>
#       <li class="instagram">
#        <a href="https://instagram.com/skytrax_uk/" target="_blank">
#         Follow us on Instagram
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#    <!--    <div class="credit">-->
#    <!-- <p><a href="http://gendall.co.uk/">Developed by Gendall</a></p>-->
#    <!--    </div>-->
#    <!-- end #inner-footer -->
#   </footer>
#   <!-- end .footer -->
#   <!-- end #container -->
#   <!-- </div> -->
#   <!-- end .inner-wrap -->
#   <!-- </div> -->
#   <!-- end .off-canvas-wrap -->
#   <!-- all js scripts are loaded in library/joints.php -->
#   <script id="google_cse_v2-js-extra" type="text/javascript">
#    /* <![CDATA[ */
# var scriptParams = {"google_search_engine_id":"017679995690221766716:2jeansnuuqa"};
# /* ]]> */
#   </script>
#   <script data-rocket-defer="" defer="" id="google_cse_v2-js" src="https://www.airlinequality.com/wp-content/plugins/wp-google-search/assets/js/google_cse_v2.js" type="text/javascript">
#   </script>
#   <script data-rocket-defer="" defer="" id="foundation-js-js" src="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/js/foundation/foundation.js" type="text/javascript">
#   </script>
#   <script data-rocket-defer="" defer="" id="foundation-js-offcanvas-js" src="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/js/foundation/foundation.offcanvas.js" type="text/javascript">
#   </script>
#   <script data-rocket-defer="" defer="" id="foundation-js-tab-js" src="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/js/foundation/foundation.tab.js" type="text/javascript">
#   </script>
#   <script data-rocket-defer="" defer="" id="foundation-js-dropdown-js" src="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/js/foundation/foundation.dropdown.js" type="text/javascript">
#   </script>
#   <script data-rocket-defer="" defer="" id="foundation-js-abide-js" src="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/js/foundation/foundation.abide.js" type="text/javascript">
#   </script>
#   <script data-rocket-defer="" defer="" id="foundation-js-clearing-js" src="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/js/foundation/foundation.clearing.js" type="text/javascript">
#   </script>
#   <script data-rocket-defer="" defer="" id="foundation-js-accordion-js" src="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/js/foundation/foundation.accordion.js" type="text/javascript">
#   </script>
#   <script data-rocket-defer="" defer="" id="foundation-js-tooltip-js" src="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/js/foundation/foundation.tooltip.js" type="text/javascript">
#   </script>
#   <script data-rocket-defer="" defer="" id="jquery-ui-core-js" src="https://www.airlinequality.com/wp-includes/js/jquery/ui/core.min.js" type="text/javascript">
#   </script>
#   <script data-rocket-defer="" defer="" id="jquery-ui-mouse-js" src="https://www.airlinequality.com/wp-includes/js/jquery/ui/mouse.min.js" type="text/javascript">
#   </script>
#   <script data-rocket-defer="" defer="" id="jquery-ui-slider-js" src="https://www.airlinequality.com/wp-includes/js/jquery/ui/slider.min.js" type="text/javascript">
#   </script>
#   <script data-rocket-defer="" defer="" id="touchpunch-js" src="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/js/vendor/jquery.ui.touch-punch.min.js" type="text/javascript">
#   </script>
#   <script data-rocket-defer="" defer="" id="lightbox-js" src="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/js/vendor/lightbox.min.js" type="text/javascript">
#   </script>
#   <script data-rocket-defer="" defer="" id="textCounter-js" src="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/js/vendor/textcounter.min.js" type="text/javascript">
#   </script>
#   <script data-rocket-defer="" defer="" id="slick-js" src="//cdn.jsdelivr.net/npm/slick-carousel@1.8.1/slick/slick.min.js" type="text/javascript">
#   </script>
#   <script data-rocket-defer="" defer="" id="jquery-ui-menu-js" src="https://www.airlinequality.com/wp-includes/js/jquery/ui/menu.min.js" type="text/javascript">
#   </script>
#   <script data-rocket-defer="" defer="" id="wp-dom-ready-js" src="https://www.airlinequality.com/wp-includes/js/dist/dom-ready.min.js" type="text/javascript">
#   </script>
#   <script id="wp-hooks-js" src="https://www.airlinequality.com/wp-includes/js/dist/hooks.min.js" type="text/javascript">
#   </script>
#   <script id="wp-i18n-js" src="https://www.airlinequality.com/wp-includes/js/dist/i18n.min.js" type="text/javascript">
#   </script>
#   <script id="wp-i18n-js-after" type="text/javascript">
#    /* <![CDATA[ */
# wp.i18n.setLocaleData( { 'text direction\u0004ltr': [ 'ltr' ] } );
# /* ]]> */
#   </script>
#   <script id="wp-a11y-js-translations" type="text/javascript">
#    /* <![CDATA[ */
# ( function( domain, translations ) {
# 	var localeData = translations.locale_data[ domain ] || translations.locale_data.messages;
# 	localeData[""].domain = domain;
# 	wp.i18n.setLocaleData( localeData, domain );
# } )( "default", {"translation-revision-date":"2024-11-14 20:13:08+0000","generator":"GlotPress\/4.0.1","domain":"messages","locale_data":{"messages":{"":{"domain":"messages","plural-forms":"nplurals=2; plural=n != 1;","lang":"en_GB"},"Notifications":["Notifications"]}},"comment":{"reference":"wp-includes\/js\/dist\/a11y.js"}} );
# /* ]]> */
#   </script>
#   <script data-rocket-defer="" defer="" id="wp-a11y-js" src="https://www.airlinequality.com/wp-includes/js/dist/a11y.min.js" type="text/javascript">
#   </script>
#   <script data-rocket-defer="" defer="" id="jquery-ui-autocomplete-js" src="https://www.airlinequality.com/wp-includes/js/jquery/ui/autocomplete.min.js" type="text/javascript">
#   </script>
#   <script data-rocket-defer="" defer="" id="joints-js-js" src="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/js/scripts.js" type="text/javascript">
#   </script>
#   <!--[if lt IE 9]>
# <script src="library/js/rem.js" type="text/javascript"></script>
# <![endif]-->
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#   ga('create', 'UA-7107328-1', 'auto');
#   ga('send', 'pageview');
#   </script>
#   <script>
#    (function(){function c(){var b=a.contentDocument||a.contentWindow.document;if(b){var d=b.createElement('script');d.innerHTML="window.__CF$cv$params={r:'9187777b9c75e232',t:'MTc0MDY1MTg4Mi4wMDAwMDA='};var a=document.createElement('script');a.nonce='';a.src='/cdn-cgi/challenge-platform/scripts/jsd/main.js';document.getElementsByTagName('head')[0].appendChild(a);";b.getElementsByTagName('head')[0].appendChild(d)}}if(document.body){var a=document.createElement('iframe');a.height=1;a.width=1;a.style.position='absolute';a.style.top=0;a.style.left=0;a.style.border='none';a.style.visibility='hidden';document.body.appendChild(a);if('loading'!==document.readyState)c();else if(window.addEventListener)document.addEventListener('DOMContentLoaded',c);else{var e=document.onreadystatechange||function(){};document.onreadystatechange=function(b){e(b);'loading'!==document.readyState&&(document.onreadystatechange=e,c())}}}})();
#   </script>
#  </body>
# </html>
# <!-- end page -->
# <!-- This website is like a Rocket, isn't it? Performance optimized by WP Rocket. Learn more: https://wp-rocket.me - Debug: cached@1740651160 -->
#
#
# ❌ No reviews found on the page. Check class name or site structure!
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[64], line 37
#      34     exit()
#      36 # Extract first review for testing
# ---> 37 first_review = review_containers[0]  # Get the first review
#      39 # Extract review text
#      40 review_text = first_review.find("div", class_="text_content")
#
# IndexError: list index out of range

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# Function to scrape Skytrax reviews
def scrape_skytrax_reviews(airport_name, url, pages=5):  
    reviews = []  # Store all reviews

    headers = { 
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/133.0.0.0 Safari/537.36 Edg/133.0.0.0"
    }

    for page in range(1, pages + 1):
        print(f"Scraping {airport_name} - Page {page}...")

        # Construct URL for each page
        page_url = f"{url}/page/{page}/" if page > 1 else url

        # Send request
        response = requests.get(page_url, headers=headers)
        if response.status_code != 200:
            print(f"❌ Failed to fetch {airport_name} - Page {page}")
            continue

        # Parse HTML
        soup = BeautifulSoup(response.text, "html.parser")
        
        # Find all reviews
        review_containers = soup.find_all("article", itemprop="review")
        if not review_containers:
            print(f"⚠️ No reviews found for {airport_name} - Page {page}")
            continue

        # Extract data from each review
        for review in review_containers:
            try:
                review_text = review.find("div", itemprop="reviewBody").text.strip()
                overall_rating = review.find("div", itemprop="reviewRating").find("span", itemprop="ratingValue").text.strip()
                recommended = review.find("td", class_="review-value").text.strip()

                # Extract additional details
                date_of_visit = review.find("tr", class_="review-rating-header date_visit").find_next_sibling("td").text.strip()
                traveller_type = review.find("tr", class_="review-rating-header type_of_traveller").find_next_sibling("td").text.strip()
                experience = review.find("tr", class_="review-rating-header experience_at_airport").find_next_sibling("td").text.strip()

                # Extract ratings for different categories
                rating_labels = {
                    "Terminal Cleanliness": "terminal_cleanliness",
                    "Terminal Seating": "terminal_seating",
                    "Terminal Signs": "terminal_signs",
                    "Food & Beverages": "food_beverages",
                    "Airport Shopping": "airport_shopping",
                    "Wifi Connectivity": "wifi_connectivity",
                    "Airport Staff": "airport_staff"
                }

                ratings_dict = {}
                for label, class_name in rating_labels.items():
                    rating_td = review.find("td", class_=f"review-rating-header {class_name}")
                    if rating_td:
                        stars = len(rating_td.find_next_sibling("td").find_all("span", class_="star fill"))
                        ratings_dict[label] = stars
                    else:
                        ratings_dict[label] = None  # No rating found

                # Append review data
                reviews.append({
                    "Airport": airport_name,
                    "Review": review_text,
                    "Overall Rating": overall_rating,
                    "Recommended": recommended,
                    "Date of Visit": date_of_visit,
                    "Type of Traveller": traveller_type,
                    "Experience": experience,
                    **ratings_dict  # Unpack category ratings into the dictionary
                })

            except Exception as e: 
                print(f"⚠️ Error extracting review: {e}")

        time.sleep(1)  # Avoid overwhelming the server

    return reviews

# List of airports to scrape
airport_data = {
    "Istanbul Airport": "https://www.airlinequality.com/airport-reviews/istanbul-airport",
    "Addis Ababa Bole Airport": "https://www.airlinequality.com/airport-reviews/addis-ababa-airport",
    "Dubai Airport": "https://www.airlinequality.com/airport-reviews/dubai-airport",
    "Doha Hamad Airport": "https://www.airlinequality.com/airport-reviews/doha-airport",
    "Abu Dhabi Airport": "https://www.airlinequality.com/airport-reviews/abu-dhabi-airport",
    "Bangkok Suvarnabhumi": "https://www.airlinequality.com/airport-reviews/bangkok-suvarnabhumi-airport",
    "Singapore Changi": "https://www.airlinequality.com/airport-reviews/singapore-changi-airport",
    "Hong Kong Airport": "https://www.airlinequality.com/airport-reviews/hong-kong-airport",
    "Delhi IGI Airport": "https://www.airlinequality.com/airport-reviews/delhi-airport",
    "Mumbai Airport": "https://www.airlinequality.com/airport-reviews/mumbai-airport",
    "Bangalore Airport": "https://www.airlinequality.com/airport-reviews/bangalore-airport",
    "Hyderabad Airport": "https://www.airlinequality.com/airport-reviews/hyderabad-airport",
}

# Run scraper for all airports
all_reviews = []
for airport, url in airport_data.items():
    reviews = scrape_skytrax_reviews(airport, url, pages=3)  # Scrape first 3 pages
    all_reviews.extend(reviews)

# Save to CSV
df = pd.DataFrame(all_reviews)
df.to_csv("airport_reviews.csv", index=False)
print("\n✅ Scraping complete! Data saved to 'airport_reviews.csv'")
# Out:
# Scraping Istanbul Airport - Page 1...
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# Scraping Istanbul Airport - Page 2...
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# Scraping Istanbul Airport - Page 3...
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# Scraping Addis Ababa Bole Airport - Page 1...
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# Scraping Addis Ababa Bole Airport - Page 2...
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# Scraping Addis Ababa Bole Airport - Page 3...
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# Scraping Dubai Airport - Page 1...
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# Scraping Dubai Airport - Page 2...
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# Scraping Dubai Airport - Page 3...
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# Scraping Doha Hamad Airport - Page 1...
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# Scraping Doha Hamad Airport - Page 2...
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# Scraping Doha Hamad Airport - Page 3...
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# Scraping Abu Dhabi Airport - Page 1...
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# Scraping Abu Dhabi Airport - Page 2...
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# Scraping Abu Dhabi Airport - Page 3...
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# Scraping Bangkok Suvarnabhumi - Page 1...
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# Scraping Bangkok Suvarnabhumi - Page 2...
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# Scraping Bangkok Suvarnabhumi - Page 3...
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# Scraping Singapore Changi - Page 1...
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# Scraping Singapore Changi - Page 2...
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# Scraping Singapore Changi - Page 3...
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# Scraping Hong Kong Airport - Page 1...
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# Scraping Hong Kong Airport - Page 2...
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# Scraping Hong Kong Airport - Page 3...
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# Scraping Delhi IGI Airport - Page 1...
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# Scraping Delhi IGI Airport - Page 2...
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# Scraping Delhi IGI Airport - Page 3...
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# Scraping Mumbai Airport - Page 1...
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# Scraping Mumbai Airport - Page 2...
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# Scraping Mumbai Airport - Page 3...
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# Scraping Bangalore Airport - Page 1...
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# Scraping Bangalore Airport - Page 2...
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# Scraping Bangalore Airport - Page 3...
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# Scraping Hyderabad Airport - Page 1...
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# Scraping Hyderabad Airport - Page 2...
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# Scraping Hyderabad Airport - Page 3...
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
# ⚠️ Error extracting review: 'NoneType' object has no attribute 'find_next_sibling'
#
# ✅ Scraping complete! Data saved to 'airport_reviews.csv'

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# Function to scrape Skytrax reviews
def scrape_skytrax_reviews(airport_name, url, pages=3):  
    reviews = []  # Store all reviews

    headers = { 
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/133.0.0.0 Safari/537.36 Edg/133.0.0.0"
    }

    for page in range(1, pages + 1):
        print(f"\nScraping {airport_name} - Page {page}...")

        # Construct URL for each page
        page_url = f"{url}/page/{page}/" if page > 1 else url

        # Send request
        response = requests.get(page_url, headers=headers)
        if response.status_code != 200:
            print(f"❌ Failed to fetch {airport_name} - Page {page}")
            continue

        # Parse HTML
        soup = BeautifulSoup(response.text, "html.parser")
        
        # Find all reviews
        review_containers = soup.find_all("article", itemprop="review")
        print(f"Found {len(review_containers)} reviews on {airport_name} - Page {page}")

        if not review_containers:
            print(f"⚠️ No reviews found for {airport_name} - Page {page}")
            continue

        # Extract data from each review
        for review in review_containers:
            try:
                # Extract review text
                review_text_element = review.find("div", itemprop="reviewBody")
                review_text = review_text_element.text.strip() if review_text_element else "N/A"

                # Extract overall rating
                rating_element = review.find("div", itemprop="reviewRating")
                overall_rating = rating_element.find("span", itemprop="ratingValue").text.strip() if rating_element else "N/A"

                # Extract recommended (yes/no)
                recommended_element = review.find("td", class_="review-value")
                recommended = recommended_element.text.strip() if recommended_element else "N/A"

                # Extract date of visit
                date_visit_element = review.find("td", class_="review-rating-header date_visit")
                date_of_visit = date_visit_element.find_next_sibling("td").text.strip() if date_visit_element else "N/A"

                # Extract traveller type
                traveller_element = review.find("td", class_="review-rating-header type_of_traveller")
                traveller_type = traveller_element.find_next_sibling("td").text.strip() if traveller_element else "N/A"

                # Extract experience (departure/arrival)
                experience_element = review.find("td", class_="review-rating-header experience_at_airport")
                experience = experience_element.find_next_sibling("td").text.strip() if experience_element else "N/A"

                # Extract ratings for different categories
                rating_labels = {
                    "Terminal Cleanliness": "terminal_cleanliness",
                    "Terminal Seating": "terminal_seating",
                    "Terminal Signs": "terminal_signs",
                    "Food & Beverages": "food_beverages",
                    "Airport Shopping": "airport_shopping",
                    "Wifi Connectivity": "wifi_connectivity",
                    "Airport Staff": "airport_staff"
                }

                ratings_dict = {}
                for label, class_name in rating_labels.items():
                    rating_td = review.find("td", class_=f"review-rating-header {class_name}")
                    if rating_td:
                        stars = len(rating_td.find_next_sibling("td").find_all("span", class_="star fill"))
                        ratings_dict[label] = stars
                    else:
                        ratings_dict[label] = "N/A"  # No rating found

                # Debug: Print extracted review
                print(f"📝 Review from {airport_name} - Page {page}:")
                print(f"Review Text: {review_text[:100]}...")  # Print first 100 characters
                print(f"Overall Rating: {overall_rating}, Recommended: {recommended}, Date of Visit: {date_of_visit}")
                print(f"Traveller Type: {traveller_type}, Experience: {experience}")
                print(f"Ratings: {ratings_dict}")

                # Append review data
                reviews.append({
                    "Airport": airport_name,
                    "Review": review_text,
                    "Overall Rating": overall_rating,
                    "Recommended": recommended,
                    "Date of Visit": date_of_visit,
                    "Type of Traveller": traveller_type,
                    "Experience": experience,
                    **ratings_dict  # Unpack category ratings into the dictionary
                })

            except Exception as e: 
                print(f"⚠️ Error extracting review: {e}")

        time.sleep(1)  # Avoid overwhelming the server

    return reviews

# List of airports to scrape
airport_data = {
    "Istanbul Airport": "https://www.airlinequality.com/airport-reviews/istanbul-airport",
    "Addis Ababa Bole Airport": "https://www.airlinequality.com/airport-reviews/addis-ababa-airport",
}

# Run scraper for all airports
all_reviews = []
for airport, url in airport_data.items():
    reviews = scrape_skytrax_reviews(airport, url, pages=3)  # Scrape first 3 pages
    all_reviews.extend(reviews)

# Save to CSV
df = pd.DataFrame(all_reviews)
df.to_csv("airport_reviews_debug.csv", index=False)
print("\n✅ Scraping complete! Data saved to 'airport_reviews_debug.csv'")
# Out:
# Scraping Istanbul Airport - Page 1...
# Found 10 reviews on Istanbul Airport - Page 1
# 📝 Review from Istanbul Airport - Page 1:
# Review Text: Not Verified |  Ridiculous prices on everything. Tired staff. Will avoid or bring my own food and dr...
# Overall Rating: 2, Recommended: Arrival and Departure, Date of Visit: February 2025
# Traveller Type: Family Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 2, 'Terminal Seating': 1, 'Terminal Signs': 3, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 1, 'Airport Staff': 1}
# 📝 Review from Istanbul Airport - Page 1:
# Review Text: Not Verified |  The biggest trap for the tourists worldwide, one Big Mac 25 euros and a bag of pista...
# Overall Rating: 1, Recommended: Departure Only, Date of Visit: February 2025
# Traveller Type: Couple Leisure, Experience: Departure Only
# Ratings: {'Terminal Cleanliness': 1, 'Terminal Seating': 1, 'Terminal Signs': 1, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 1, 'Airport Staff': 1}
# 📝 Review from Istanbul Airport - Page 1:
# Review Text: ✅ Trip Verified |   Fast food price is just ridiculously expensive! Went to a fried chicken restaura...
# Overall Rating: 2, Recommended: Transit, Date of Visit: January 2025
# Traveller Type: Solo Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 5, 'Terminal Signs': 5, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 5, 'Airport Staff': 3}
# 📝 Review from Istanbul Airport - Page 1:
# Review Text: ✅ Trip Verified |   This airport is luxury and new! However, there are multiple issues that needs to...
# Overall Rating: 2, Recommended: Arrival and Departure, Date of Visit: January 2025
# Traveller Type: Business, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 1, 'Terminal Seating': 2, 'Terminal Signs': 3, 'Food & Beverages': 3, 'Airport Shopping': 4, 'Wifi Connectivity': 2, 'Airport Staff': 1}
# 📝 Review from Istanbul Airport - Page 1:
# Review Text: ✅ Trip Verified | Arrived just before midnight with TA from KRK and was surprised with a 5hrs delay ...
# Overall Rating: 3, Recommended: Transit, Date of Visit: December 2024
# Traveller Type: Solo Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 3, 'Terminal Seating': 1, 'Terminal Signs': 2, 'Food & Beverages': 0, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 3, 'Airport Staff': 'N/A'}
# 📝 Review from Istanbul Airport - Page 1:
# Review Text: ✅ Trip Verified | Be prepared to walk kilometers, in an unfriendly environment. Get ready to pay a f...
# Overall Rating: 1, Recommended: Transit, Date of Visit: November 2024
# Traveller Type: Solo Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 3, 'Terminal Signs': 1, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 1, 'Airport Staff': 1}
# 📝 Review from Istanbul Airport - Page 1:
# Review Text: Not Verified |  Beautiful new architecture doesn’t make up for an airport’s miserable customer servi...
# Overall Rating: 1, Recommended: Arrival Only, Date of Visit: November 2024
# Traveller Type: Solo Leisure, Experience: Arrival Only
# Ratings: {'Terminal Cleanliness': 3, 'Terminal Seating': 3, 'Terminal Signs': 1, 'Food & Beverages': 0, 'Airport Shopping': 4, 'Wifi Connectivity': 'N/A', 'Airport Staff': 1}
# 📝 Review from Istanbul Airport - Page 1:
# Review Text: ✅ Trip Verified |   I travel a lot and used IST frequently, mainly for transfer flights. Now I will ...
# Overall Rating: 1, Recommended: Arrival and Departure, Date of Visit: November 2024
# Traveller Type: Business, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 1, 'Terminal Signs': 5, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 1, 'Airport Staff': 1}
# 📝 Review from Istanbul Airport - Page 1:
# Review Text: ✅ Trip Verified |   Istanbul Airport is one of the worst airports you could ever visit. It is consta...
# Overall Rating: 1, Recommended: Transit, Date of Visit: October 2024
# Traveller Type: Family Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 3, 'Terminal Seating': 1, 'Terminal Signs': 1, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 1, 'Airport Staff': 1}
# 📝 Review from Istanbul Airport - Page 1:
# Review Text: ✅ Trip Verified | We are a family of 3 with a severe low functioning child with epilepsy, hearing an...
# Overall Rating: 1, Recommended: Transit, Date of Visit: October 2024
# Traveller Type: Family Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 3, 'Terminal Signs': 5, 'Food & Beverages': 3, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 3, 'Airport Staff': 1}
#
# Scraping Istanbul Airport - Page 2...
# Found 10 reviews on Istanbul Airport - Page 2
# 📝 Review from Istanbul Airport - Page 2:
# Review Text: ✅ Trip Verified | Two things strike the traveller about the "new" Istanbul Airport, firstly it is hu...
# Overall Rating: 6, Recommended: Transit, Date of Visit: November 2024
# Traveller Type: Couple Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 1, 'Terminal Signs': 4, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 1, 'Airport Staff': 1}
# 📝 Review from Istanbul Airport - Page 2:
# Review Text: Not Verified | The airport looks big, clean and good safety control. The prices of the food are extr...
# Overall Rating: 4, Recommended: Arrival and Departure, Date of Visit: November 2024
# Traveller Type: Couple Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 3, 'Terminal Signs': 3, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 1, 'Airport Staff': 3}
# 📝 Review from Istanbul Airport - Page 2:
# Review Text: Not Verified | I was staying here for a 6 hour layover, my father is paralyzed on his right side so ...
# Overall Rating: 1, Recommended: Arrival and Departure, Date of Visit: October 2024
# Traveller Type: Family Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 1, 'Terminal Seating': 1, 'Terminal Signs': 2, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 1, 'Airport Staff': 1}
# 📝 Review from Istanbul Airport - Page 2:
# Review Text: Not Verified | I give this the Worst airport ever. Duty free more expensive then Champs Elysees Pari...
# Overall Rating: 1, Recommended: Transit, Date of Visit: November 2023
# Traveller Type: Solo Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 2, 'Terminal Seating': 1, 'Terminal Signs': 2, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 1, 'Airport Staff': 1}
# 📝 Review from Istanbul Airport - Page 2:
# Review Text: ✅ Trip Verified |   Unacceptable long waiting time to get through passport control and security chec...
# Overall Rating: 2, Recommended: Departure Only, Date of Visit: October 2024
# Traveller Type: Family Leisure, Experience: Departure Only
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 3, 'Terminal Signs': 5, 'Food & Beverages': 1, 'Airport Shopping': 5, 'Wifi Connectivity': 'N/A', 'Airport Staff': 3}
# 📝 Review from Istanbul Airport - Page 2:
# Review Text: Not Verified | Istanbul Airport is without doubt the worst and least friendly airport I have ever tr...
# Overall Rating: 1, Recommended: Departure Only, Date of Visit: September 2024
# Traveller Type: Couple Leisure, Experience: Departure Only
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 2, 'Terminal Signs': 1, 'Food & Beverages': 2, 'Airport Shopping': 4, 'Wifi Connectivity': 1, 'Airport Staff': 1}
# 📝 Review from Istanbul Airport - Page 2:
# Review Text: ✅ Trip Verified |   One of the worst transfer experiences I’ve ever had. On landing, taxiing time wa...
# Overall Rating: 2, Recommended: Transit, Date of Visit: September 2024
# Traveller Type: Couple Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 'N/A', 'Terminal Signs': 2, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 1, 'Airport Staff': 2}
# 📝 Review from Istanbul Airport - Page 2:
# Review Text: ✅ Trip Verified | Ground staff lacking respect, ignored when approach them for help, arrogant and ve...
# Overall Rating: 1, Recommended: Transit, Date of Visit: September 2024
# Traveller Type: Business, Experience: Transit
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 3, 'Terminal Signs': 1, 'Food & Beverages': 0, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 'N/A', 'Airport Staff': 1}
# 📝 Review from Istanbul Airport - Page 2:
# Review Text: ✅ Trip Verified | First time in the new big Istanbul airport so I was curious to see how it was. On ...
# Overall Rating: 3, Recommended: Departure Only, Date of Visit: August 2024
# Traveller Type: Couple Leisure, Experience: Departure Only
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 4, 'Terminal Signs': 4, 'Food & Beverages': 3, 'Airport Shopping': 3, 'Wifi Connectivity': 1, 'Airport Staff': 3}
# 📝 Review from Istanbul Airport - Page 2:
# Review Text: ✅ Trip Verified | To return tax, I had to get to another desk and only one employee was serving to a...
# Overall Rating: 2, Recommended: Departure Only, Date of Visit: September 2024
# Traveller Type: Business, Experience: Departure Only
# Ratings: {'Terminal Cleanliness': 3, 'Terminal Seating': 'N/A', 'Terminal Signs': 4, 'Food & Beverages': 0, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 1, 'Airport Staff': 1}
#
# Scraping Istanbul Airport - Page 3...
# Found 10 reviews on Istanbul Airport - Page 3
# 📝 Review from Istanbul Airport - Page 3:
# Review Text: Not Verified |  Worst customer service, very rude and charge you even if you don't have to pay the a...
# Overall Rating: 1, Recommended: Arrival and Departure, Date of Visit: September 2024
# Traveller Type: Solo Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 3, 'Terminal Seating': 2, 'Terminal Signs': 1, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 1, 'Airport Staff': 1}
# 📝 Review from Istanbul Airport - Page 3:
# Review Text: Not Verified | The staff was incredibly unfriendly and unhelpful. Laughed at me when I asked for dir...
# Overall Rating: 1, Recommended: Transit, Date of Visit: September 2024
# Traveller Type: Solo Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 1, 'Terminal Seating': 4, 'Terminal Signs': 1, 'Food & Beverages': 1, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 1, 'Airport Staff': 1}
# 📝 Review from Istanbul Airport - Page 3:
# Review Text: Not Verified |   The airport is made large, maybe to beat Dubai, but it doesn't benefit passengers. ...
# Overall Rating: 4, Recommended: Arrival and Departure, Date of Visit: August 2024
# Traveller Type: Solo Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 1, 'Terminal Seating': 2, 'Terminal Signs': 4, 'Food & Beverages': 4, 'Airport Shopping': 3, 'Wifi Connectivity': 4, 'Airport Staff': 1}
# 📝 Review from Istanbul Airport - Page 3:
# Review Text: ✅ Trip Verified |   The airport doesn’t offer free unlimited internet access, they should be ashamed...
# Overall Rating: 3, Recommended: Transit, Date of Visit: September 2024
# Traveller Type: Solo Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 2, 'Terminal Seating': 'N/A', 'Terminal Signs': 2, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 1, 'Airport Staff': 1}
# 📝 Review from Istanbul Airport - Page 3:
# Review Text: Not Verified |  One of the worst airport with impolite airport personnel. None of them spoke English...
# Overall Rating: 3, Recommended: Departure Only, Date of Visit: August 2024
# Traveller Type: Family Leisure, Experience: Departure Only
# Ratings: {'Terminal Cleanliness': 3, 'Terminal Seating': 2, 'Terminal Signs': 2, 'Food & Beverages': 2, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 1, 'Airport Staff': 1}
# 📝 Review from Istanbul Airport - Page 3:
# Review Text: Not Verified |  Absolute rip off. Had a 5 hour lay over and got Turkish kebab plate. $71usd. $22usd ...
# Overall Rating: 2, Recommended: Transit, Date of Visit: August 2024
# Traveller Type: Couple Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 2, 'Terminal Seating': 2, 'Terminal Signs': 2, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 1, 'Airport Staff': 2}
# 📝 Review from Istanbul Airport - Page 3:
# Review Text: ✅ Trip Verified |  After flying from Hanover, Germany, we had a layover at Atatürk Airport in Istanb...
# Overall Rating: 5, Recommended: Transit, Date of Visit: March 2024
# Traveller Type: Solo Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 3, 'Terminal Signs': 2, 'Food & Beverages': 3, 'Airport Shopping': 4, 'Wifi Connectivity': 2, 'Airport Staff': 2}
# 📝 Review from Istanbul Airport - Page 3:
# Review Text: Not Verified | €6 for water! 500ml. €13 euro for a sandwich! Wow! Basic human rights is water and yo...
# Overall Rating: 5, Recommended: Departure Only, Date of Visit: July 2024
# Traveller Type: Business, Experience: Departure Only
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 5, 'Terminal Signs': 5, 'Food & Beverages': 1, 'Airport Shopping': 3, 'Wifi Connectivity': 5, 'Airport Staff': 5}
# 📝 Review from Istanbul Airport - Page 3:
# Review Text: Not Verified |   Very limited food options which didn’t make the layover pleasant at all. Also, I do...
# Overall Rating: 2, Recommended: Departure Only, Date of Visit: July 2024
# Traveller Type: Family Leisure, Experience: Departure Only
# Ratings: {'Terminal Cleanliness': 3, 'Terminal Seating': 2, 'Terminal Signs': 3, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 1, 'Airport Staff': 2}
# 📝 Review from Istanbul Airport - Page 3:
# Review Text: Not Verified |   Unbelievably expensive airport. A cup of coffee costs 7.5 euro. A pastry which in t...
# Overall Rating: 2, Recommended: Transit, Date of Visit: June 2024
# Traveller Type: Solo Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 3, 'Terminal Seating': 3, 'Terminal Signs': 5, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 1, 'Airport Staff': 2}
#
# Scraping Addis Ababa Bole Airport - Page 1...
# Found 10 reviews on Addis Ababa Bole Airport - Page 1
# 📝 Review from Addis Ababa Bole Airport - Page 1:
# Review Text: ✅ Trip Verified | I'll keep this short, for such a busy airline/country it is shocking how bad this ...
# Overall Rating: 1, Recommended: Arrival Only, Date of Visit: November 2024
# Traveller Type: Solo Leisure, Experience: Arrival Only
# Ratings: {'Terminal Cleanliness': 2, 'Terminal Seating': 1, 'Terminal Signs': 2, 'Food & Beverages': 0, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 3, 'Airport Staff': 1}
# 📝 Review from Addis Ababa Bole Airport - Page 1:
# Review Text: Not Verified |   I was pretty frustrated by the experience, mainly due to unhelpful staff. I arrived...
# Overall Rating: 3, Recommended: Transit, Date of Visit: June 2024
# Traveller Type: Solo Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 2, 'Terminal Signs': 4, 'Food & Beverages': 2, 'Airport Shopping': 2, 'Wifi Connectivity': 4, 'Airport Staff': 1}
# 📝 Review from Addis Ababa Bole Airport - Page 1:
# Review Text: ✅ Trip Verified | ADD Bole airport is a zoo. On our outbound flight we arrived from London and passe...
# Overall Rating: 2, Recommended: Transit, Date of Visit: April 2024
# Traveller Type: Couple Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 2, 'Terminal Seating': 3, 'Terminal Signs': 2, 'Food & Beverages': 0, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 'N/A', 'Airport Staff': 1}
# 📝 Review from Addis Ababa Bole Airport - Page 1:
# Review Text: Not Verified | Check in and immigration fine. Nice breakfast in London Cafe. Smooth boarding for Win...
# Overall Rating: 10, Recommended: Arrival and Departure, Date of Visit: March 2024
# Traveller Type: Couple Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 5, 'Terminal Signs': 5, 'Food & Beverages': 5, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 5, 'Airport Staff': 5}
# 📝 Review from Addis Ababa Bole Airport - Page 1:
# Review Text: ✅ Trip Verified | While flying with Ethiopian Airlines is rather reliable and straight-forward (in m...
# Overall Rating: 2, Recommended: Arrival and Departure, Date of Visit: March 2024
# Traveller Type: Business, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 2, 'Terminal Seating': 2, 'Terminal Signs': 3, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 2, 'Airport Staff': 1}
# 📝 Review from Addis Ababa Bole Airport - Page 1:
# Review Text: Not Verified |  This is one of the most chaotic airports I’ve ever had the experience of being in. W...
# Overall Rating: 1, Recommended: Transit, Date of Visit: January 2024
# Traveller Type: Family Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 2, 'Terminal Seating': 1, 'Terminal Signs': 1, 'Food & Beverages': 2, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 3, 'Airport Staff': 1}
# 📝 Review from Addis Ababa Bole Airport - Page 1:
# Review Text: Not Verified |  Transit in the early morning. Lucky to have airbridges for arrival and departure. Di...
# Overall Rating: 6, Recommended: Transit, Date of Visit: November 2023
# Traveller Type: Couple Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 2, 'Terminal Seating': 3, 'Terminal Signs': 3, 'Food & Beverages': 0, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 'N/A', 'Airport Staff': 2}
# 📝 Review from Addis Ababa Bole Airport - Page 1:
# Review Text: ✅ Trip Verified | What a shambles this airport was for our very recent transits. The bus transfer fr...
# Overall Rating: 1, Recommended: Transit, Date of Visit: September 2023
# Traveller Type: Couple Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 2, 'Terminal Seating': 1, 'Terminal Signs': 3, 'Food & Beverages': 2, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 'N/A', 'Airport Staff': 1}
# 📝 Review from Addis Ababa Bole Airport - Page 1:
# Review Text: ✅ Trip Verified | Few toilets in the boarding area and not enough seats. The shops were closed in th...
# Overall Rating: 4, Recommended: Transit, Date of Visit: August 2023
# Traveller Type: Family Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 1, 'Terminal Signs': 4, 'Food & Beverages': 2, 'Airport Shopping': 1, 'Wifi Connectivity': 2, 'Airport Staff': 3}
# 📝 Review from Addis Ababa Bole Airport - Page 1:
# Review Text: Not Verified |  Why do you have to remove your shoes and bags checked twice. Whats worse is that the...
# Overall Rating: 2, Recommended: Departure Only, Date of Visit: July 2023
# Traveller Type: Business, Experience: Departure Only
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 3, 'Terminal Signs': 3, 'Food & Beverages': 0, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 2, 'Airport Staff': 2}
#
# Scraping Addis Ababa Bole Airport - Page 2...
# Found 10 reviews on Addis Ababa Bole Airport - Page 2
# 📝 Review from Addis Ababa Bole Airport - Page 2:
# Review Text: ✅ Trip Verified |  Never transit here. Staff are not very helpful and don't know how to resolve the ...
# Overall Rating: 6, Recommended: Transit, Date of Visit: July 2023
# Traveller Type: Solo Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 2, 'Terminal Seating': 1, 'Terminal Signs': 3, 'Food & Beverages': 2, 'Airport Shopping': 2, 'Wifi Connectivity': 3, 'Airport Staff': 4}
# 📝 Review from Addis Ababa Bole Airport - Page 2:
# Review Text: Not Verified |  The airport is inefficient and arranged in a terrible manner. A complete rethink is ...
# Overall Rating: 3, Recommended: Arrival and Departure, Date of Visit: May 2023
# Traveller Type: Solo Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 2, 'Terminal Seating': 3, 'Terminal Signs': 3, 'Food & Beverages': 3, 'Airport Shopping': 3, 'Wifi Connectivity': 1, 'Airport Staff': 2}
# 📝 Review from Addis Ababa Bole Airport - Page 2:
# Review Text: Not Verified | Infrastructure not able to cope even in rush hours which do get a bit manic. Some sta...
# Overall Rating: 6, Recommended: Departure Only, Date of Visit: May 2023
# Traveller Type: Couple Leisure, Experience: Departure Only
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 4, 'Terminal Signs': 5, 'Food & Beverages': 4, 'Airport Shopping': 4, 'Wifi Connectivity': 3, 'Airport Staff': 4}
# 📝 Review from Addis Ababa Bole Airport - Page 2:
# Review Text: Not Verified |  Bole these days is a pleasant experience. The massively enlarged departure area is h...
# Overall Rating: 8, Recommended: Arrival and Departure, Date of Visit: April 2023
# Traveller Type: Couple Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 5, 'Terminal Signs': 5, 'Food & Beverages': 4, 'Airport Shopping': 4, 'Wifi Connectivity': 5, 'Airport Staff': 4}
# 📝 Review from Addis Ababa Bole Airport - Page 2:
# Review Text: Not Verified |  We’ve been back and forth through Addis Ababa Airport multiple times. Ethiopia is a ...
# Overall Rating: 6, Recommended: Transit, Date of Visit: January 2023
# Traveller Type: Couple Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 2, 'Terminal Signs': 4, 'Food & Beverages': 4, 'Airport Shopping': 4, 'Wifi Connectivity': 3, 'Airport Staff': 1}
# 📝 Review from Addis Ababa Bole Airport - Page 2:
# Review Text: ✅ Trip Verified |
# Security checks, whether you are originating from Addis or in transit are shamb...
# Overall Rating: 1, Recommended: Transit, Date of Visit: March 2023
# Traveller Type: Business, Experience: Transit
# Ratings: {'Terminal Cleanliness': 2, 'Terminal Seating': 1, 'Terminal Signs': 2, 'Food & Beverages': 2, 'Airport Shopping': 2, 'Wifi Connectivity': 1, 'Airport Staff': 1}
# 📝 Review from Addis Ababa Bole Airport - Page 2:
# Review Text: ✅ Trip Verified |  It is busy in the two 6 to 9 rush hours but do not be put off by comments by the ...
# Overall Rating: 9, Recommended: Arrival Only, Date of Visit: February 2023
# Traveller Type: Couple Leisure, Experience: Arrival Only
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 5, 'Terminal Signs': 5, 'Food & Beverages': 5, 'Airport Shopping': 3, 'Wifi Connectivity': 5, 'Airport Staff': 5}
# 📝 Review from Addis Ababa Bole Airport - Page 2:
# Review Text: ✅ Trip Verified | The airport itself has improved with better shopping and seating experience. But t...
# Overall Rating: 1, Recommended: Transit, Date of Visit: December 2022
# Traveller Type: Business, Experience: Transit
# Ratings: {'Terminal Cleanliness': 1, 'Terminal Seating': 2, 'Terminal Signs': 2, 'Food & Beverages': 1, 'Airport Shopping': 2, 'Wifi Connectivity': 2, 'Airport Staff': 1}
# 📝 Review from Addis Ababa Bole Airport - Page 2:
# Review Text: Not Verified |  Flew Ethiopian to Cairo, 22.30, May 17th. This is in the evening rush hour in Addis ...
# Overall Rating: 9, Recommended: Departure Only, Date of Visit: May 2021
# Traveller Type: Solo Leisure, Experience: Departure Only
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 5, 'Terminal Signs': 4, 'Food & Beverages': 4, 'Airport Shopping': 4, 'Wifi Connectivity': 3, 'Airport Staff': 5}
# 📝 Review from Addis Ababa Bole Airport - Page 2:
# Review Text: Not Verified |  Not the worst Airport in the world. I did not know what to expect when I arrived at ...
# Overall Rating: 8, Recommended: Transit, Date of Visit: February 2021
# Traveller Type: Business, Experience: Transit
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 5, 'Terminal Signs': 5, 'Food & Beverages': 4, 'Airport Shopping': 3, 'Wifi Connectivity': 2, 'Airport Staff': 4}
#
# Scraping Addis Ababa Bole Airport - Page 3...
# Found 10 reviews on Addis Ababa Bole Airport - Page 3
# 📝 Review from Addis Ababa Bole Airport - Page 3:
# Review Text: ✅ Trip Verified | I transited in Addis Ababa from Johannesburg to Paris and was pretty disappointed....
# Overall Rating: 3, Recommended: Transit, Date of Visit: December 2020
# Traveller Type: Solo Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 1, 'Terminal Seating': 1, 'Terminal Signs': 2, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 1, 'Airport Staff': 3}
# 📝 Review from Addis Ababa Bole Airport - Page 3:
# Review Text: Not Verified |  These reviews are in good standing to make an anxious soul feel wrecked about the po...
# Overall Rating: 8, Recommended: Transit, Date of Visit: December 2020
# Traveller Type: Couple Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 5, 'Terminal Signs': 5, 'Food & Beverages': 0, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 1, 'Airport Staff': 5}
# 📝 Review from Addis Ababa Bole Airport - Page 3:
# Review Text: Not Verified |  Shocking, absolutely disgusting the airport is filthy. Nobody smokes in the smoking ...
# Overall Rating: 1, Recommended: Transit, Date of Visit: June 2019
# Traveller Type: Family Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 1, 'Terminal Seating': 1, 'Terminal Signs': 1, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 'N/A', 'Airport Staff': 1}
# 📝 Review from Addis Ababa Bole Airport - Page 3:
# Review Text: ✅ Trip Verified |  Truly awful and disorganized. Ethiopian was incompetent and couldn't board in a t...
# Overall Rating: 2, Recommended: Transit, Date of Visit: March 2020
# Traveller Type: Family Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 1, 'Terminal Seating': 1, 'Terminal Signs': 1, 'Food & Beverages': 1, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 1, 'Airport Staff': 1}
# 📝 Review from Addis Ababa Bole Airport - Page 3:
# Review Text: Not Verified |  After reading the various reviews, I was expecting a nightmare. But it was actually ...
# Overall Rating: 8, Recommended: Arrival and Departure, Date of Visit: February 2020
# Traveller Type: Solo Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 5, 'Terminal Signs': 4, 'Food & Beverages': 4, 'Airport Shopping': 4, 'Wifi Connectivity': 5, 'Airport Staff': 4}
# 📝 Review from Addis Ababa Bole Airport - Page 3:
# Review Text: Not Verified |  I have passed through Addis probably over a dozen times since 2016. I am by parts co...
# Overall Rating: 6, Recommended: Transit, Date of Visit: December 2019
# Traveller Type: Business, Experience: Transit
# Ratings: {'Terminal Cleanliness': 3, 'Terminal Seating': 3, 'Terminal Signs': 1, 'Food & Beverages': 3, 'Airport Shopping': 2, 'Wifi Connectivity': 2, 'Airport Staff': 3}
# 📝 Review from Addis Ababa Bole Airport - Page 3:
# Review Text: ✅ Trip Verified |  Addis Ababa airport is still a very unworthy hub for the otherwise decent Ethiopi...
# Overall Rating: 3, Recommended: Arrival and Departure, Date of Visit: November 2019
# Traveller Type: Couple Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 2, 'Terminal Seating': 1, 'Terminal Signs': 3, 'Food & Beverages': 1, 'Airport Shopping': 2, 'Wifi Connectivity': 'N/A', 'Airport Staff': 3}
# 📝 Review from Addis Ababa Bole Airport - Page 3:
# Review Text: ✅ Trip Verified |  Very disappointing. The airport is modern and clean but not big enough to handle ...
# Overall Rating: 3, Recommended: Transit, Date of Visit: October 2019
# Traveller Type: Business, Experience: Transit
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 2, 'Terminal Signs': 1, 'Food & Beverages': 0, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 3, 'Airport Staff': 2}
# 📝 Review from Addis Ababa Bole Airport - Page 3:
# Review Text: Not Verified |  This is one of the most unfriendly airports I've ever experienced. Poor service and ...
# Overall Rating: 3, Recommended: Departure Only, Date of Visit: October 2019
# Traveller Type: Business, Experience: Departure Only
# Ratings: {'Terminal Cleanliness': 3, 'Terminal Seating': 'N/A', 'Terminal Signs': 2, 'Food & Beverages': 0, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 'N/A', 'Airport Staff': 1}
# 📝 Review from Addis Ababa Bole Airport - Page 3:
# Review Text: ✅ Trip Verified | At least 3 to 4 times a year I pass-through this airport. Every time it has been a...
# Overall Rating: 2, Recommended: Transit, Date of Visit: August 2019
# Traveller Type: Business, Experience: Transit
# Ratings: {'Terminal Cleanliness': 1, 'Terminal Seating': 1, 'Terminal Signs': 1, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 1, 'Airport Staff': 1}
#
# ✅ Scraping complete! Data saved to 'airport_reviews_debug.csv'

# %%
df.head()
# Out:
#             Airport                                             Review  \
# 0  Istanbul Airport  Not Verified |  Ridiculous prices on everythin...
# 1  Istanbul Airport  Not Verified |  The biggest trap for the touri...
# 2  Istanbul Airport  ✅ Trip Verified |   Fast food price is just ri...
# 3  Istanbul Airport  ✅ Trip Verified |   This airport is luxury and...
# 4  Istanbul Airport  ✅ Trip Verified | Arrived just before midnight...
#
#   Overall Rating            Recommended  Date of Visit Type of Traveller  \
# 0              2  Arrival and Departure  February 2025    Family Leisure
# 1              1         Departure Only  February 2025    Couple Leisure
# 2              2                Transit   January 2025      Solo Leisure
# 3              2  Arrival and Departure   January 2025          Business
# 4              3                Transit  December 2024      Solo Leisure
#
#               Experience  Terminal Cleanliness Terminal Seating  \
# 0  Arrival and Departure                     2                1
# 1         Departure Only                     1                1
# 2                Transit                     5                5
# 3  Arrival and Departure                     1                2
# 4                Transit                     3                1
#
#    Terminal Signs  Food & Beverages Airport Shopping Wifi Connectivity  \
# 0               3                 1                1                 1
# 1               1                 1                1                 1
# 2               5                 1                1                 5
# 3               3                 3                4                 2
# 4               2                 0              N/A                 3
#
#   Airport Staff
# 0             1
# 1             1
# 2             3
# 3             1
# 4           N/A

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# Function to scrape reviews
def scrape_skytrax_reviews(airport_name, url, pages=30):  
    reviews = []  

    headers = { 
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/133.0.0.0 Safari/537.36 Edg/133.0.0.0"
    }

    for page in range(1, pages + 1):
        print(f"\nScraping {airport_name} - Page {page}...")

        # Construct URL for each page
        page_url = f"{url}/page/{page}/" if page > 1 else url

        # Send request
        response = requests.get(page_url, headers=headers)
        if response.status_code != 200:
            print(f"❌ Failed to fetch {airport_name} - Page {page}")
            continue

        # Parse HTML
        soup = BeautifulSoup(response.text, "html.parser")
        
        # Find all reviews
        review_containers = soup.find_all("article", itemprop="review")
        print(f"Found {len(review_containers)} reviews on {airport_name} - Page {page}")

        if not review_containers:
            print(f"⚠️ No reviews found for {airport_name} - Page {page}")
            continue

        # Extract data from each review
        for review in review_containers:
            try:
                review_text_element = review.find("div", itemprop="reviewBody")
                review_text = review_text_element.text.strip() if review_text_element else "N/A"

                rating_element = review.find("div", itemprop="reviewRating")
                overall_rating = rating_element.find("span", itemprop="ratingValue").text.strip() if rating_element else "N/A"

                recommended_element = review.find("td", class_="review-value")
                recommended = recommended_element.text.strip() if recommended_element else "N/A"

                date_visit_element = review.find("td", class_="review-rating-header date_visit")
                date_of_visit = date_visit_element.find_next_sibling("td").text.strip() if date_visit_element else "N/A"

                traveller_element = review.find("td", class_="review-rating-header type_of_traveller")
                traveller_type = traveller_element.find_next_sibling("td").text.strip() if traveller_element else "N/A"

                experience_element = review.find("td", class_="review-rating-header experience_at_airport")
                experience = experience_element.find_next_sibling("td").text.strip() if experience_element else "N/A"

                rating_labels = {
                    "Terminal Cleanliness": "terminal_cleanliness",
                    "Terminal Seating": "terminal_seating",
                    "Terminal Signs": "terminal_signs",
                    "Food & Beverages": "food_beverages",
                    "Airport Shopping": "airport_shopping",
                    "Wifi Connectivity": "wifi_connectivity",
                    "Airport Staff": "airport_staff"
                }

                ratings_dict = {}
                for label, class_name in rating_labels.items():
                    rating_td = review.find("td", class_=f"review-rating-header {class_name}")
                    if rating_td:
                        stars = len(rating_td.find_next_sibling("td").find_all("span", class_="star fill"))
                        ratings_dict[label] = stars
                    else:
                        ratings_dict[label] = "N/A"

                print(f"📝 Review from {airport_name} - Page {page}:")
                print(f"Review Text: {review_text[:100]}...")
                print(f"Overall Rating: {overall_rating}, Recommended: {recommended}, Date of Visit: {date_of_visit}")
                print(f"Traveller Type: {traveller_type}, Experience: {experience}")
                print(f"Ratings: {ratings_dict}")

                reviews.append({
                    "Airport": airport_name,
                    "Review": review_text,
                    "Overall Rating": overall_rating,
                    "Recommended": recommended,
                    "Date of Visit": date_of_visit,
                    "Type of Traveller": traveller_type,
                    "Experience": experience,
                    **ratings_dict
                })

            except Exception as e: 
                print(f"⚠️ Error extracting review: {e}")

        time.sleep(1)

    return reviews

# More airports to scrape
airport_data = {
    "Istanbul Airport": "https://www.airlinequality.com/airport-reviews/istanbul-airport",
    "Addis Ababa Bole Airport": "https://www.airlinequality.com/airport-reviews/addis-ababa-airport",
    "Dubai": "https://www.airlinequality.com/airport-reviews/dubai-airport",
    "Doha": "https://www.airlinequality.com/airport-reviews/doha-hamad-airport",
    "Abu Dhabi": "https://www.airlinequality.com/airport-reviews/abu-dhabi-airport",
    "Bangkok": "https://www.airlinequality.com/airport-reviews/bangkok-airport",
    "Singapore": "https://www.airlinequality.com/airport-reviews/singapore-changi-airport",
    "Hong Kong": "https://www.airlinequality.com/airport-reviews/hong-kong-airport",
    "Delhi": "https://www.airlinequality.com/airport-reviews/delhi-indira-gandhi-airport",
    "Mumbai": "https://www.airlinequality.com/airport-reviews/mumbai-chhatrapati-shivaji-airport",
    "Bangalore": "https://www.airlinequality.com/airport-reviews/bangalore-kempegowda-airport",
    "Hyderabad": "https://www.airlinequality.com/airport-reviews/hyderabad-rajiv-gandhi-airport"
}

# Run scraper for all airports
all_reviews = []
for airport, url in airport_data.items():
    reviews = scrape_skytrax_reviews(airport, url, pages=3)  # Scrape first 3 pages
    all_reviews.extend(reviews)

# Data is stored in 'all_reviews' list, but NOT saved to CSV yet
print("\n✅ Scraping complete! Data is stored in the 'all_reviews' list.")
# Out:
# Scraping Istanbul Airport - Page 1...
# Found 10 reviews on Istanbul Airport - Page 1
# 📝 Review from Istanbul Airport - Page 1:
# Review Text: Not Verified |  Ridiculous prices on everything. Tired staff. Will avoid or bring my own food and dr...
# Overall Rating: 2, Recommended: Arrival and Departure, Date of Visit: February 2025
# Traveller Type: Family Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 2, 'Terminal Seating': 1, 'Terminal Signs': 3, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 1, 'Airport Staff': 1}
# 📝 Review from Istanbul Airport - Page 1:
# Review Text: Not Verified |  The biggest trap for the tourists worldwide, one Big Mac 25 euros and a bag of pista...
# Overall Rating: 1, Recommended: Departure Only, Date of Visit: February 2025
# Traveller Type: Couple Leisure, Experience: Departure Only
# Ratings: {'Terminal Cleanliness': 1, 'Terminal Seating': 1, 'Terminal Signs': 1, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 1, 'Airport Staff': 1}
# 📝 Review from Istanbul Airport - Page 1:
# Review Text: ✅ Trip Verified |   Fast food price is just ridiculously expensive! Went to a fried chicken restaura...
# Overall Rating: 2, Recommended: Transit, Date of Visit: January 2025
# Traveller Type: Solo Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 5, 'Terminal Signs': 5, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 5, 'Airport Staff': 3}
# 📝 Review from Istanbul Airport - Page 1:
# Review Text: ✅ Trip Verified |   This airport is luxury and new! However, there are multiple issues that needs to...
# Overall Rating: 2, Recommended: Arrival and Departure, Date of Visit: January 2025
# Traveller Type: Business, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 1, 'Terminal Seating': 2, 'Terminal Signs': 3, 'Food & Beverages': 3, 'Airport Shopping': 4, 'Wifi Connectivity': 2, 'Airport Staff': 1}
# 📝 Review from Istanbul Airport - Page 1:
# Review Text: ✅ Trip Verified | Arrived just before midnight with TA from KRK and was surprised with a 5hrs delay ...
# Overall Rating: 3, Recommended: Transit, Date of Visit: December 2024
# Traveller Type: Solo Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 3, 'Terminal Seating': 1, 'Terminal Signs': 2, 'Food & Beverages': 0, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 3, 'Airport Staff': 'N/A'}
# 📝 Review from Istanbul Airport - Page 1:
# Review Text: ✅ Trip Verified | Be prepared to walk kilometers, in an unfriendly environment. Get ready to pay a f...
# Overall Rating: 1, Recommended: Transit, Date of Visit: November 2024
# Traveller Type: Solo Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 3, 'Terminal Signs': 1, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 1, 'Airport Staff': 1}
# 📝 Review from Istanbul Airport - Page 1:
# Review Text: Not Verified |  Beautiful new architecture doesn’t make up for an airport’s miserable customer servi...
# Overall Rating: 1, Recommended: Arrival Only, Date of Visit: November 2024
# Traveller Type: Solo Leisure, Experience: Arrival Only
# Ratings: {'Terminal Cleanliness': 3, 'Terminal Seating': 3, 'Terminal Signs': 1, 'Food & Beverages': 0, 'Airport Shopping': 4, 'Wifi Connectivity': 'N/A', 'Airport Staff': 1}
# 📝 Review from Istanbul Airport - Page 1:
# Review Text: ✅ Trip Verified |   I travel a lot and used IST frequently, mainly for transfer flights. Now I will ...
# Overall Rating: 1, Recommended: Arrival and Departure, Date of Visit: November 2024
# Traveller Type: Business, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 1, 'Terminal Signs': 5, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 1, 'Airport Staff': 1}
# 📝 Review from Istanbul Airport - Page 1:
# Review Text: ✅ Trip Verified |   Istanbul Airport is one of the worst airports you could ever visit. It is consta...
# Overall Rating: 1, Recommended: Transit, Date of Visit: October 2024
# Traveller Type: Family Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 3, 'Terminal Seating': 1, 'Terminal Signs': 1, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 1, 'Airport Staff': 1}
# 📝 Review from Istanbul Airport - Page 1:
# Review Text: ✅ Trip Verified | We are a family of 3 with a severe low functioning child with epilepsy, hearing an...
# Overall Rating: 1, Recommended: Transit, Date of Visit: October 2024
# Traveller Type: Family Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 3, 'Terminal Signs': 5, 'Food & Beverages': 3, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 3, 'Airport Staff': 1}
#
# Scraping Istanbul Airport - Page 2...
# Found 10 reviews on Istanbul Airport - Page 2
# 📝 Review from Istanbul Airport - Page 2:
# Review Text: ✅ Trip Verified | Two things strike the traveller about the "new" Istanbul Airport, firstly it is hu...
# Overall Rating: 6, Recommended: Transit, Date of Visit: November 2024
# Traveller Type: Couple Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 1, 'Terminal Signs': 4, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 1, 'Airport Staff': 1}
# 📝 Review from Istanbul Airport - Page 2:
# Review Text: Not Verified | The airport looks big, clean and good safety control. The prices of the food are extr...
# Overall Rating: 4, Recommended: Arrival and Departure, Date of Visit: November 2024
# Traveller Type: Couple Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 3, 'Terminal Signs': 3, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 1, 'Airport Staff': 3}
# 📝 Review from Istanbul Airport - Page 2:
# Review Text: Not Verified | I was staying here for a 6 hour layover, my father is paralyzed on his right side so ...
# Overall Rating: 1, Recommended: Arrival and Departure, Date of Visit: October 2024
# Traveller Type: Family Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 1, 'Terminal Seating': 1, 'Terminal Signs': 2, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 1, 'Airport Staff': 1}
# 📝 Review from Istanbul Airport - Page 2:
# Review Text: Not Verified | I give this the Worst airport ever. Duty free more expensive then Champs Elysees Pari...
# Overall Rating: 1, Recommended: Transit, Date of Visit: November 2023
# Traveller Type: Solo Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 2, 'Terminal Seating': 1, 'Terminal Signs': 2, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 1, 'Airport Staff': 1}
# 📝 Review from Istanbul Airport - Page 2:
# Review Text: ✅ Trip Verified |   Unacceptable long waiting time to get through passport control and security chec...
# Overall Rating: 2, Recommended: Departure Only, Date of Visit: October 2024
# Traveller Type: Family Leisure, Experience: Departure Only
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 3, 'Terminal Signs': 5, 'Food & Beverages': 1, 'Airport Shopping': 5, 'Wifi Connectivity': 'N/A', 'Airport Staff': 3}
# 📝 Review from Istanbul Airport - Page 2:
# Review Text: Not Verified | Istanbul Airport is without doubt the worst and least friendly airport I have ever tr...
# Overall Rating: 1, Recommended: Departure Only, Date of Visit: September 2024
# Traveller Type: Couple Leisure, Experience: Departure Only
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 2, 'Terminal Signs': 1, 'Food & Beverages': 2, 'Airport Shopping': 4, 'Wifi Connectivity': 1, 'Airport Staff': 1}
# 📝 Review from Istanbul Airport - Page 2:
# Review Text: ✅ Trip Verified |   One of the worst transfer experiences I’ve ever had. On landing, taxiing time wa...
# Overall Rating: 2, Recommended: Transit, Date of Visit: September 2024
# Traveller Type: Couple Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 'N/A', 'Terminal Signs': 2, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 1, 'Airport Staff': 2}
# 📝 Review from Istanbul Airport - Page 2:
# Review Text: ✅ Trip Verified | Ground staff lacking respect, ignored when approach them for help, arrogant and ve...
# Overall Rating: 1, Recommended: Transit, Date of Visit: September 2024
# Traveller Type: Business, Experience: Transit
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 3, 'Terminal Signs': 1, 'Food & Beverages': 0, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 'N/A', 'Airport Staff': 1}
# 📝 Review from Istanbul Airport - Page 2:
# Review Text: ✅ Trip Verified | First time in the new big Istanbul airport so I was curious to see how it was. On ...
# Overall Rating: 3, Recommended: Departure Only, Date of Visit: August 2024
# Traveller Type: Couple Leisure, Experience: Departure Only
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 4, 'Terminal Signs': 4, 'Food & Beverages': 3, 'Airport Shopping': 3, 'Wifi Connectivity': 1, 'Airport Staff': 3}
# 📝 Review from Istanbul Airport - Page 2:
# Review Text: ✅ Trip Verified | To return tax, I had to get to another desk and only one employee was serving to a...
# Overall Rating: 2, Recommended: Departure Only, Date of Visit: September 2024
# Traveller Type: Business, Experience: Departure Only
# Ratings: {'Terminal Cleanliness': 3, 'Terminal Seating': 'N/A', 'Terminal Signs': 4, 'Food & Beverages': 0, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 1, 'Airport Staff': 1}
#
# Scraping Istanbul Airport - Page 3...
# Found 10 reviews on Istanbul Airport - Page 3
# 📝 Review from Istanbul Airport - Page 3:
# Review Text: Not Verified |  Worst customer service, very rude and charge you even if you don't have to pay the a...
# Overall Rating: 1, Recommended: Arrival and Departure, Date of Visit: September 2024
# Traveller Type: Solo Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 3, 'Terminal Seating': 2, 'Terminal Signs': 1, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 1, 'Airport Staff': 1}
# 📝 Review from Istanbul Airport - Page 3:
# Review Text: Not Verified | The staff was incredibly unfriendly and unhelpful. Laughed at me when I asked for dir...
# Overall Rating: 1, Recommended: Transit, Date of Visit: September 2024
# Traveller Type: Solo Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 1, 'Terminal Seating': 4, 'Terminal Signs': 1, 'Food & Beverages': 1, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 1, 'Airport Staff': 1}
# 📝 Review from Istanbul Airport - Page 3:
# Review Text: Not Verified |   The airport is made large, maybe to beat Dubai, but it doesn't benefit passengers. ...
# Overall Rating: 4, Recommended: Arrival and Departure, Date of Visit: August 2024
# Traveller Type: Solo Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 1, 'Terminal Seating': 2, 'Terminal Signs': 4, 'Food & Beverages': 4, 'Airport Shopping': 3, 'Wifi Connectivity': 4, 'Airport Staff': 1}
# 📝 Review from Istanbul Airport - Page 3:
# Review Text: ✅ Trip Verified |   The airport doesn’t offer free unlimited internet access, they should be ashamed...
# Overall Rating: 3, Recommended: Transit, Date of Visit: September 2024
# Traveller Type: Solo Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 2, 'Terminal Seating': 'N/A', 'Terminal Signs': 2, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 1, 'Airport Staff': 1}
# 📝 Review from Istanbul Airport - Page 3:
# Review Text: Not Verified |  One of the worst airport with impolite airport personnel. None of them spoke English...
# Overall Rating: 3, Recommended: Departure Only, Date of Visit: August 2024
# Traveller Type: Family Leisure, Experience: Departure Only
# Ratings: {'Terminal Cleanliness': 3, 'Terminal Seating': 2, 'Terminal Signs': 2, 'Food & Beverages': 2, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 1, 'Airport Staff': 1}
# 📝 Review from Istanbul Airport - Page 3:
# Review Text: Not Verified |  Absolute rip off. Had a 5 hour lay over and got Turkish kebab plate. $71usd. $22usd ...
# Overall Rating: 2, Recommended: Transit, Date of Visit: August 2024
# Traveller Type: Couple Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 2, 'Terminal Seating': 2, 'Terminal Signs': 2, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 1, 'Airport Staff': 2}
# 📝 Review from Istanbul Airport - Page 3:
# Review Text: ✅ Trip Verified |  After flying from Hanover, Germany, we had a layover at Atatürk Airport in Istanb...
# Overall Rating: 5, Recommended: Transit, Date of Visit: March 2024
# Traveller Type: Solo Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 3, 'Terminal Signs': 2, 'Food & Beverages': 3, 'Airport Shopping': 4, 'Wifi Connectivity': 2, 'Airport Staff': 2}
# 📝 Review from Istanbul Airport - Page 3:
# Review Text: Not Verified | €6 for water! 500ml. €13 euro for a sandwich! Wow! Basic human rights is water and yo...
# Overall Rating: 5, Recommended: Departure Only, Date of Visit: July 2024
# Traveller Type: Business, Experience: Departure Only
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 5, 'Terminal Signs': 5, 'Food & Beverages': 1, 'Airport Shopping': 3, 'Wifi Connectivity': 5, 'Airport Staff': 5}
# 📝 Review from Istanbul Airport - Page 3:
# Review Text: Not Verified |   Very limited food options which didn’t make the layover pleasant at all. Also, I do...
# Overall Rating: 2, Recommended: Departure Only, Date of Visit: July 2024
# Traveller Type: Family Leisure, Experience: Departure Only
# Ratings: {'Terminal Cleanliness': 3, 'Terminal Seating': 2, 'Terminal Signs': 3, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 1, 'Airport Staff': 2}
# 📝 Review from Istanbul Airport - Page 3:
# Review Text: Not Verified |   Unbelievably expensive airport. A cup of coffee costs 7.5 euro. A pastry which in t...
# Overall Rating: 2, Recommended: Transit, Date of Visit: June 2024
# Traveller Type: Solo Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 3, 'Terminal Seating': 3, 'Terminal Signs': 5, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 1, 'Airport Staff': 2}
#
# Scraping Addis Ababa Bole Airport - Page 1...
# Found 10 reviews on Addis Ababa Bole Airport - Page 1
# 📝 Review from Addis Ababa Bole Airport - Page 1:
# Review Text: ✅ Trip Verified | I'll keep this short, for such a busy airline/country it is shocking how bad this ...
# Overall Rating: 1, Recommended: Arrival Only, Date of Visit: November 2024
# Traveller Type: Solo Leisure, Experience: Arrival Only
# Ratings: {'Terminal Cleanliness': 2, 'Terminal Seating': 1, 'Terminal Signs': 2, 'Food & Beverages': 0, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 3, 'Airport Staff': 1}
# 📝 Review from Addis Ababa Bole Airport - Page 1:
# Review Text: Not Verified |   I was pretty frustrated by the experience, mainly due to unhelpful staff. I arrived...
# Overall Rating: 3, Recommended: Transit, Date of Visit: June 2024
# Traveller Type: Solo Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 2, 'Terminal Signs': 4, 'Food & Beverages': 2, 'Airport Shopping': 2, 'Wifi Connectivity': 4, 'Airport Staff': 1}
# 📝 Review from Addis Ababa Bole Airport - Page 1:
# Review Text: ✅ Trip Verified | ADD Bole airport is a zoo. On our outbound flight we arrived from London and passe...
# Overall Rating: 2, Recommended: Transit, Date of Visit: April 2024
# Traveller Type: Couple Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 2, 'Terminal Seating': 3, 'Terminal Signs': 2, 'Food & Beverages': 0, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 'N/A', 'Airport Staff': 1}
# 📝 Review from Addis Ababa Bole Airport - Page 1:
# Review Text: Not Verified | Check in and immigration fine. Nice breakfast in London Cafe. Smooth boarding for Win...
# Overall Rating: 10, Recommended: Arrival and Departure, Date of Visit: March 2024
# Traveller Type: Couple Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 5, 'Terminal Signs': 5, 'Food & Beverages': 5, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 5, 'Airport Staff': 5}
# 📝 Review from Addis Ababa Bole Airport - Page 1:
# Review Text: ✅ Trip Verified | While flying with Ethiopian Airlines is rather reliable and straight-forward (in m...
# Overall Rating: 2, Recommended: Arrival and Departure, Date of Visit: March 2024
# Traveller Type: Business, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 2, 'Terminal Seating': 2, 'Terminal Signs': 3, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 2, 'Airport Staff': 1}
# 📝 Review from Addis Ababa Bole Airport - Page 1:
# Review Text: Not Verified |  This is one of the most chaotic airports I’ve ever had the experience of being in. W...
# Overall Rating: 1, Recommended: Transit, Date of Visit: January 2024
# Traveller Type: Family Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 2, 'Terminal Seating': 1, 'Terminal Signs': 1, 'Food & Beverages': 2, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 3, 'Airport Staff': 1}
# 📝 Review from Addis Ababa Bole Airport - Page 1:
# Review Text: Not Verified |  Transit in the early morning. Lucky to have airbridges for arrival and departure. Di...
# Overall Rating: 6, Recommended: Transit, Date of Visit: November 2023
# Traveller Type: Couple Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 2, 'Terminal Seating': 3, 'Terminal Signs': 3, 'Food & Beverages': 0, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 'N/A', 'Airport Staff': 2}
# 📝 Review from Addis Ababa Bole Airport - Page 1:
# Review Text: ✅ Trip Verified | What a shambles this airport was for our very recent transits. The bus transfer fr...
# Overall Rating: 1, Recommended: Transit, Date of Visit: September 2023
# Traveller Type: Couple Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 2, 'Terminal Seating': 1, 'Terminal Signs': 3, 'Food & Beverages': 2, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 'N/A', 'Airport Staff': 1}
# 📝 Review from Addis Ababa Bole Airport - Page 1:
# Review Text: ✅ Trip Verified | Few toilets in the boarding area and not enough seats. The shops were closed in th...
# Overall Rating: 4, Recommended: Transit, Date of Visit: August 2023
# Traveller Type: Family Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 1, 'Terminal Signs': 4, 'Food & Beverages': 2, 'Airport Shopping': 1, 'Wifi Connectivity': 2, 'Airport Staff': 3}
# 📝 Review from Addis Ababa Bole Airport - Page 1:
# Review Text: Not Verified |  Why do you have to remove your shoes and bags checked twice. Whats worse is that the...
# Overall Rating: 2, Recommended: Departure Only, Date of Visit: July 2023
# Traveller Type: Business, Experience: Departure Only
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 3, 'Terminal Signs': 3, 'Food & Beverages': 0, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 2, 'Airport Staff': 2}
#
# Scraping Addis Ababa Bole Airport - Page 2...
# Found 10 reviews on Addis Ababa Bole Airport - Page 2
# 📝 Review from Addis Ababa Bole Airport - Page 2:
# Review Text: ✅ Trip Verified |  Never transit here. Staff are not very helpful and don't know how to resolve the ...
# Overall Rating: 6, Recommended: Transit, Date of Visit: July 2023
# Traveller Type: Solo Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 2, 'Terminal Seating': 1, 'Terminal Signs': 3, 'Food & Beverages': 2, 'Airport Shopping': 2, 'Wifi Connectivity': 3, 'Airport Staff': 4}
# 📝 Review from Addis Ababa Bole Airport - Page 2:
# Review Text: Not Verified |  The airport is inefficient and arranged in a terrible manner. A complete rethink is ...
# Overall Rating: 3, Recommended: Arrival and Departure, Date of Visit: May 2023
# Traveller Type: Solo Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 2, 'Terminal Seating': 3, 'Terminal Signs': 3, 'Food & Beverages': 3, 'Airport Shopping': 3, 'Wifi Connectivity': 1, 'Airport Staff': 2}
# 📝 Review from Addis Ababa Bole Airport - Page 2:
# Review Text: Not Verified | Infrastructure not able to cope even in rush hours which do get a bit manic. Some sta...
# Overall Rating: 6, Recommended: Departure Only, Date of Visit: May 2023
# Traveller Type: Couple Leisure, Experience: Departure Only
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 4, 'Terminal Signs': 5, 'Food & Beverages': 4, 'Airport Shopping': 4, 'Wifi Connectivity': 3, 'Airport Staff': 4}
# 📝 Review from Addis Ababa Bole Airport - Page 2:
# Review Text: Not Verified |  Bole these days is a pleasant experience. The massively enlarged departure area is h...
# Overall Rating: 8, Recommended: Arrival and Departure, Date of Visit: April 2023
# Traveller Type: Couple Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 5, 'Terminal Signs': 5, 'Food & Beverages': 4, 'Airport Shopping': 4, 'Wifi Connectivity': 5, 'Airport Staff': 4}
# 📝 Review from Addis Ababa Bole Airport - Page 2:
# Review Text: Not Verified |  We’ve been back and forth through Addis Ababa Airport multiple times. Ethiopia is a ...
# Overall Rating: 6, Recommended: Transit, Date of Visit: January 2023
# Traveller Type: Couple Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 2, 'Terminal Signs': 4, 'Food & Beverages': 4, 'Airport Shopping': 4, 'Wifi Connectivity': 3, 'Airport Staff': 1}
# 📝 Review from Addis Ababa Bole Airport - Page 2:
# Review Text: ✅ Trip Verified |
# Security checks, whether you are originating from Addis or in transit are shamb...
# Overall Rating: 1, Recommended: Transit, Date of Visit: March 2023
# Traveller Type: Business, Experience: Transit
# Ratings: {'Terminal Cleanliness': 2, 'Terminal Seating': 1, 'Terminal Signs': 2, 'Food & Beverages': 2, 'Airport Shopping': 2, 'Wifi Connectivity': 1, 'Airport Staff': 1}
# 📝 Review from Addis Ababa Bole Airport - Page 2:
# Review Text: ✅ Trip Verified |  It is busy in the two 6 to 9 rush hours but do not be put off by comments by the ...
# Overall Rating: 9, Recommended: Arrival Only, Date of Visit: February 2023
# Traveller Type: Couple Leisure, Experience: Arrival Only
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 5, 'Terminal Signs': 5, 'Food & Beverages': 5, 'Airport Shopping': 3, 'Wifi Connectivity': 5, 'Airport Staff': 5}
# 📝 Review from Addis Ababa Bole Airport - Page 2:
# Review Text: ✅ Trip Verified | The airport itself has improved with better shopping and seating experience. But t...
# Overall Rating: 1, Recommended: Transit, Date of Visit: December 2022
# Traveller Type: Business, Experience: Transit
# Ratings: {'Terminal Cleanliness': 1, 'Terminal Seating': 2, 'Terminal Signs': 2, 'Food & Beverages': 1, 'Airport Shopping': 2, 'Wifi Connectivity': 2, 'Airport Staff': 1}
# 📝 Review from Addis Ababa Bole Airport - Page 2:
# Review Text: Not Verified |  Flew Ethiopian to Cairo, 22.30, May 17th. This is in the evening rush hour in Addis ...
# Overall Rating: 9, Recommended: Departure Only, Date of Visit: May 2021
# Traveller Type: Solo Leisure, Experience: Departure Only
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 5, 'Terminal Signs': 4, 'Food & Beverages': 4, 'Airport Shopping': 4, 'Wifi Connectivity': 3, 'Airport Staff': 5}
# 📝 Review from Addis Ababa Bole Airport - Page 2:
# Review Text: Not Verified |  Not the worst Airport in the world. I did not know what to expect when I arrived at ...
# Overall Rating: 8, Recommended: Transit, Date of Visit: February 2021
# Traveller Type: Business, Experience: Transit
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 5, 'Terminal Signs': 5, 'Food & Beverages': 4, 'Airport Shopping': 3, 'Wifi Connectivity': 2, 'Airport Staff': 4}
#
# Scraping Addis Ababa Bole Airport - Page 3...
# Found 10 reviews on Addis Ababa Bole Airport - Page 3
# 📝 Review from Addis Ababa Bole Airport - Page 3:
# Review Text: ✅ Trip Verified | I transited in Addis Ababa from Johannesburg to Paris and was pretty disappointed....
# Overall Rating: 3, Recommended: Transit, Date of Visit: December 2020
# Traveller Type: Solo Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 1, 'Terminal Seating': 1, 'Terminal Signs': 2, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 1, 'Airport Staff': 3}
# 📝 Review from Addis Ababa Bole Airport - Page 3:
# Review Text: Not Verified |  These reviews are in good standing to make an anxious soul feel wrecked about the po...
# Overall Rating: 8, Recommended: Transit, Date of Visit: December 2020
# Traveller Type: Couple Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 5, 'Terminal Signs': 5, 'Food & Beverages': 0, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 1, 'Airport Staff': 5}
# 📝 Review from Addis Ababa Bole Airport - Page 3:
# Review Text: Not Verified |  Shocking, absolutely disgusting the airport is filthy. Nobody smokes in the smoking ...
# Overall Rating: 1, Recommended: Transit, Date of Visit: June 2019
# Traveller Type: Family Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 1, 'Terminal Seating': 1, 'Terminal Signs': 1, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 'N/A', 'Airport Staff': 1}
# 📝 Review from Addis Ababa Bole Airport - Page 3:
# Review Text: ✅ Trip Verified |  Truly awful and disorganized. Ethiopian was incompetent and couldn't board in a t...
# Overall Rating: 2, Recommended: Transit, Date of Visit: March 2020
# Traveller Type: Family Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 1, 'Terminal Seating': 1, 'Terminal Signs': 1, 'Food & Beverages': 1, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 1, 'Airport Staff': 1}
# 📝 Review from Addis Ababa Bole Airport - Page 3:
# Review Text: Not Verified |  After reading the various reviews, I was expecting a nightmare. But it was actually ...
# Overall Rating: 8, Recommended: Arrival and Departure, Date of Visit: February 2020
# Traveller Type: Solo Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 5, 'Terminal Signs': 4, 'Food & Beverages': 4, 'Airport Shopping': 4, 'Wifi Connectivity': 5, 'Airport Staff': 4}
# 📝 Review from Addis Ababa Bole Airport - Page 3:
# Review Text: Not Verified |  I have passed through Addis probably over a dozen times since 2016. I am by parts co...
# Overall Rating: 6, Recommended: Transit, Date of Visit: December 2019
# Traveller Type: Business, Experience: Transit
# Ratings: {'Terminal Cleanliness': 3, 'Terminal Seating': 3, 'Terminal Signs': 1, 'Food & Beverages': 3, 'Airport Shopping': 2, 'Wifi Connectivity': 2, 'Airport Staff': 3}
# 📝 Review from Addis Ababa Bole Airport - Page 3:
# Review Text: ✅ Trip Verified |  Addis Ababa airport is still a very unworthy hub for the otherwise decent Ethiopi...
# Overall Rating: 3, Recommended: Arrival and Departure, Date of Visit: November 2019
# Traveller Type: Couple Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 2, 'Terminal Seating': 1, 'Terminal Signs': 3, 'Food & Beverages': 1, 'Airport Shopping': 2, 'Wifi Connectivity': 'N/A', 'Airport Staff': 3}
# 📝 Review from Addis Ababa Bole Airport - Page 3:
# Review Text: ✅ Trip Verified |  Very disappointing. The airport is modern and clean but not big enough to handle ...
# Overall Rating: 3, Recommended: Transit, Date of Visit: October 2019
# Traveller Type: Business, Experience: Transit
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 2, 'Terminal Signs': 1, 'Food & Beverages': 0, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 3, 'Airport Staff': 2}
# 📝 Review from Addis Ababa Bole Airport - Page 3:
# Review Text: Not Verified |  This is one of the most unfriendly airports I've ever experienced. Poor service and ...
# Overall Rating: 3, Recommended: Departure Only, Date of Visit: October 2019
# Traveller Type: Business, Experience: Departure Only
# Ratings: {'Terminal Cleanliness': 3, 'Terminal Seating': 'N/A', 'Terminal Signs': 2, 'Food & Beverages': 0, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 'N/A', 'Airport Staff': 1}
# 📝 Review from Addis Ababa Bole Airport - Page 3:
# Review Text: ✅ Trip Verified | At least 3 to 4 times a year I pass-through this airport. Every time it has been a...
# Overall Rating: 2, Recommended: Transit, Date of Visit: August 2019
# Traveller Type: Business, Experience: Transit
# Ratings: {'Terminal Cleanliness': 1, 'Terminal Seating': 1, 'Terminal Signs': 1, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 1, 'Airport Staff': 1}
#
# Scraping Dubai - Page 1...
# Found 10 reviews on Dubai - Page 1
# 📝 Review from Dubai - Page 1:
# Review Text: ✅ Trip Verified |   The airport is big, upon my arrival I passed through the electronic gate and it ...
# Overall Rating: 10, Recommended: Arrival and Departure, Date of Visit: January 2025
# Traveller Type: Family Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 5, 'Terminal Signs': 5, 'Food & Beverages': 5, 'Airport Shopping': 5, 'Wifi Connectivity': 5, 'Airport Staff': 5}
# 📝 Review from Dubai - Page 1:
# Review Text: ✅ Trip Verified |   The airport police in Dubai are really unpleasant. When I went through security,...
# Overall Rating: 5, Recommended: Departure Only, Date of Visit: February 2025
# Traveller Type: Solo Leisure, Experience: Departure Only
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 'N/A', 'Terminal Signs': 5, 'Food & Beverages': 4, 'Airport Shopping': 5, 'Wifi Connectivity': 4, 'Airport Staff': 1}
# 📝 Review from Dubai - Page 1:
# Review Text: Not Verified | No air conditioning , it’s terribly hot. Worst airport in my life. The heat is unbear...
# Overall Rating: 1, Recommended: Departure Only, Date of Visit: January 2025
# Traveller Type: Family Leisure, Experience: Departure Only
# Ratings: {'Terminal Cleanliness': 1, 'Terminal Seating': 1, 'Terminal Signs': 1, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 1, 'Airport Staff': 1}
# 📝 Review from Dubai - Page 1:
# Review Text: ✅ Trip Verified |   Me and my husband have really big travel experience, but never had such a bad tr...
# Overall Rating: 1, Recommended: Transit, Date of Visit: January 2025
# Traveller Type: Family Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 3, 'Terminal Seating': 3, 'Terminal Signs': 1, 'Food & Beverages': 0, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 'N/A', 'Airport Staff': 1}
# 📝 Review from Dubai - Page 1:
# Review Text: ✅ Trip Verified |   This a not an airport, it's only a shopping mall. the customer care does not exi...
# Overall Rating: 1, Recommended: Transit, Date of Visit: January 2025
# Traveller Type: Couple Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 1, 'Terminal Seating': 1, 'Terminal Signs': 1, 'Food & Beverages': 1, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 1, 'Airport Staff': 1}
# 📝 Review from Dubai - Page 1:
# Review Text: Not Verified |  Awful airport. 1 hour trip by bus from the aircraft to the arrival terminal. Then an...
# Overall Rating: 2, Recommended: Arrival Only, Date of Visit: December 2024
# Traveller Type: Solo Leisure, Experience: Arrival Only
# Ratings: {'Terminal Cleanliness': 3, 'Terminal Seating': 2, 'Terminal Signs': 1, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 1, 'Airport Staff': 1}
# 📝 Review from Dubai - Page 1:
# Review Text: Not Verified |  My mother, who just turned 76 needed a wheelchair so we booked one a long time ago, ...
# Overall Rating: 1, Recommended: Transit, Date of Visit: November 2024
# Traveller Type: Family Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 3, 'Terminal Seating': 1, 'Terminal Signs': 3, 'Food & Beverages': 0, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 4, 'Airport Staff': 1}
# 📝 Review from Dubai - Page 1:
# Review Text: Not Verified |  We landed at Dubai Airport just before midnight following a 6 and a half hour flight...
# Overall Rating: 3, Recommended: Arrival Only, Date of Visit: November 2024
# Traveller Type: Family Leisure, Experience: Arrival Only
# Ratings: {'Terminal Cleanliness': 3, 'Terminal Seating': 'N/A', 'Terminal Signs': 4, 'Food & Beverages': 0, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 4, 'Airport Staff': 1}
# 📝 Review from Dubai - Page 1:
# Review Text: Not Verified |  Unbelievably rude and lazy staff! They shout, don't greet, treat you like and object...
# Overall Rating: 1, Recommended: Transit, Date of Visit: November 2024
# Traveller Type: Solo Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 2, 'Terminal Seating': 1, 'Terminal Signs': 1, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 3, 'Airport Staff': 1}
# 📝 Review from Dubai - Page 1:
# Review Text: Not Verified |  My wife and I were returning from Bologna to Singapore. As we were traveling through...
# Overall Rating: 1, Recommended: Departure Only, Date of Visit: September 2024
# Traveller Type: Couple Leisure, Experience: Departure Only
# Ratings: {'Terminal Cleanliness': 3, 'Terminal Seating': 'N/A', 'Terminal Signs': 3, 'Food & Beverages': 0, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 2, 'Airport Staff': 1}
#
# Scraping Dubai - Page 2...
# Found 10 reviews on Dubai - Page 2
# 📝 Review from Dubai - Page 2:
# Review Text: Not Verified | Disappointed with Dubai airport (and with Emirates airlines in general, but this is a...
# Overall Rating: 1, Recommended: Transit, Date of Visit: July 2024
# Traveller Type: Solo Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 3, 'Terminal Seating': 3, 'Terminal Signs': 4, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 2, 'Airport Staff': 4}
# 📝 Review from Dubai - Page 2:
# Review Text: Not Verified | Horrible staff yelling at people. Very rude. On a long distance trip from Melbourne t...
# Overall Rating: 1, Recommended: Arrival and Departure, Date of Visit: July 2024
# Traveller Type: Couple Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 2, 'Terminal Seating': 1, 'Terminal Signs': 1, 'Food & Beverages': 2, 'Airport Shopping': 1, 'Wifi Connectivity': 1, 'Airport Staff': 1}
# 📝 Review from Dubai - Page 2:
# Review Text: Not Verified |   Same experience as previously in regards to woefully inadequate seating for the hug...
# Overall Rating: 1, Recommended: Transit, Date of Visit: July 2024
# Traveller Type: Couple Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 3, 'Terminal Seating': 1, 'Terminal Signs': 1, 'Food & Beverages': 1, 'Airport Shopping': 2, 'Wifi Connectivity': 2, 'Airport Staff': 1}
# 📝 Review from Dubai - Page 2:
# Review Text: Not Verified | I'm surprised by all the negative reviews as I found Dubai clean, efficient and well ...
# Overall Rating: 8, Recommended: Arrival and Departure, Date of Visit: July 2024
# Traveller Type: Solo Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 4, 'Terminal Signs': 5, 'Food & Beverages': 3, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 3, 'Airport Staff': 3}
# 📝 Review from Dubai - Page 2:
# Review Text: ✅ Trip Verified |  Its a peak of the summer and its somewhat hot inside the Terminal 2. The recent e...
# Overall Rating: 9, Recommended: Arrival and Departure, Date of Visit: July 2024
# Traveller Type: Solo Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 5, 'Terminal Signs': 5, 'Food & Beverages': 5, 'Airport Shopping': 4, 'Wifi Connectivity': 'N/A', 'Airport Staff': 5}
# 📝 Review from Dubai - Page 2:
# Review Text: Not Verified |   Stopped here on the way back from Poland for a 22 hr stopover before flying to Aust...
# Overall Rating: 4, Recommended: Transit, Date of Visit: May 2024
# Traveller Type: Business, Experience: Transit
# Ratings: {'Terminal Cleanliness': 3, 'Terminal Seating': 1, 'Terminal Signs': 3, 'Food & Beverages': 1, 'Airport Shopping': 5, 'Wifi Connectivity': 'N/A', 'Airport Staff': 3}
# 📝 Review from Dubai - Page 2:
# Review Text: Not Verified |   Very bad experience at DXB.. Due to mishandling of luggage my luggage was badly dam...
# Overall Rating: 1, Recommended: Arrival and Departure, Date of Visit: January 2024
# Traveller Type: Business, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 2, 'Terminal Signs': 3, 'Food & Beverages': 1, 'Airport Shopping': 2, 'Wifi Connectivity': 1, 'Airport Staff': 1}
# 📝 Review from Dubai - Page 2:
# Review Text: ✅ Trip Verified |  Dubai Airport was a well organized Airport. It has many shops and restaurants. Ho...
# Overall Rating: 6, Recommended: Transit, Date of Visit: June 2023
# Traveller Type: Business, Experience: Transit
# Ratings: {'Terminal Cleanliness': 3, 'Terminal Seating': 3, 'Terminal Signs': 4, 'Food & Beverages': 3, 'Airport Shopping': 3, 'Wifi Connectivity': 4, 'Airport Staff': 1}
# 📝 Review from Dubai - Page 2:
# Review Text: ✅ Trip Verified |  True color of organisation is discovered when time of need arise, and Dubai airpo...
# Overall Rating: 1, Recommended: Departure Only, Date of Visit: April 2024
# Traveller Type: Solo Leisure, Experience: Departure Only
# Ratings: {'Terminal Cleanliness': 1, 'Terminal Seating': 1, 'Terminal Signs': 1, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 1, 'Airport Staff': 1}
# 📝 Review from Dubai - Page 2:
# Review Text: ✅ Trip Verified |  Instead of being responsible and cancelling all flights, they decided to pretend ...
# Overall Rating: 1, Recommended: Arrival and Departure, Date of Visit: April 2024
# Traveller Type: Solo Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 1, 'Terminal Seating': 1, 'Terminal Signs': 1, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 1, 'Airport Staff': 1}
#
# Scraping Dubai - Page 3...
# Found 10 reviews on Dubai - Page 3
# 📝 Review from Dubai - Page 3:
# Review Text: Not Verified |   Very disappointed. I travelled a lot and this by far is the worst airport I have ex...
# Overall Rating: 1, Recommended: Transit, Date of Visit: April 2024
# Traveller Type: Family Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 3, 'Terminal Seating': 2, 'Terminal Signs': 2, 'Food & Beverages': 4, 'Airport Shopping': 4, 'Wifi Connectivity': 4, 'Airport Staff': 2}
# 📝 Review from Dubai - Page 3:
# Review Text: ✅ Trip Verified | I have been coming to Georgia for 4 years. It’s a place a love visiting. I am Afri...
# Overall Rating: 1, Recommended: Arrival Only, Date of Visit: February 2024
# Traveller Type: Couple Leisure, Experience: Arrival Only
# Ratings: {'Terminal Cleanliness': 1, 'Terminal Seating': 1, 'Terminal Signs': 1, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 1, 'Airport Staff': 1}
# 📝 Review from Dubai - Page 3:
# Review Text: Not Verified |  What a grim experience. 40 minute hold above Dubai to start. At 1 am in the morning?...
# Overall Rating: 1, Recommended: Transit, Date of Visit: January 2024
# Traveller Type: Solo Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 'N/A', 'Terminal Signs': 5, 'Food & Beverages': 3, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 1, 'Airport Staff': 3}
# 📝 Review from Dubai - Page 3:
# Review Text: Not Verified | Dubai airport is vast, but on entering arrivals staff were to hand explaining exactly...
# Overall Rating: 5, Recommended: Arrival and Departure, Date of Visit: October 2023
# Traveller Type: Couple Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 4, 'Terminal Signs': 4, 'Food & Beverages': 5, 'Airport Shopping': 4, 'Wifi Connectivity': 'N/A', 'Airport Staff': 2}
# 📝 Review from Dubai - Page 3:
# Review Text: ✅ Trip Verified |   Terminal 1 is used by non UAE airlines, easily connected through city by bus ,me...
# Overall Rating: 8, Recommended: Departure Only, Date of Visit: October 2023
# Traveller Type: Solo Leisure, Experience: Departure Only
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 3, 'Terminal Signs': 5, 'Food & Beverages': 2, 'Airport Shopping': 5, 'Wifi Connectivity': 4, 'Airport Staff': 4}
# 📝 Review from Dubai - Page 3:
# Review Text: Not Verified |  Bad experience of security. Half of the passengers were selected for searching. I en...
# Overall Rating: 1, Recommended: Transit, Date of Visit: September 2023
# Traveller Type: Solo Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 2, 'Terminal Signs': 4, 'Food & Beverages': 4, 'Airport Shopping': 4, 'Wifi Connectivity': 4, 'Airport Staff': 1}
# 📝 Review from Dubai - Page 3:
# Review Text: Not Verified |  I had a bad experience at the airport security. I was travelling to Toronto on Sep 2...
# Overall Rating: 2, Recommended: Arrival and Departure, Date of Visit: September 2023
# Traveller Type: Family Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 4, 'Terminal Signs': 5, 'Food & Beverages': 4, 'Airport Shopping': 5, 'Wifi Connectivity': 5, 'Airport Staff': 1}
# 📝 Review from Dubai - Page 3:
# Review Text: ✅ Trip Verified |  Overall, my journey through the airport has been smooth. And staying in the Airpo...
# Overall Rating: 6, Recommended: Transit, Date of Visit: July 2023
# Traveller Type: Solo Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 3, 'Terminal Seating': 4, 'Terminal Signs': 4, 'Food & Beverages': 3, 'Airport Shopping': 3, 'Wifi Connectivity': 4, 'Airport Staff': 5}
# 📝 Review from Dubai - Page 3:
# Review Text: ✅ Trip Verified |  I traveled use Emirates from Dammam and landed at terminal 3, and I have connecti...
# Overall Rating: 7, Recommended: Departure Only, Date of Visit: August 2023
# Traveller Type: Solo Leisure, Experience: Departure Only
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 5, 'Terminal Signs': 5, 'Food & Beverages': 5, 'Airport Shopping': 5, 'Wifi Connectivity': 5, 'Airport Staff': 1}
# 📝 Review from Dubai - Page 3:
# Review Text: Not Verified |  Frankly, it's abysmal in one major respect. There aren't any travelators and it is a...
# Overall Rating: 5, Recommended: Arrival and Departure, Date of Visit: July 2023
# Traveller Type: Solo Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 3, 'Terminal Seating': 2, 'Terminal Signs': 1, 'Food & Beverages': 0, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 'N/A', 'Airport Staff': 1}
#
# Scraping Doha - Page 1...
# ❌ Failed to fetch Doha - Page 1
#
# Scraping Doha - Page 2...
# Found 1 reviews on Doha - Page 2
# 📝 Review from Doha - Page 2:
# Review Text: ✅ Trip Verified | Went through KLIA terminal one domestic section for morning departure and afternoo...
# Overall Rating: 10, Recommended: Arrival and Departure, Date of Visit: February 2025
# Traveller Type: Solo Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 5, 'Terminal Signs': 5, 'Food & Beverages': 5, 'Airport Shopping': 5, 'Wifi Connectivity': 5, 'Airport Staff': 4}
#
# Scraping Doha - Page 3...
# Found 1 reviews on Doha - Page 3
# 📝 Review from Doha - Page 3:
# Review Text: ✅ Trip Verified | Went through KLIA terminal one domestic section for morning departure and afternoo...
# Overall Rating: 10, Recommended: Arrival and Departure, Date of Visit: February 2025
# Traveller Type: Solo Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 5, 'Terminal Signs': 5, 'Food & Beverages': 5, 'Airport Shopping': 5, 'Wifi Connectivity': 5, 'Airport Staff': 4}
#
# Scraping Abu Dhabi - Page 1...
# Found 10 reviews on Abu Dhabi - Page 1
# 📝 Review from Abu Dhabi - Page 1:
# Review Text: Not Verified |  This is a very modern airport but they have not thought through all details. There i...
# Overall Rating: 6, Recommended: Transit, Date of Visit: January 2025
# Traveller Type: Solo Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 2, 'Terminal Signs': 5, 'Food & Beverages': 4, 'Airport Shopping': 4, 'Wifi Connectivity': 5, 'Airport Staff': 3}
# 📝 Review from Abu Dhabi - Page 1:
# Review Text: ✅ Trip Verified |   The Airport is pretty decent in a lot of aspects. The duty free is vast, the air...
# Overall Rating: 8, Recommended: Transit, Date of Visit: December 2024
# Traveller Type: Solo Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 5, 'Terminal Signs': 5, 'Food & Beverages': 4, 'Airport Shopping': 5, 'Wifi Connectivity': 4, 'Airport Staff': 5}
# 📝 Review from Abu Dhabi - Page 1:
# Review Text: Not Verified |  Great airport. Good duty free Good f&b outlets. Just one question - why do you clean...
# Overall Rating: 9, Recommended: Arrival and Departure, Date of Visit: November 2024
# Traveller Type: Business, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 5, 'Terminal Signs': 5, 'Food & Beverages': 5, 'Airport Shopping': 5, 'Wifi Connectivity': 4, 'Airport Staff': 4}
# 📝 Review from Abu Dhabi - Page 1:
# Review Text: Not Verified | Super modern airport, bright shiny and very clean. Security control was reasonably qu...
# Overall Rating: 8, Recommended: Arrival and Departure, Date of Visit: October 2024
# Traveller Type: Solo Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 4, 'Terminal Signs': 4, 'Food & Beverages': 2, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 4, 'Airport Staff': 3}
# 📝 Review from Abu Dhabi - Page 1:
# Review Text: Not Verified |  Was feeling travel sick after arriving Abu Dhabi airport and while waiting for my ne...
# Overall Rating: 10, Recommended: Transit, Date of Visit: August 2024
# Traveller Type: Solo Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 5, 'Terminal Signs': 5, 'Food & Beverages': 5, 'Airport Shopping': 5, 'Wifi Connectivity': 3, 'Airport Staff': 5}
# 📝 Review from Abu Dhabi - Page 1:
# Review Text: ✅ Trip Verified |  On 10th of June I had a connection flight from Abu Dhabi to London at 2pm at gate...
# Overall Rating: 4, Recommended: Departure Only, Date of Visit: June 2024
# Traveller Type: Solo Leisure, Experience: Departure Only
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 4, 'Terminal Signs': 5, 'Food & Beverages': 5, 'Airport Shopping': 4, 'Wifi Connectivity': 5, 'Airport Staff': 1}
# 📝 Review from Abu Dhabi - Page 1:
# Review Text: Not Verified |   Airport may look amazing but passport control for arrivals is a shambles. 3 people ...
# Overall Rating: 2, Recommended: Arrival Only, Date of Visit: February 2024
# Traveller Type: Family Leisure, Experience: Arrival Only
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 'N/A', 'Terminal Signs': 2, 'Food & Beverages': 0, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 'N/A', 'Airport Staff': 'N/A'}
# 📝 Review from Abu Dhabi - Page 1:
# Review Text: ✅ Trip Verified |  As inefficient as the old airport. The only thing that has changed is the infrast...
# Overall Rating: 3, Recommended: Departure Only, Date of Visit: February 2024
# Traveller Type: Solo Leisure, Experience: Departure Only
# Ratings: {'Terminal Cleanliness': 3, 'Terminal Seating': 5, 'Terminal Signs': 5, 'Food & Beverages': 4, 'Airport Shopping': 5, 'Wifi Connectivity': 4, 'Airport Staff': 1}
# 📝 Review from Abu Dhabi - Page 1:
# Review Text: ✅ Trip Verified |  We have been transiting through this airport for over a decade, during which it h...
# Overall Rating: 4, Recommended: Transit, Date of Visit: October 2023
# Traveller Type: Couple Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 3, 'Terminal Seating': 3, 'Terminal Signs': 4, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 'N/A', 'Airport Staff': 2}
# 📝 Review from Abu Dhabi - Page 1:
# Review Text: Not Verified | Transited two times in Abu Dhabi and I confirm it as the worst airport of my life. Fu...
# Overall Rating: 1, Recommended: Transit, Date of Visit: August 2023
# Traveller Type: Couple Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 1, 'Terminal Seating': 1, 'Terminal Signs': 2, 'Food & Beverages': 2, 'Airport Shopping': 1, 'Wifi Connectivity': 3, 'Airport Staff': 1}
#
# Scraping Abu Dhabi - Page 2...
# Found 10 reviews on Abu Dhabi - Page 2
# 📝 Review from Abu Dhabi - Page 2:
# ...
# Overall Rating: 10, Recommended: Arrival and Departure, Date of Visit: April 2024
# Traveller Type: Family Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 5, 'Terminal Signs': 5, 'Food & Beverages': 5, 'Airport Shopping': 5, 'Wifi Connectivity': 5, 'Airport Staff': 5}
# 📝 Review from Hong Kong - Page 1:
# Review Text: ✅ Trip Verified | Shocking to find no city check in services provided both in TST and Central. All c...
# Overall Rating: 5, Recommended: Departure Only, Date of Visit: November 2023
# Traveller Type: Solo Leisure, Experience: Departure Only
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 5, 'Terminal Signs': 5, 'Food & Beverages': 4, 'Airport Shopping': 4, 'Wifi Connectivity': 5, 'Airport Staff': 4}
# 📝 Review from Hong Kong - Page 1:
# Review Text: ✅ Trip Verified | I do not understand how people claim this is a top tier airport. I found the staff...
# Overall Rating: 5, Recommended: Arrival and Departure, Date of Visit: November 2023
# Traveller Type: Solo Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 3, 'Terminal Seating': 5, 'Terminal Signs': 2, 'Food & Beverages': 3, 'Airport Shopping': 3, 'Wifi Connectivity': 5, 'Airport Staff': 2}
# 📝 Review from Hong Kong - Page 1:
# Review Text: ✅ Trip Verified | It is clean, modern and spacious. Employees are friendly and helpful. Goods in the...
# Overall Rating: 8, Recommended: Transit, Date of Visit: October 2023
# Traveller Type: Solo Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 4, 'Terminal Signs': 4, 'Food & Beverages': 4, 'Airport Shopping': 4, 'Wifi Connectivity': 4, 'Airport Staff': 4}
# 📝 Review from Hong Kong - Page 1:
# Review Text: ✅ Trip Verified |   Despite the good service of the airline staff, the airport staff are rude or non...
# Overall Rating: 1, Recommended: Departure Only, Date of Visit: October 2023
# Traveller Type: Business, Experience: Departure Only
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 3, 'Terminal Signs': 1, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 3, 'Airport Staff': 1}
#
# Scraping Hong Kong - Page 2...
# Found 10 reviews on Hong Kong - Page 2
# 📝 Review from Hong Kong - Page 2:
# Review Text: Not Verified |  Airport staff were a bit rude. Only one person at the transit gate who didn't bother...
# Overall Rating: 4, Recommended: Transit, Date of Visit: July 2023
# Traveller Type: Solo Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 3, 'Terminal Seating': 3, 'Terminal Signs': 4, 'Food & Beverages': 1, 'Airport Shopping': 4, 'Wifi Connectivity': 4, 'Airport Staff': 1}
# 📝 Review from Hong Kong - Page 2:
# Review Text: Not Verified | Without question the worst airport I’ve been in for years. It’s difficult to comprehe...
# Overall Rating: 1, Recommended: Departure Only, Date of Visit: May 2023
# Traveller Type: Business, Experience: Departure Only
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 1, 'Terminal Signs': 3, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 4, 'Airport Staff': 1}
# 📝 Review from Hong Kong - Page 2:
# Review Text: ✅ Trip Verified |  I got to visit the newly opened Sky Bridge that connects T1 to the T1 Satellite C...
# Overall Rating: 8, Recommended: Arrival Only, Date of Visit: March 2023
# Traveller Type: Solo Leisure, Experience: Arrival Only
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 4, 'Terminal Signs': 5, 'Food & Beverages': 5, 'Airport Shopping': 4, 'Wifi Connectivity': 5, 'Airport Staff': 4}
# 📝 Review from Hong Kong - Page 2:
# Review Text: ✅ Trip Verified |  I left my passport accidentally at the washroom and I didn't notice it until the ...
# Overall Rating: 8, Recommended: Departure Only, Date of Visit: March 2023
# Traveller Type: Solo Leisure, Experience: Departure Only
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 4, 'Terminal Signs': 5, 'Food & Beverages': 4, 'Airport Shopping': 3, 'Wifi Connectivity': 5, 'Airport Staff': 5}
# 📝 Review from Hong Kong - Page 2:
# Review Text: ✅ Trip Verified |  The baggage check-in and TSA process were efficient. The airport has opened more ...
# Overall Rating: 9, Recommended: Arrival and Departure, Date of Visit: April 2023
# Traveller Type: Solo Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 5, 'Terminal Signs': 5, 'Food & Beverages': 4, 'Airport Shopping': 5, 'Wifi Connectivity': 5, 'Airport Staff': 5}
# 📝 Review from Hong Kong - Page 2:
# Review Text: ✅ Trip Verified |  The immigration and baggage claim process was expeditious. While waiting for my b...
# Overall Rating: 9, Recommended: Arrival Only, Date of Visit: March 2023
# Traveller Type: Solo Leisure, Experience: Arrival Only
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 4, 'Terminal Signs': 5, 'Food & Beverages': 5, 'Airport Shopping': 4, 'Wifi Connectivity': 5, 'Airport Staff': 5}
# 📝 Review from Hong Kong - Page 2:
# Review Text: Not Verified |  Transited HKG airport twice within 8 days, and on both occasions experienced abrupt ...
# Overall Rating: 4, Recommended: Transit, Date of Visit: March 2023
# Traveller Type: Couple Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 3, 'Terminal Seating': 3, 'Terminal Signs': 4, 'Food & Beverages': 2, 'Airport Shopping': 3, 'Wifi Connectivity': 4, 'Airport Staff': 2}
# 📝 Review from Hong Kong - Page 2:
# Review Text: ✅ Trip Verified |  The airport is enormous and I had trouble finding directions to my boarding gate....
# Overall Rating: 8, Recommended: Arrival and Departure, Date of Visit: March 2023
# Traveller Type: Solo Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 4, 'Terminal Signs': 4, 'Food & Beverages': 4, 'Airport Shopping': 4, 'Wifi Connectivity': 5, 'Airport Staff': 5}
# 📝 Review from Hong Kong - Page 2:
# Review Text: ✅ Trip Verified |  Check in counter pretty much packed with passengers. Managed to grab a coffee fro...
# Overall Rating: 9, Recommended: Departure Only, Date of Visit: February 2023
# Traveller Type: Solo Leisure, Experience: Departure Only
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 5, 'Terminal Signs': 5, 'Food & Beverages': 4, 'Airport Shopping': 5, 'Wifi Connectivity': 5, 'Airport Staff': 5}
# 📝 Review from Hong Kong - Page 2:
# Review Text: ✅ Trip Verified | I can definitely feel the hustle and bustle vibe as I step into the airport. It lo...
# Overall Rating: 7, Recommended: Arrival and Departure, Date of Visit: February 2023
# Traveller Type: Family Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 4, 'Terminal Signs': 5, 'Food & Beverages': 5, 'Airport Shopping': 4, 'Wifi Connectivity': 5, 'Airport Staff': 4}
#
# Scraping Hong Kong - Page 3...
# Found 10 reviews on Hong Kong - Page 3
# 📝 Review from Hong Kong - Page 3:
# Review Text: ✅ Trip Verified | World class airport! I'm touched to see the airport is packed of travelers and tou...
# Overall Rating: 9, Recommended: Departure Only, Date of Visit: February 2023
# Traveller Type: Solo Leisure, Experience: Departure Only
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 4, 'Terminal Signs': 5, 'Food & Beverages': 5, 'Airport Shopping': 4, 'Wifi Connectivity': 5, 'Airport Staff': 5}
# 📝 Review from Hong Kong - Page 3:
# Review Text: ✅ Trip Verified |  The airport still looks great overall and I notice a few improvements and enhance...
# Overall Rating: 8, Recommended: Departure Only, Date of Visit: February 2023
# Traveller Type: Couple Leisure, Experience: Departure Only
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 4, 'Terminal Signs': 5, 'Food & Beverages': 3, 'Airport Shopping': 4, 'Wifi Connectivity': 5, 'Airport Staff': 4}
# 📝 Review from Hong Kong - Page 3:
# Review Text: ✅ Trip Verified | The airport is crowded again compared with the last 3 years. I experienced a long ...
# Overall Rating: 8, Recommended: Departure Only, Date of Visit: February 2023
# Traveller Type: Couple Leisure, Experience: Departure Only
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 4, 'Terminal Signs': 5, 'Food & Beverages': 3, 'Airport Shopping': 4, 'Wifi Connectivity': 5, 'Airport Staff': 5}
# 📝 Review from Hong Kong - Page 3:
# Review Text: ✅ Trip Verified |  The terminal is clean, a huge amount of check in counters but there was not too m...
# Overall Rating: 9, Recommended: Departure Only, Date of Visit: October 2022
# Traveller Type: Solo Leisure, Experience: Departure Only
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 5, 'Terminal Signs': 5, 'Food & Beverages': 4, 'Airport Shopping': 4, 'Wifi Connectivity': 5, 'Airport Staff': 5}
# 📝 Review from Hong Kong - Page 3:
# Review Text: ✅ Trip Verified | Since there is no PCR procedure, the whole process from checking in baggage to the...
# Overall Rating: 9, Recommended: Departure Only, Date of Visit: February 2023
# Traveller Type: Solo Leisure, Experience: Departure Only
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 5, 'Terminal Signs': 5, 'Food & Beverages': 4, 'Airport Shopping': 4, 'Wifi Connectivity': 5, 'Airport Staff': 4}
# 📝 Review from Hong Kong - Page 3:
# Review Text: ✅ Trip Verified |  Finally I came back to the airport as I'd have a business trip to Taiwan. The air...
# Overall Rating: 9, Recommended: Departure Only, Date of Visit: February 2023
# Traveller Type: Business, Experience: Departure Only
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 4, 'Terminal Signs': 5, 'Food & Beverages': 4, 'Airport Shopping': 3, 'Wifi Connectivity': 5, 'Airport Staff': 4}
# 📝 Review from Hong Kong - Page 3:
# Review Text: ✅ Trip Verified |  HKIA features 2 terminals with 2 separate concourses connected by the automated p...
# Overall Rating: 9, Recommended: Arrival and Departure, Date of Visit: February 2023
# Traveller Type: Family Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 5, 'Terminal Signs': 5, 'Food & Beverages': 4, 'Airport Shopping': 5, 'Wifi Connectivity': 5, 'Airport Staff': 4}
# 📝 Review from Hong Kong - Page 3:
# Review Text: ✅ Trip Verified |  Absolutely atrocious transit experience. I flew in from MNL allowing myself two h...
# Overall Rating: 2, Recommended: Transit, Date of Visit: February 2023
# Traveller Type: Couple Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 4, 'Terminal Seating': 'N/A', 'Terminal Signs': 4, 'Food & Beverages': 0, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 'N/A', 'Airport Staff': 1}
# 📝 Review from Hong Kong - Page 3:
# Review Text: ✅ Trip Verified |  Arrived at Hong Kong Airport for transit on 15 December 2022 by Cathy Pacific fli...
# Overall Rating: 4, Recommended: Transit, Date of Visit: December 2022
# Traveller Type: Solo Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 1, 'Terminal Seating': 3, 'Terminal Signs': 1, 'Food & Beverages': 0, 'Airport Shopping': 'N/A', 'Wifi Connectivity': 'N/A', 'Airport Staff': 3}
# 📝 Review from Hong Kong - Page 3:
# Review Text: Not Verified | One of the worse experience ever. Excessive AC (18°C outside as I write this), a cons...
# Overall Rating: 2, Recommended: Transit, Date of Visit: December 2022
# Traveller Type: Couple Leisure, Experience: Transit
# Ratings: {'Terminal Cleanliness': 2, 'Terminal Seating': 1, 'Terminal Signs': 3, 'Food & Beverages': 1, 'Airport Shopping': 1, 'Wifi Connectivity': 3, 'Airport Staff': 2}
#
# Scraping Delhi - Page 1...
# ❌ Failed to fetch Delhi - Page 1
#
# Scraping Delhi - Page 2...
# Found 1 reviews on Delhi - Page 2
# 📝 Review from Delhi - Page 2:
# Review Text: ✅ Trip Verified | Went through KLIA terminal one domestic section for morning departure and afternoo...
# Overall Rating: 10, Recommended: Arrival and Departure, Date of Visit: February 2025
# Traveller Type: Solo Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 5, 'Terminal Signs': 5, 'Food & Beverages': 5, 'Airport Shopping': 5, 'Wifi Connectivity': 5, 'Airport Staff': 4}
#
# Scraping Delhi - Page 3...
# Found 1 reviews on Delhi - Page 3
# 📝 Review from Delhi - Page 3:
# Review Text: ✅ Trip Verified | Went through KLIA terminal one domestic section for morning departure and afternoo...
# Overall Rating: 10, Recommended: Arrival and Departure, Date of Visit: February 2025
# Traveller Type: Solo Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 5, 'Terminal Signs': 5, 'Food & Beverages': 5, 'Airport Shopping': 5, 'Wifi Connectivity': 5, 'Airport Staff': 4}
#
# Scraping Mumbai - Page 1...
# ❌ Failed to fetch Mumbai - Page 1
#
# Scraping Mumbai - Page 2...
# Found 1 reviews on Mumbai - Page 2
# 📝 Review from Mumbai - Page 2:
# Review Text: ✅ Trip Verified | Went through KLIA terminal one domestic section for morning departure and afternoo...
# Overall Rating: 10, Recommended: Arrival and Departure, Date of Visit: February 2025
# Traveller Type: Solo Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 5, 'Terminal Signs': 5, 'Food & Beverages': 5, 'Airport Shopping': 5, 'Wifi Connectivity': 5, 'Airport Staff': 4}
#
# Scraping Mumbai - Page 3...
# Found 1 reviews on Mumbai - Page 3
# 📝 Review from Mumbai - Page 3:
# Review Text: ✅ Trip Verified | Went through KLIA terminal one domestic section for morning departure and afternoo...
# Overall Rating: 10, Recommended: Arrival and Departure, Date of Visit: February 2025
# Traveller Type: Solo Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 5, 'Terminal Signs': 5, 'Food & Beverages': 5, 'Airport Shopping': 5, 'Wifi Connectivity': 5, 'Airport Staff': 4}
#
# Scraping Bangalore - Page 1...
# ❌ Failed to fetch Bangalore - Page 1
#
# Scraping Bangalore - Page 2...
# Found 1 reviews on Bangalore - Page 2
# 📝 Review from Bangalore - Page 2:
# Review Text: ✅ Trip Verified | Went through KLIA terminal one domestic section for morning departure and afternoo...
# Overall Rating: 10, Recommended: Arrival and Departure, Date of Visit: February 2025
# Traveller Type: Solo Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 5, 'Terminal Signs': 5, 'Food & Beverages': 5, 'Airport Shopping': 5, 'Wifi Connectivity': 5, 'Airport Staff': 4}
#
# Scraping Bangalore - Page 3...
# Found 1 reviews on Bangalore - Page 3
# 📝 Review from Bangalore - Page 3:
# Review Text: ✅ Trip Verified | Went through KLIA terminal one domestic section for morning departure and afternoo...
# Overall Rating: 10, Recommended: Arrival and Departure, Date of Visit: February 2025
# Traveller Type: Solo Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 5, 'Terminal Signs': 5, 'Food & Beverages': 5, 'Airport Shopping': 5, 'Wifi Connectivity': 5, 'Airport Staff': 4}
#
# Scraping Hyderabad - Page 1...
# ❌ Failed to fetch Hyderabad - Page 1
#
# Scraping Hyderabad - Page 2...
# Found 1 reviews on Hyderabad - Page 2
# 📝 Review from Hyderabad - Page 2:
# Review Text: ✅ Trip Verified | Went through KLIA terminal one domestic section for morning departure and afternoo...
# Overall Rating: 10, Recommended: Arrival and Departure, Date of Visit: February 2025
# Traveller Type: Solo Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 5, 'Terminal Signs': 5, 'Food & Beverages': 5, 'Airport Shopping': 5, 'Wifi Connectivity': 5, 'Airport Staff': 4}
#
# Scraping Hyderabad - Page 3...
# Found 1 reviews on Hyderabad - Page 3
# 📝 Review from Hyderabad - Page 3:
# Review Text: ✅ Trip Verified | Went through KLIA terminal one domestic section for morning departure and afternoo...
# Overall Rating: 10, Recommended: Arrival and Departure, Date of Visit: February 2025
# Traveller Type: Solo Leisure, Experience: Arrival and Departure
# Ratings: {'Terminal Cleanliness': 5, 'Terminal Seating': 5, 'Terminal Signs': 5, 'Food & Beverages': 5, 'Airport Shopping': 5, 'Wifi Connectivity': 5, 'Airport Staff': 4}
#
# ✅ Scraping complete! Data is stored in the 'all_reviews' list.

# %%
df = pd.DataFrame(all_reviews)
df.to_csv("airport_reviews.csv", index=False)
print("Data saved to airport_reviews.csv")
